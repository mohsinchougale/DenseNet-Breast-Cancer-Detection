# %%
import tensorflow 

import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import models

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("Tensorflow-version:", tensorflow.__version__)
# Out:
# Tensorflow-version: 2.8.0

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(8,activation='softmax')(x) #FC-layer
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 1s 0us/step
# 29097984/29084464 [==============================] - 1s 0us/step

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(3,activation='softmax')(x) #FC-layer

# %%
model=Model(inputs=model_d.input,outputs=preds)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 4, 4, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 4, 4, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 4, 4, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 4, 4, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 4, 4, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 4, 4, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 4, 4, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 4, 4, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 4, 4, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 4, 4, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 4, 4, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 4, 4, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 4, 4, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 4, 4, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 4, 4, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 4, 4, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 4, 4, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 4, 4, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 4, 4, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 4, 4, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 4, 4, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 4, 4, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 4, 4, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 4, 4, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 4, 4, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 4, 4, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 4, 4, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 4, 4, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1024)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1024)        4096        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1049600     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 8,619,587
# Trainable params: 8,532,867
# Non-trainable params: 86,720
# __________________________________________________________________________________________________

# %%
for layer in model.layers[:-8]:
    layer.trainable=False
    
for layer in model.layers[-8:]:
    layer.trainable=True

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 4, 4, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 4, 4, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 4, 4, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 4, 4, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 4, 4, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 4, 4, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 4, 4, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 4, 4, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 4, 4, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 4, 4, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 4, 4, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 4, 4, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 4, 4, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 4, 4, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 4, 4, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 4, 4, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 4, 4, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 4, 4, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 4, 4, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 4, 4, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 4, 4, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 4, 4, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 4, 4, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 4, 4, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 4, 4, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 4, 4, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 4, 4, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 4, 4, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1024)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1024)        4096        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1049600     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 8,619,587
# Trainable params: 1,579,011
# Non-trainable params: 7,040,576
# __________________________________________________________________________________________________

# %%
data=[]
labels=[]
random.seed(42)
# imagePaths = sorted(list(os.listdir("/content/drive/MyDrive/Mini_DDSM_Upload")))
imagePaths = ['Benign','Cancer','Normal']
random.shuffle(imagePaths)
print(imagePaths)
# Out:
# ['Cancer', 'Benign', 'Normal']

# %%
for img in imagePaths:
    path=sorted(list(os.listdir("/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img)))
    for i in path:
      if("RIGHT_CC" in i):
        #Considereing original and flipped image
        for flip in range(2):
          if(flip == 0):
            print("\n****************************************")
            print("Original")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            print(image_path)
            # print("Reading image")
            image = cv2.imread(image_path)
            
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResized Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            # print("Label - ",l)
            labels.append(l)
          else:
            print("\n\n")
            print("FLIPPED")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            # print("Image Path - ",image_path)
            # print("Reading image ",i)
            image = cv2.imread(image_path)
            # print("Flipping Image")
            image = cv2.flip(image,1)
            
            # print("\nResizing the flipped image")
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResizing Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            print("Label - ",l)
            labels.append(l)
        else:
          continue
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1828_D_4536_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1832_D_4537_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1836_D_4538_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1840_D_4539_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1844_D_4540_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1848_D_4541_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/184_A_0062_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1852_D_4542_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1856_D_4543_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1860_D_4544_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1864_D_4545_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1868_D_4546_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1872_D_4547_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1876_D_4551_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1880_D_4552_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1884_D_4553_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1888_D_4555_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/188_A_0063_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1892_D_4557_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1896_D_4558_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1900_D_4559_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1904_D_4560_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1908_D_4561_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1912_D_4562_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1916_D_4563_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1920_D_4565_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1924_D_4566_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1928_D_4567_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/192_A_0064_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1932_D_4570_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1936_D_4571_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1940_D_4572_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1944_D_4574_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1948_D_4575_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1952_D_4576_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1956_D_4577_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1960_D_4582_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1964_D_4583_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1968_D_4584_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/196_A_0067_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1972_D_4585_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1976_D_4587_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1980_D_4588_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1984_D_4589_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1988_D_4590_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1992_D_4591_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1996_D_4592_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2000_D_4593_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2003_D_4548_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2004_D_4548_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2007_D_4549_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2008_D_4549_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/200_A_0068_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2011_D_4550_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2012_D_4550_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2015_D_4554_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2016_D_4554_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2019_D_4556_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2020_D_4556_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2023_D_4564_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2024_D_4564_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2028_D_4568_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2031_D_4573_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2032_D_4573_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2036_D_4578_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2040_D_4579_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2043_D_4580_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2044_D_4580_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2047_D_4581_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2048_D_4581_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/204_A_0069_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2051_D_4586_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2052_D_4586_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2055_D_4596_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2056_D_4596_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2059_D_4597_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2060_D_4597_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2063_D_4598_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2064_D_4598_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2067_D_4599_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2068_D_4599_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2071_D_4600_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2072_D_4600_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2075_D_4601_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2076_D_4601_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2079_D_4602_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2080_D_4602_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2083_D_4603_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2084_D_4603_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2087_D_4604_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2088_D_4604_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/208_A_0070_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2091_D_4605_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2092_D_4605_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2095_D_4606_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2096_D_4606_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2099_D_4607_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/20_A_0009_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2100_D_4607_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2103_D_4608_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2104_D_4608_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2107_B_3600_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2108_B_3600_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2111_B_3601_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2112_B_3601_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2115_B_3602_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2116_B_3602_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2119_B_3603_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2120_B_3603_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2123_B_3604_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2124_B_3604_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2127_B_3605_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2128_B_3605_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/212_A_0071_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2131_B_3606_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2132_B_3606_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2135_B_3607_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2136_B_3607_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2139_B_3608_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2140_B_3608_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2143_B_3609_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2144_B_3609_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2147_B_3610_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2148_B_3610_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2151_B_3611_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2152_B_3611_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2155_B_3612_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2156_B_3612_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2159_B_3613_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2160_B_3613_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2163_B_3614_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2164_B_3614_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2167_B_3615_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2168_B_3615_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/216_A_0072_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2171_B_3616_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2172_B_3616_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2175_B_3617_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2176_B_3617_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2179_B_3618_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2180_B_3618_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2183_B_3619_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2184_B_3619_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2187_B_3620_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2188_B_3620_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2191_B_3621_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2192_B_3621_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2195_B_3622_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2196_B_3622_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2199_B_3623_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2200_B_3623_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2203_B_3624_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2204_B_3624_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2207_B_3625_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2208_B_3625_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/220_A_0073_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2211_B_3626_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2212_B_3626_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2215_B_3627_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2216_B_3627_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2219_B_3628_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2220_B_3628_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2223_B_3629_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2224_B_3629_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2227_B_3630_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2228_B_3630_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2231_B_3631_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2232_B_3631_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2235_B_3632_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2236_B_3632_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2239_B_3633_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2240_B_3633_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2243_B_3634_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2244_B_3634_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2247_B_3635_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2248_B_3635_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/224_A_0074_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2251_B_3636_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2252_B_3636_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2255_B_3637_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2256_B_3637_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2259_B_3638_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2260_B_3638_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2263_B_3639_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2264_B_3639_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2267_B_3640_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2268_B_3640_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2271_B_3641_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2272_B_3641_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2275_B_3642_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2276_B_3642_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2279_B_3643_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2280_B_3643_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2283_B_3644_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2284_B_3644_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2287_B_3645_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2288_B_3645_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/228_A_0075_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2291_B_3646_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2292_B_3646_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2295_B_3647_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2296_B_3647_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2299_B_3648_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2300_B_3648_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2303_B_3649_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2304_B_3649_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2307_B_3650_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2308_B_3650_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2311_B_3651_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2312_B_3651_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2315_B_3652_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2316_B_3652_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2319_B_3653_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2320_B_3653_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2323_B_3654_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2324_B_3654_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2327_B_3655_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2328_B_3655_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/232_A_0076_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2331_B_3656_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2332_B_3656_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2335_B_3657_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2336_B_3657_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2339_B_3660_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2340_B_3660_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2343_B_3661_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2344_B_3661_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2347_B_3662_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2348_B_3662_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2351_B_3663_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2352_B_3663_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2355_B_3664_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2356_B_3664_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2359_B_3665_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2360_B_3665_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2363_B_3666_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2364_B_3666_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2367_B_3667_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2368_B_3667_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/236_A_0077_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2371_B_3668_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2372_B_3668_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2375_B_3669_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2376_B_3669_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2379_B_3670_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2380_B_3670_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2383_B_3671_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2384_B_3671_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2387_B_3672_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2388_B_3672_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2391_B_3673_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2392_B_3673_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2395_B_3674_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2396_B_3674_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2399_B_3675_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2400_B_3675_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2403_B_3676_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2404_B_3676_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2407_B_3677_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2408_B_3677_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/240_A_0079_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2411_B_3678_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2412_B_3678_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2415_B_3679_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2416_B_3679_1.RIGHT_CC.LJPEG.1_highpass.png
#
# ...
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/680_A_0263_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/684_A_0264_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/688_A_0265_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/68_A_0026_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/692_A_0266_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/696_A_0267_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/700_A_0268_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/704_A_0269_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/708_A_0270_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/712_A_0271_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/716_A_0272_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/720_A_0273_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/724_A_0274_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/728_A_0275_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/72_A_0027_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/732_A_0276_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/736_A_0277_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/740_A_0278_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/744_A_0279_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/748_A_0280_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/752_A_0282_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/756_A_0283_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/760_A_0284_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/764_A_0285_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/768_A_0286_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/76_A_0030_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/772_A_0287_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/776_A_0290_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/780_A_0292_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/784_A_0293_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/788_A_0294_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/792_A_0295_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/796_A_0296_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/800_A_0297_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/804_A_0298_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/808_A_0299_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/80_A_0031_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/812_A_0302_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/816_A_0303_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/820_A_0304_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/824_A_0305_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/828_A_0306_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/832_A_0307_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/836_A_0309_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/840_A_0310_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/844_A_0311_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/848_A_0312_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/84_A_0032_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/852_A_0313_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/856_A_0314_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/860_A_0315_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/864_A_0317_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/868_A_0318_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/872_A_0319_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/876_A_0320_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/880_A_0321_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/884_A_0322_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/888_A_0323_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/88_A_0034_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/892_A_0325_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/896_A_0326_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/8_A_0003_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/900_A_0327_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/904_A_0328_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/908_A_0330_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/912_A_0331_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/916_A_0333_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/920_A_0334_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/924_A_0335_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/928_A_0336_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/92_A_0035_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/932_A_0337_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/936_A_0338_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/940_A_0339_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/944_A_0341_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/948_A_0342_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/952_A_0343_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/956_A_0344_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/960_A_0345_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/964_A_0347_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/968_A_0348_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/96_A_0036_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/972_A_0349_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/976_A_0351_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/980_A_0352_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/984_A_0354_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/988_A_0355_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/992_A_0356_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/996_A_0357_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal

# %%
print("Length of dataset = ",len(labels))
# Out:
# Length of dataset =  3358

# %%
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
print(labels[0])
# Out:
# [0 1 0]

# %%
(xtrain,xtest,ytrain,ytest)=train_test_split(data,labels,test_size=0.2,random_state=42)
print(xtrain.shape, xtest.shape)
# Out:
# (2686, 128, 128, 3) (672, 128, 128, 3)

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)


datagen.fit(xtrain)
# Fits-the-model
history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=128),
               steps_per_epoch=xtrain.shape[0] //128,
               epochs=150, #try 100
               verbose=2,
               callbacks=[anne, checkpoint],
               validation_data=(xtrain, ytrain))
# Out:
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 1.14423, saving model to model.h5
# 20/20 - 32s - loss: 1.1536 - accuracy: 0.6388 - val_loss: 1.1442 - val_accuracy: 0.6083 - lr: 0.0010 - 32s/epoch - 2s/step
# Epoch 2/150
#
# Epoch 2: val_loss improved from 1.14423 to 0.74184, saving model to model.h5
# 20/20 - 12s - loss: 0.8892 - accuracy: 0.7035 - val_loss: 0.7418 - val_accuracy: 0.6906 - lr: 0.0010 - 12s/epoch - 613ms/step
# Epoch 3/150
#
# Epoch 3: val_loss improved from 0.74184 to 0.55075, saving model to model.h5
# 20/20 - 12s - loss: 0.7797 - accuracy: 0.7150 - val_loss: 0.5508 - val_accuracy: 0.7580 - lr: 0.0010 - 12s/epoch - 615ms/step
# Epoch 4/150
#
# Epoch 4: val_loss improved from 0.55075 to 0.55027, saving model to model.h5
# 20/20 - 12s - loss: 0.6840 - accuracy: 0.7314 - val_loss: 0.5503 - val_accuracy: 0.7509 - lr: 0.0010 - 12s/epoch - 614ms/step
# Epoch 5/150
#
# Epoch 5: val_loss improved from 0.55027 to 0.52286, saving model to model.h5
# 20/20 - 12s - loss: 0.6699 - accuracy: 0.7377 - val_loss: 0.5229 - val_accuracy: 0.7707 - lr: 0.0010 - 12s/epoch - 615ms/step
# Epoch 6/150
#
# Epoch 6: val_loss improved from 0.52286 to 0.46933, saving model to model.h5
# 20/20 - 12s - loss: 0.5909 - accuracy: 0.7557 - val_loss: 0.4693 - val_accuracy: 0.7990 - lr: 0.0010 - 12s/epoch - 617ms/step
# Epoch 7/150
#
# Epoch 7: val_loss improved from 0.46933 to 0.44462, saving model to model.h5
# 20/20 - 12s - loss: 0.5775 - accuracy: 0.7647 - val_loss: 0.4446 - val_accuracy: 0.8071 - lr: 0.0010 - 12s/epoch - 614ms/step
# Epoch 8/150
#
# Epoch 8: val_loss improved from 0.44462 to 0.40784, saving model to model.h5
# 20/20 - 12s - loss: 0.5350 - accuracy: 0.7748 - val_loss: 0.4078 - val_accuracy: 0.8306 - lr: 0.0010 - 12s/epoch - 614ms/step
# Epoch 9/150
#
# Epoch 9: val_loss improved from 0.40784 to 0.40499, saving model to model.h5
# 20/20 - 13s - loss: 0.5387 - accuracy: 0.7776 - val_loss: 0.4050 - val_accuracy: 0.8254 - lr: 0.0010 - 13s/epoch - 627ms/step
# Epoch 10/150
#
# Epoch 10: val_loss improved from 0.40499 to 0.39377, saving model to model.h5
# 20/20 - 12s - loss: 0.5105 - accuracy: 0.7889 - val_loss: 0.3938 - val_accuracy: 0.8332 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 11/150
#
# Epoch 11: val_loss improved from 0.39377 to 0.39255, saving model to model.h5
# 20/20 - 12s - loss: 0.5231 - accuracy: 0.7862 - val_loss: 0.3926 - val_accuracy: 0.8354 - lr: 0.0010 - 12s/epoch - 606ms/step
# Epoch 12/150
#
# Epoch 12: val_loss improved from 0.39255 to 0.36591, saving model to model.h5
# 20/20 - 12s - loss: 0.4891 - accuracy: 0.7901 - val_loss: 0.3659 - val_accuracy: 0.8488 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 13/150
#
# Epoch 13: val_loss improved from 0.36591 to 0.35213, saving model to model.h5
# 20/20 - 12s - loss: 0.4774 - accuracy: 0.8018 - val_loss: 0.3521 - val_accuracy: 0.8485 - lr: 0.0010 - 12s/epoch - 613ms/step
# Epoch 14/150
#
# Epoch 14: val_loss improved from 0.35213 to 0.32811, saving model to model.h5
# 20/20 - 12s - loss: 0.4694 - accuracy: 0.7987 - val_loss: 0.3281 - val_accuracy: 0.8667 - lr: 0.0010 - 12s/epoch - 604ms/step
# Epoch 15/150
#
# Epoch 15: val_loss improved from 0.32811 to 0.32714, saving model to model.h5
# 20/20 - 12s - loss: 0.4678 - accuracy: 0.7995 - val_loss: 0.3271 - val_accuracy: 0.8812 - lr: 0.0010 - 12s/epoch - 608ms/step
# Epoch 16/150
#
# Epoch 16: val_loss improved from 0.32714 to 0.31736, saving model to model.h5
# 20/20 - 12s - loss: 0.4495 - accuracy: 0.8104 - val_loss: 0.3174 - val_accuracy: 0.8853 - lr: 0.0010 - 12s/epoch - 606ms/step
# Epoch 17/150
#
# Epoch 17: val_loss did not improve from 0.31736
# 20/20 - 11s - loss: 0.4543 - accuracy: 0.8053 - val_loss: 0.3204 - val_accuracy: 0.8704 - lr: 0.0010 - 11s/epoch - 559ms/step
# Epoch 18/150
#
# Epoch 18: val_loss improved from 0.31736 to 0.30831, saving model to model.h5
# 20/20 - 12s - loss: 0.4734 - accuracy: 0.8018 - val_loss: 0.3083 - val_accuracy: 0.8786 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 19/150
#
# Epoch 19: val_loss improved from 0.30831 to 0.29905, saving model to model.h5
# 20/20 - 12s - loss: 0.4332 - accuracy: 0.8206 - val_loss: 0.2991 - val_accuracy: 0.8864 - lr: 0.0010 - 12s/epoch - 610ms/step
# Epoch 20/150
#
# Epoch 20: val_loss did not improve from 0.29905
# 20/20 - 11s - loss: 0.4676 - accuracy: 0.8065 - val_loss: 0.3006 - val_accuracy: 0.8831 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 21/150
#
# Epoch 21: val_loss improved from 0.29905 to 0.27775, saving model to model.h5
# 20/20 - 12s - loss: 0.4282 - accuracy: 0.8256 - val_loss: 0.2777 - val_accuracy: 0.9039 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 22/150
#
# Epoch 22: val_loss improved from 0.27775 to 0.27107, saving model to model.h5
# 20/20 - 12s - loss: 0.4141 - accuracy: 0.8178 - val_loss: 0.2711 - val_accuracy: 0.8950 - lr: 0.0010 - 12s/epoch - 609ms/step
# Epoch 23/150
#
# Epoch 23: val_loss did not improve from 0.27107
# 20/20 - 11s - loss: 0.4090 - accuracy: 0.8268 - val_loss: 0.2723 - val_accuracy: 0.8969 - lr: 0.0010 - 11s/epoch - 568ms/step
# Epoch 24/150
#
# Epoch 24: val_loss improved from 0.27107 to 0.24881, saving model to model.h5
# 20/20 - 12s - loss: 0.4180 - accuracy: 0.8217 - val_loss: 0.2488 - val_accuracy: 0.9166 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 25/150
#
# Epoch 25: val_loss improved from 0.24881 to 0.22568, saving model to model.h5
# 20/20 - 12s - loss: 0.4019 - accuracy: 0.8362 - val_loss: 0.2257 - val_accuracy: 0.9289 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 26/150
#
# Epoch 26: val_loss did not improve from 0.22568
# 20/20 - 11s - loss: 0.4065 - accuracy: 0.8276 - val_loss: 0.2284 - val_accuracy: 0.9281 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 27/150
#
# Epoch 27: val_loss improved from 0.22568 to 0.21370, saving model to model.h5
# 20/20 - 12s - loss: 0.3963 - accuracy: 0.8358 - val_loss: 0.2137 - val_accuracy: 0.9274 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 28/150
#
# Epoch 28: val_loss improved from 0.21370 to 0.20415, saving model to model.h5
# 20/20 - 12s - loss: 0.3649 - accuracy: 0.8479 - val_loss: 0.2041 - val_accuracy: 0.9293 - lr: 0.0010 - 12s/epoch - 609ms/step
# Epoch 29/150
#
# Epoch 29: val_loss improved from 0.20415 to 0.20037, saving model to model.h5
# 20/20 - 12s - loss: 0.3817 - accuracy: 0.8460 - val_loss: 0.2004 - val_accuracy: 0.9304 - lr: 0.0010 - 12s/epoch - 613ms/step
# Epoch 30/150
#
# Epoch 30: val_loss did not improve from 0.20037
# 20/20 - 11s - loss: 0.3917 - accuracy: 0.8397 - val_loss: 0.2071 - val_accuracy: 0.9311 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 31/150
#
# Epoch 31: val_loss improved from 0.20037 to 0.18336, saving model to model.h5
# 20/20 - 12s - loss: 0.3686 - accuracy: 0.8511 - val_loss: 0.1834 - val_accuracy: 0.9352 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 32/150
#
# Epoch 32: val_loss improved from 0.18336 to 0.17688, saving model to model.h5
# 20/20 - 12s - loss: 0.3524 - accuracy: 0.8569 - val_loss: 0.1769 - val_accuracy: 0.9419 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 33/150
#
# Epoch 33: val_loss did not improve from 0.17688
# 20/20 - 11s - loss: 0.3655 - accuracy: 0.8542 - val_loss: 0.1776 - val_accuracy: 0.9434 - lr: 0.0010 - 11s/epoch - 565ms/step
# Epoch 34/150
#
# Epoch 34: val_loss improved from 0.17688 to 0.16883, saving model to model.h5
# 20/20 - 12s - loss: 0.3458 - accuracy: 0.8555 - val_loss: 0.1688 - val_accuracy: 0.9449 - lr: 0.0010 - 12s/epoch - 610ms/step
# Epoch 35/150
#
# Epoch 35: val_loss did not improve from 0.16883
# 20/20 - 11s - loss: 0.3675 - accuracy: 0.8518 - val_loss: 0.1869 - val_accuracy: 0.9274 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 36/150
#
# Epoch 36: val_loss improved from 0.16883 to 0.16871, saving model to model.h5
# 20/20 - 12s - loss: 0.3464 - accuracy: 0.8616 - val_loss: 0.1687 - val_accuracy: 0.9389 - lr: 0.0010 - 12s/epoch - 609ms/step
# Epoch 37/150
#
# Epoch 37: val_loss improved from 0.16871 to 0.15664, saving model to model.h5
# 20/20 - 12s - loss: 0.3492 - accuracy: 0.8522 - val_loss: 0.1566 - val_accuracy: 0.9483 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 38/150
#
# Epoch 38: val_loss did not improve from 0.15664
# 20/20 - 11s - loss: 0.3498 - accuracy: 0.8569 - val_loss: 0.1578 - val_accuracy: 0.9386 - lr: 0.0010 - 11s/epoch - 564ms/step
# Epoch 39/150
#
# Epoch 39: val_loss did not improve from 0.15664
# 20/20 - 11s - loss: 0.3668 - accuracy: 0.8530 - val_loss: 0.1570 - val_accuracy: 0.9456 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 40/150
#
# Epoch 40: val_loss improved from 0.15664 to 0.15418, saving model to model.h5
# 20/20 - 12s - loss: 0.3319 - accuracy: 0.8659 - val_loss: 0.1542 - val_accuracy: 0.9401 - lr: 0.0010 - 12s/epoch - 620ms/step
# Epoch 41/150
#
# Epoch 41: val_loss improved from 0.15418 to 0.14321, saving model to model.h5
# 20/20 - 12s - loss: 0.3328 - accuracy: 0.8608 - val_loss: 0.1432 - val_accuracy: 0.9483 - lr: 0.0010 - 12s/epoch - 610ms/step
# Epoch 42/150
#
# Epoch 42: val_loss improved from 0.14321 to 0.12564, saving model to model.h5
# 20/20 - 12s - loss: 0.3259 - accuracy: 0.8729 - val_loss: 0.1256 - val_accuracy: 0.9576 - lr: 0.0010 - 12s/epoch - 610ms/step
# Epoch 43/150
#
# Epoch 43: val_loss did not improve from 0.12564
# 20/20 - 11s - loss: 0.3102 - accuracy: 0.8733 - val_loss: 0.1306 - val_accuracy: 0.9587 - lr: 0.0010 - 11s/epoch - 564ms/step
# Epoch 44/150
#
# Epoch 44: val_loss did not improve from 0.12564
# 20/20 - 11s - loss: 0.3040 - accuracy: 0.8812 - val_loss: 0.1259 - val_accuracy: 0.9587 - lr: 0.0010 - 11s/epoch - 566ms/step
# Epoch 45/150
#
# Epoch 45: val_loss did not improve from 0.12564
# 20/20 - 11s - loss: 0.3117 - accuracy: 0.8780 - val_loss: 0.1275 - val_accuracy: 0.9572 - lr: 0.0010 - 11s/epoch - 564ms/step
# Epoch 46/150
#
# Epoch 46: val_loss did not improve from 0.12564
# 20/20 - 11s - loss: 0.3328 - accuracy: 0.8702 - val_loss: 0.1279 - val_accuracy: 0.9572 - lr: 0.0010 - 11s/epoch - 561ms/step
# Epoch 47/150
#
# Epoch 47: val_loss improved from 0.12564 to 0.11471, saving model to model.h5
# 20/20 - 12s - loss: 0.3133 - accuracy: 0.8757 - val_loss: 0.1147 - val_accuracy: 0.9628 - lr: 0.0010 - 12s/epoch - 615ms/step
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.11471 to 0.11440, saving model to model.h5
# 20/20 - 12s - loss: 0.2931 - accuracy: 0.8788 - val_loss: 0.1144 - val_accuracy: 0.9672 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 49/150
#
# Epoch 49: val_loss did not improve from 0.11440
# 20/20 - 11s - loss: 0.3041 - accuracy: 0.8737 - val_loss: 0.1145 - val_accuracy: 0.9628 - lr: 0.0010 - 11s/epoch - 567ms/step
# Epoch 50/150
#
# Epoch 50: val_loss did not improve from 0.11440
# 20/20 - 11s - loss: 0.3107 - accuracy: 0.8776 - val_loss: 0.1165 - val_accuracy: 0.9579 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 51/150
#
# Epoch 51: val_loss improved from 0.11440 to 0.10816, saving model to model.h5
# 20/20 - 12s - loss: 0.3084 - accuracy: 0.8804 - val_loss: 0.1082 - val_accuracy: 0.9620 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 52/150
#
# Epoch 52: val_loss did not improve from 0.10816
# 20/20 - 11s - loss: 0.2981 - accuracy: 0.8905 - val_loss: 0.1094 - val_accuracy: 0.9706 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 53/150
#
# Epoch 53: val_loss did not improve from 0.10816
# 20/20 - 11s - loss: 0.2944 - accuracy: 0.8788 - val_loss: 0.1097 - val_accuracy: 0.9617 - lr: 0.0010 - 11s/epoch - 564ms/step
# Epoch 54/150
#
# Epoch 54: val_loss improved from 0.10816 to 0.10378, saving model to model.h5
# 20/20 - 12s - loss: 0.2996 - accuracy: 0.8757 - val_loss: 0.1038 - val_accuracy: 0.9650 - lr: 0.0010 - 12s/epoch - 609ms/step
# Epoch 55/150
#
# Epoch 55: val_loss did not improve from 0.10378
# 20/20 - 11s - loss: 0.3026 - accuracy: 0.8780 - val_loss: 0.1103 - val_accuracy: 0.9594 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 56/150
#
# Epoch 56: val_loss improved from 0.10378 to 0.09324, saving model to model.h5
# 20/20 - 12s - loss: 0.2780 - accuracy: 0.8913 - val_loss: 0.0932 - val_accuracy: 0.9743 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 57/150
#
# Epoch 57: val_loss did not improve from 0.09324
# 20/20 - 11s - loss: 0.2912 - accuracy: 0.8858 - val_loss: 0.1010 - val_accuracy: 0.9643 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 58/150
#
# Epoch 58: val_loss did not improve from 0.09324
# 20/20 - 11s - loss: 0.3018 - accuracy: 0.8839 - val_loss: 0.1041 - val_accuracy: 0.9639 - lr: 0.0010 - 11s/epoch - 561ms/step
# Epoch 59/150
#
# Epoch 59: val_loss did not improve from 0.09324
# 20/20 - 11s - loss: 0.2894 - accuracy: 0.8831 - val_loss: 0.0949 - val_accuracy: 0.9754 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 60/150
#
# Epoch 60: val_loss did not improve from 0.09324
# 20/20 - 11s - loss: 0.2752 - accuracy: 0.9011 - val_loss: 0.0976 - val_accuracy: 0.9624 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 61/150
#
# Epoch 61: val_loss improved from 0.09324 to 0.08973, saving model to model.h5
# 20/20 - 12s - loss: 0.2678 - accuracy: 0.8948 - val_loss: 0.0897 - val_accuracy: 0.9654 - lr: 0.0010 - 12s/epoch - 608ms/step
# Epoch 62/150
#
# Epoch 62: val_loss improved from 0.08973 to 0.07885, saving model to model.h5
# 20/20 - 12s - loss: 0.2612 - accuracy: 0.8937 - val_loss: 0.0788 - val_accuracy: 0.9754 - lr: 0.0010 - 12s/epoch - 609ms/step
# Epoch 63/150
#
# Epoch 63: val_loss improved from 0.07885 to 0.07602, saving model to model.h5
# 20/20 - 12s - loss: 0.2540 - accuracy: 0.8991 - val_loss: 0.0760 - val_accuracy: 0.9780 - lr: 0.0010 - 12s/epoch - 614ms/step
# Epoch 64/150
#
# Epoch 64: val_loss improved from 0.07602 to 0.07466, saving model to model.h5
# 20/20 - 12s - loss: 0.2691 - accuracy: 0.9027 - val_loss: 0.0747 - val_accuracy: 0.9758 - lr: 0.0010 - 12s/epoch - 614ms/step
# Epoch 65/150
#
# Epoch 65: val_loss did not improve from 0.07466
# 20/20 - 11s - loss: 0.2754 - accuracy: 0.8901 - val_loss: 0.0851 - val_accuracy: 0.9732 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 66/150
#
# Epoch 66: val_loss improved from 0.07466 to 0.07379, saving model to model.h5
# 20/20 - 12s - loss: 0.2629 - accuracy: 0.9011 - val_loss: 0.0738 - val_accuracy: 0.9769 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 67/150
#
# Epoch 67: val_loss did not improve from 0.07379
# 20/20 - 11s - loss: 0.2669 - accuracy: 0.8991 - val_loss: 0.0786 - val_accuracy: 0.9754 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 68/150
#
# Epoch 68: val_loss did not improve from 0.07379
# 20/20 - 11s - loss: 0.2676 - accuracy: 0.8925 - val_loss: 0.0769 - val_accuracy: 0.9777 - lr: 0.0010 - 11s/epoch - 565ms/step
# Epoch 69/150
#
# Epoch 69: val_loss improved from 0.07379 to 0.07022, saving model to model.h5
# 20/20 - 12s - loss: 0.2570 - accuracy: 0.9015 - val_loss: 0.0702 - val_accuracy: 0.9762 - lr: 0.0010 - 12s/epoch - 614ms/step
# Epoch 70/150
#
# Epoch 70: val_loss improved from 0.07022 to 0.06471, saving model to model.h5
# 20/20 - 12s - loss: 0.2445 - accuracy: 0.9054 - val_loss: 0.0647 - val_accuracy: 0.9825 - lr: 0.0010 - 12s/epoch - 607ms/step
# Epoch 71/150
#
# Epoch 71: val_loss did not improve from 0.06471
# 20/20 - 11s - loss: 0.2462 - accuracy: 0.9054 - val_loss: 0.0722 - val_accuracy: 0.9724 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 72/150
#
# Epoch 72: val_loss improved from 0.06471 to 0.06248, saving model to model.h5
# 20/20 - 12s - loss: 0.2610 - accuracy: 0.9015 - val_loss: 0.0625 - val_accuracy: 0.9840 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 73/150
#
# Epoch 73: val_loss did not improve from 0.06248
# 20/20 - 11s - loss: 0.2387 - accuracy: 0.9105 - val_loss: 0.0769 - val_accuracy: 0.9769 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 74/150
#
# Epoch 74: val_loss did not improve from 0.06248
# 20/20 - 11s - loss: 0.2445 - accuracy: 0.9034 - val_loss: 0.0679 - val_accuracy: 0.9821 - lr: 0.0010 - 11s/epoch - 565ms/step
# Epoch 75/150
#
# Epoch 75: val_loss did not improve from 0.06248
# 20/20 - 11s - loss: 0.2367 - accuracy: 0.9062 - val_loss: 0.0657 - val_accuracy: 0.9832 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 76/150
#
# Epoch 76: val_loss did not improve from 0.06248
# 20/20 - 11s - loss: 0.2429 - accuracy: 0.9046 - val_loss: 0.0759 - val_accuracy: 0.9724 - lr: 0.0010 - 11s/epoch - 564ms/step
# Epoch 77/150
#
# Epoch 77: val_loss did not improve from 0.06248
# 20/20 - 11s - loss: 0.2490 - accuracy: 0.9011 - val_loss: 0.0857 - val_accuracy: 0.9717 - lr: 0.0010 - 11s/epoch - 558ms/step
# Epoch 78/150
#
# Epoch 78: val_loss did not improve from 0.06248
# 20/20 - 11s - loss: 0.2297 - accuracy: 0.9085 - val_loss: 0.0673 - val_accuracy: 0.9851 - lr: 0.0010 - 11s/epoch - 557ms/step
# Epoch 79/150
#
# Epoch 79: val_loss improved from 0.06248 to 0.05804, saving model to model.h5
# 20/20 - 12s - loss: 0.2150 - accuracy: 0.9195 - val_loss: 0.0580 - val_accuracy: 0.9870 - lr: 0.0010 - 12s/epoch - 612ms/step
# Epoch 80/150
#
# Epoch 80: val_loss did not improve from 0.05804
# 20/20 - 11s - loss: 0.2269 - accuracy: 0.9093 - val_loss: 0.0618 - val_accuracy: 0.9825 - lr: 0.0010 - 11s/epoch - 568ms/step
# Epoch 81/150
#
# Epoch 81: val_loss did not improve from 0.05804
# 20/20 - 11s - loss: 0.2420 - accuracy: 0.9046 - val_loss: 0.0603 - val_accuracy: 0.9840 - lr: 0.0010 - 11s/epoch - 566ms/step
# Epoch 82/150
#
# Epoch 82: val_loss did not improve from 0.05804
# 20/20 - 11s - loss: 0.2348 - accuracy: 0.9070 - val_loss: 0.0651 - val_accuracy: 0.9832 - lr: 0.0010 - 11s/epoch - 569ms/step
# Epoch 83/150
#
# Epoch 83: val_loss improved from 0.05804 to 0.05442, saving model to model.h5
# 20/20 - 12s - loss: 0.2421 - accuracy: 0.9120 - val_loss: 0.0544 - val_accuracy: 0.9885 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 84/150
#
# Epoch 84: val_loss did not improve from 0.05442
# 20/20 - 11s - loss: 0.2437 - accuracy: 0.9003 - val_loss: 0.0548 - val_accuracy: 0.9877 - lr: 0.0010 - 11s/epoch - 559ms/step
# Epoch 85/150
#
# Epoch 85: val_loss improved from 0.05442 to 0.05408, saving model to model.h5
# 20/20 - 12s - loss: 0.2085 - accuracy: 0.9183 - val_loss: 0.0541 - val_accuracy: 0.9866 - lr: 0.0010 - 12s/epoch - 606ms/step
# Epoch 86/150
#
# Epoch 86: val_loss did not improve from 0.05408
# 20/20 - 11s - loss: 0.2069 - accuracy: 0.9144 - val_loss: 0.0551 - val_accuracy: 0.9855 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 87/150
#
# Epoch 87: val_loss improved from 0.05408 to 0.04762, saving model to model.h5
# 20/20 - 12s - loss: 0.2243 - accuracy: 0.9089 - val_loss: 0.0476 - val_accuracy: 0.9888 - lr: 0.0010 - 12s/epoch - 602ms/step
# Epoch 88/150
#
# Epoch 88: val_loss did not improve from 0.04762
# 20/20 - 11s - loss: 0.2172 - accuracy: 0.9163 - val_loss: 0.0478 - val_accuracy: 0.9888 - lr: 0.0010 - 11s/epoch - 559ms/step
# Epoch 89/150
#
# Epoch 89: val_loss did not improve from 0.04762
# 20/20 - 11s - loss: 0.2048 - accuracy: 0.9214 - val_loss: 0.0506 - val_accuracy: 0.9847 - lr: 0.0010 - 11s/epoch - 557ms/step
# Epoch 90/150
#
# Epoch 90: val_loss did not improve from 0.04762
# 20/20 - 11s - loss: 0.2183 - accuracy: 0.9132 - val_loss: 0.0487 - val_accuracy: 0.9851 - lr: 0.0010 - 11s/epoch - 555ms/step
# Epoch 91/150
#
# Epoch 91: val_loss did not improve from 0.04762
# 20/20 - 11s - loss: 0.2127 - accuracy: 0.9148 - val_loss: 0.0561 - val_accuracy: 0.9825 - lr: 0.0010 - 11s/epoch - 557ms/step
# Epoch 92/150
#
# Epoch 92: val_loss did not improve from 0.04762
# 20/20 - 11s - loss: 0.2269 - accuracy: 0.9074 - val_loss: 0.0693 - val_accuracy: 0.9743 - lr: 0.0010 - 11s/epoch - 559ms/step
# Epoch 93/150
#
# Epoch 93: val_loss did not improve from 0.04762
# 20/20 - 11s - loss: 0.2010 - accuracy: 0.9226 - val_loss: 0.0523 - val_accuracy: 0.9836 - lr: 0.0010 - 11s/epoch - 552ms/step
# Epoch 94/150
#
# Epoch 94: val_loss did not improve from 0.04762
# 20/20 - 11s - loss: 0.2093 - accuracy: 0.9159 - val_loss: 0.0516 - val_accuracy: 0.9866 - lr: 0.0010 - 11s/epoch - 558ms/step
# Epoch 95/150
#
# Epoch 95: val_loss did not improve from 0.04762
# 20/20 - 11s - loss: 0.2070 - accuracy: 0.9163 - val_loss: 0.0485 - val_accuracy: 0.9862 - lr: 0.0010 - 11s/epoch - 559ms/step
# Epoch 96/150
#
# Epoch 96: val_loss improved from 0.04762 to 0.04283, saving model to model.h5
# 20/20 - 12s - loss: 0.1962 - accuracy: 0.9285 - val_loss: 0.0428 - val_accuracy: 0.9892 - lr: 0.0010 - 12s/epoch - 606ms/step
# Epoch 97/150
#
# Epoch 97: val_loss did not improve from 0.04283
# 20/20 - 11s - loss: 0.2106 - accuracy: 0.9175 - val_loss: 0.0431 - val_accuracy: 0.9896 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 98/150
#
# Epoch 98: val_loss did not improve from 0.04283
# 20/20 - 11s - loss: 0.1943 - accuracy: 0.9249 - val_loss: 0.0514 - val_accuracy: 0.9870 - lr: 0.0010 - 11s/epoch - 556ms/step
# Epoch 99/150
#
# Epoch 99: val_loss did not improve from 0.04283
# 20/20 - 11s - loss: 0.1989 - accuracy: 0.9249 - val_loss: 0.0528 - val_accuracy: 0.9829 - lr: 0.0010 - 11s/epoch - 558ms/step
# Epoch 100/150
#
# Epoch 100: val_loss did not improve from 0.04283
# 20/20 - 11s - loss: 0.2033 - accuracy: 0.9222 - val_loss: 0.0495 - val_accuracy: 0.9881 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 101/150
#
# Epoch 101: val_loss improved from 0.04283 to 0.04262, saving model to model.h5
# 20/20 - 12s - loss: 0.1908 - accuracy: 0.9289 - val_loss: 0.0426 - val_accuracy: 0.9892 - lr: 0.0010 - 12s/epoch - 605ms/step
# Epoch 102/150
#
# Epoch 102: val_loss improved from 0.04262 to 0.04171, saving model to model.h5
# 20/20 - 12s - loss: 0.1994 - accuracy: 0.9222 - val_loss: 0.0417 - val_accuracy: 0.9903 - lr: 0.0010 - 12s/epoch - 604ms/step
# Epoch 103/150
#
# Epoch 103: val_loss improved from 0.04171 to 0.04038, saving model to model.h5
# 20/20 - 12s - loss: 0.1968 - accuracy: 0.9273 - val_loss: 0.0404 - val_accuracy: 0.9911 - lr: 0.0010 - 12s/epoch - 615ms/step
# Epoch 104/150
#
# Epoch 104: val_loss did not improve from 0.04038
# 20/20 - 11s - loss: 0.1828 - accuracy: 0.9352 - val_loss: 0.0419 - val_accuracy: 0.9862 - lr: 0.0010 - 11s/epoch - 558ms/step
# Epoch 105/150
#
# Epoch 105: val_loss did not improve from 0.04038
# 20/20 - 11s - loss: 0.1896 - accuracy: 0.9242 - val_loss: 0.0405 - val_accuracy: 0.9888 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 106/150
#
# Epoch 106: val_loss improved from 0.04038 to 0.03838, saving model to model.h5
# 20/20 - 12s - loss: 0.1929 - accuracy: 0.9316 - val_loss: 0.0384 - val_accuracy: 0.9907 - lr: 0.0010 - 12s/epoch - 605ms/step
# Epoch 107/150
#
# Epoch 107: val_loss improved from 0.03838 to 0.03291, saving model to model.h5
# 20/20 - 12s - loss: 0.1843 - accuracy: 0.9296 - val_loss: 0.0329 - val_accuracy: 0.9929 - lr: 0.0010 - 12s/epoch - 604ms/step
# Epoch 108/150
#
# Epoch 108: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1682 - accuracy: 0.9351 - val_loss: 0.0412 - val_accuracy: 0.9885 - lr: 0.0010 - 11s/epoch - 564ms/step
# Epoch 109/150
#
# Epoch 109: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1842 - accuracy: 0.9324 - val_loss: 0.0369 - val_accuracy: 0.9918 - lr: 0.0010 - 11s/epoch - 554ms/step
# Epoch 110/150
#
# Epoch 110: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1931 - accuracy: 0.9281 - val_loss: 0.0397 - val_accuracy: 0.9899 - lr: 0.0010 - 11s/epoch - 558ms/step
# Epoch 111/150
#
# Epoch 111: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1879 - accuracy: 0.9261 - val_loss: 0.0430 - val_accuracy: 0.9866 - lr: 0.0010 - 11s/epoch - 558ms/step
# Epoch 112/150
#
# Epoch 112: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1829 - accuracy: 0.9277 - val_loss: 0.0363 - val_accuracy: 0.9926 - lr: 0.0010 - 11s/epoch - 561ms/step
# Epoch 113/150
#
# Epoch 113: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1814 - accuracy: 0.9312 - val_loss: 0.0331 - val_accuracy: 0.9922 - lr: 0.0010 - 11s/epoch - 556ms/step
# Epoch 114/150
#
# Epoch 114: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1875 - accuracy: 0.9249 - val_loss: 0.0340 - val_accuracy: 0.9929 - lr: 0.0010 - 11s/epoch - 552ms/step
# Epoch 115/150
#
# Epoch 115: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1747 - accuracy: 0.9308 - val_loss: 0.0372 - val_accuracy: 0.9896 - lr: 0.0010 - 11s/epoch - 556ms/step
# Epoch 116/150
#
# Epoch 116: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1544 - accuracy: 0.9394 - val_loss: 0.0338 - val_accuracy: 0.9914 - lr: 0.0010 - 11s/epoch - 556ms/step
# Epoch 117/150
#
# Epoch 117: val_loss did not improve from 0.03291
# 20/20 - 11s - loss: 0.1738 - accuracy: 0.9332 - val_loss: 0.0333 - val_accuracy: 0.9929 - lr: 0.0010 - 11s/epoch - 556ms/step
# Epoch 118/150
#
# Epoch 118: val_loss improved from 0.03291 to 0.03274, saving model to model.h5
# 20/20 - 12s - loss: 0.1853 - accuracy: 0.9320 - val_loss: 0.0327 - val_accuracy: 0.9907 - lr: 0.0010 - 12s/epoch - 605ms/step
# Epoch 119/150
#
# Epoch 119: val_loss improved from 0.03274 to 0.03262, saving model to model.h5
# 20/20 - 12s - loss: 0.1530 - accuracy: 0.9437 - val_loss: 0.0326 - val_accuracy: 0.9937 - lr: 0.0010 - 12s/epoch - 598ms/step
# Epoch 120/150
#
# Epoch 120: val_loss improved from 0.03262 to 0.02985, saving model to model.h5
# 20/20 - 12s - loss: 0.1591 - accuracy: 0.9433 - val_loss: 0.0298 - val_accuracy: 0.9937 - lr: 0.0010 - 12s/epoch - 604ms/step
# Epoch 121/150
#
# Epoch 121: val_loss did not improve from 0.02985
# 20/20 - 11s - loss: 0.1655 - accuracy: 0.9312 - val_loss: 0.0305 - val_accuracy: 0.9903 - lr: 0.0010 - 11s/epoch - 554ms/step
# Epoch 122/150
#
# Epoch 122: val_loss improved from 0.02985 to 0.02765, saving model to model.h5
# 20/20 - 12s - loss: 0.1559 - accuracy: 0.9414 - val_loss: 0.0277 - val_accuracy: 0.9948 - lr: 0.0010 - 12s/epoch - 607ms/step
# Epoch 123/150
#
# Epoch 123: val_loss did not improve from 0.02765
# 20/20 - 11s - loss: 0.1590 - accuracy: 0.9355 - val_loss: 0.0311 - val_accuracy: 0.9911 - lr: 0.0010 - 11s/epoch - 554ms/step
# Epoch 124/150
#
# Epoch 124: val_loss did not improve from 0.02765
# 20/20 - 11s - loss: 0.1697 - accuracy: 0.9335 - val_loss: 0.0285 - val_accuracy: 0.9918 - lr: 0.0010 - 11s/epoch - 553ms/step
# Epoch 125/150
#
# Epoch 125: val_loss improved from 0.02765 to 0.02622, saving model to model.h5
# 20/20 - 12s - loss: 0.1529 - accuracy: 0.9464 - val_loss: 0.0262 - val_accuracy: 0.9940 - lr: 0.0010 - 12s/epoch - 604ms/step
# Epoch 126/150
#
# Epoch 126: val_loss improved from 0.02622 to 0.02580, saving model to model.h5
# 20/20 - 12s - loss: 0.1663 - accuracy: 0.9355 - val_loss: 0.0258 - val_accuracy: 0.9944 - lr: 0.0010 - 12s/epoch - 606ms/step
# Epoch 127/150
#
# Epoch 127: val_loss did not improve from 0.02580
# 20/20 - 11s - loss: 0.1463 - accuracy: 0.9484 - val_loss: 0.0279 - val_accuracy: 0.9926 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 128/150
#
# Epoch 128: val_loss improved from 0.02580 to 0.02465, saving model to model.h5
# 20/20 - 12s - loss: 0.1807 - accuracy: 0.9371 - val_loss: 0.0247 - val_accuracy: 0.9952 - lr: 0.0010 - 12s/epoch - 604ms/step
# Epoch 129/150
#
# Epoch 129: val_loss did not improve from 0.02465
# 20/20 - 11s - loss: 0.1641 - accuracy: 0.9386 - val_loss: 0.0250 - val_accuracy: 0.9944 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 130/150
#
# Epoch 130: val_loss did not improve from 0.02465
# 20/20 - 11s - loss: 0.1586 - accuracy: 0.9437 - val_loss: 0.0299 - val_accuracy: 0.9914 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 131/150
#
# Epoch 131: val_loss did not improve from 0.02465
# 20/20 - 11s - loss: 0.1742 - accuracy: 0.9371 - val_loss: 0.0298 - val_accuracy: 0.9922 - lr: 0.0010 - 11s/epoch - 559ms/step
# Epoch 132/150
#
# Epoch 132: val_loss did not improve from 0.02465
# 20/20 - 11s - loss: 0.1506 - accuracy: 0.9425 - val_loss: 0.0298 - val_accuracy: 0.9907 - lr: 0.0010 - 11s/epoch - 562ms/step
# Epoch 133/150
#
# Epoch 133: val_loss improved from 0.02465 to 0.02236, saving model to model.h5
# 20/20 - 12s - loss: 0.1632 - accuracy: 0.9386 - val_loss: 0.0224 - val_accuracy: 0.9959 - lr: 0.0010 - 12s/epoch - 605ms/step
# Epoch 134/150
#
# Epoch 134: val_loss did not improve from 0.02236
# 20/20 - 11s - loss: 0.1485 - accuracy: 0.9488 - val_loss: 0.0246 - val_accuracy: 0.9944 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 135/150
#
# Epoch 135: val_loss did not improve from 0.02236
# 20/20 - 11s - loss: 0.1385 - accuracy: 0.9511 - val_loss: 0.0226 - val_accuracy: 0.9959 - lr: 0.0010 - 11s/epoch - 558ms/step
# Epoch 136/150
#
# Epoch 136: val_loss improved from 0.02236 to 0.02116, saving model to model.h5
# 20/20 - 12s - loss: 0.1504 - accuracy: 0.9429 - val_loss: 0.0212 - val_accuracy: 0.9944 - lr: 0.0010 - 12s/epoch - 605ms/step
# Epoch 137/150
#
# Epoch 137: val_loss improved from 0.02116 to 0.01986, saving model to model.h5
# 20/20 - 12s - loss: 0.1342 - accuracy: 0.9480 - val_loss: 0.0199 - val_accuracy: 0.9959 - lr: 0.0010 - 12s/epoch - 610ms/step
# Epoch 138/150
#
# Epoch 138: val_loss did not improve from 0.01986
# 20/20 - 11s - loss: 0.1622 - accuracy: 0.9414 - val_loss: 0.0247 - val_accuracy: 0.9911 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 139/150
#
# Epoch 139: val_loss did not improve from 0.01986
# 20/20 - 11s - loss: 0.1423 - accuracy: 0.9429 - val_loss: 0.0250 - val_accuracy: 0.9933 - lr: 0.0010 - 11s/epoch - 559ms/step
# Epoch 140/150
#
# Epoch 140: val_loss did not improve from 0.01986
# 20/20 - 11s - loss: 0.1316 - accuracy: 0.9492 - val_loss: 0.0219 - val_accuracy: 0.9944 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 141/150
#
# Epoch 141: val_loss did not improve from 0.01986
# 20/20 - 11s - loss: 0.1465 - accuracy: 0.9429 - val_loss: 0.0215 - val_accuracy: 0.9955 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 142/150
#
# Epoch 142: val_loss did not improve from 0.01986
# 20/20 - 11s - loss: 0.1532 - accuracy: 0.9386 - val_loss: 0.0199 - val_accuracy: 0.9966 - lr: 0.0010 - 11s/epoch - 559ms/step
# Epoch 143/150
#
# Epoch 143: val_loss did not improve from 0.01986
# 20/20 - 11s - loss: 0.1563 - accuracy: 0.9406 - val_loss: 0.0238 - val_accuracy: 0.9948 - lr: 0.0010 - 11s/epoch - 563ms/step
# Epoch 144/150
#
# Epoch 144: val_loss did not improve from 0.01986
# 20/20 - 11s - loss: 0.1331 - accuracy: 0.9476 - val_loss: 0.0207 - val_accuracy: 0.9963 - lr: 0.0010 - 11s/epoch - 560ms/step
# Epoch 145/150
#
# Epoch 145: val_loss improved from 0.01986 to 0.01920, saving model to model.h5
# 20/20 - 12s - loss: 0.1393 - accuracy: 0.9484 - val_loss: 0.0192 - val_accuracy: 0.9974 - lr: 0.0010 - 12s/epoch - 607ms/step
# Epoch 146/150
#
# Epoch 146: val_loss improved from 0.01920 to 0.01870, saving model to model.h5
# 20/20 - 12s - loss: 0.1460 - accuracy: 0.9468 - val_loss: 0.0187 - val_accuracy: 0.9978 - lr: 0.0010 - 12s/epoch - 611ms/step
# Epoch 147/150
#
# Epoch 147: val_loss improved from 0.01870 to 0.01767, saving model to model.h5
# 20/20 - 12s - loss: 0.1288 - accuracy: 0.9507 - val_loss: 0.0177 - val_accuracy: 0.9959 - lr: 0.0010 - 12s/epoch - 608ms/step
# Epoch 148/150
#
# Epoch 148: val_loss improved from 0.01767 to 0.01538, saving model to model.h5
# 20/20 - 12s - loss: 0.1579 - accuracy: 0.9394 - val_loss: 0.0154 - val_accuracy: 0.9966 - lr: 0.0010 - 12s/epoch - 609ms/step
# Epoch 149/150
#
# Epoch 149: val_loss did not improve from 0.01538
# 20/20 - 11s - loss: 0.1350 - accuracy: 0.9492 - val_loss: 0.0181 - val_accuracy: 0.9948 - lr: 0.0010 - 11s/epoch - 561ms/step
# Epoch 150/150
#
# Epoch 150: val_loss did not improve from 0.01538
# 20/20 - 11s - loss: 0.1365 - accuracy: 0.9468 - val_loss: 0.0183 - val_accuracy: 0.9955 - lr: 0.0010 - 11s/epoch - 560ms/step

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper left')
plt.show()

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper right')
plt.show()

# %%
model.save('/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/ML_Models/DenseNet_150_epoch/DenseNet121/Case_5_Right_CC/model.h5')

# %%
ypred = model.predict(xtest)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(ypred)):
    if np.argmax(ypred[i]) == np.argmax(ytest[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Total-test-data; 672 	accurately-predicted-data: 629 	 wrongly-predicted-data:  43
# Accuracy: 93.601 %

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(accurateindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(wrongindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
Ypred = model.predict(xtest)

Ypred = np.argmax(Ypred, axis=1)
Ytrue = np.argmax(ytest, axis=1)

cm = confusion_matrix(Ytrue, Ypred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')
