# %%
import tensorflow 

import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import models

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("Tensorflow-version:", tensorflow.__version__)
# Out:
# Tensorflow-version: 2.8.0

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(8,activation='softmax')(x) #FC-layer
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# 29097984/29084464 [==============================] - 0s 0us/step

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(3,activation='softmax')(x) #FC-layer

# %%
model=Model(inputs=model_d.input,outputs=preds)
model.summary()

# %%
for layer in model.layers[:-8]:
    layer.trainable=False
    
for layer in model.layers[-8:]:
    layer.trainable=True

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()

# %%
data=[]
labels=[]
random.seed(42)
# imagePaths = sorted(list(os.listdir("/content/drive/MyDrive/Mini_DDSM_Upload")))
imagePaths = ['Benign','Cancer','Normal']
random.shuffle(imagePaths)
print(imagePaths)
# Out:
# ['Cancer', 'Benign', 'Normal']

# %%
for img in imagePaths:
    path=sorted(list(os.listdir("/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img)))
    for i in path:
      if("LEFT_CC" in i):
        #Considereing original and flipped image
        for flip in range(2):
          if(flip == 0):
            print("\n****************************************")
            print("Original")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            print(image_path)
            # print("Reading image")
            image = cv2.imread(image_path)
            
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResized Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            # print("Label - ",l)
            labels.append(l)
          else:
            print("\n\n")
            print("FLIPPED")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            # print("Image Path - ",image_path)
            # print("Reading image ",i)
            image = cv2.imread(image_path)
            # print("Flipping Image")
            image = cv2.flip(image,1)
            
            # print("\nResizing the flipped image")
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResizing Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            print("Label - ",l)
            labels.append(l)
        else:
          continue
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1091_A_0423_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1095_A_0424_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1099_A_0425_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1103_A_0426_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1107_A_0427_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1111_A_0431_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1115_A_0432_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1119_A_0433_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/111_A_0041_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1123_A_0434_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1127_A_0435_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1131_A_0436_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1135_A_0437_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1139_A_0438_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1143_A_0439_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1147_A_0440_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1151_A_0441_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1155_A_0442_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1159_A_0443_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/115_A_0042_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1163_A_0444_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1167_A_0445_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1171_A_0446_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1175_A_0447_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1179_A_0448_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1183_A_0449_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1187_A_0450_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1191_A_0451_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1195_A_0452_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1199_A_0453_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/119_A_0043_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/11_A_0005_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1203_A_0455_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1207_A_0456_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1211_A_0457_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1215_A_0462_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1219_A_0463_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1223_A_0464_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1227_A_0465_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1231_A_0466_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1235_A_0467_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1239_A_0468_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/123_A_0044_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1243_A_0469_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1247_A_0470_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1251_A_0471_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1255_A_0472_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1259_A_0473_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1263_A_0474_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1267_A_0475_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1271_A_0477_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1275_A_0478_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1279_A_0482_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/127_A_0045_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1283_A_0483_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1287_A_0484_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1291_A_0490_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1295_A_0491_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1299_A_0492_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1303_A_0493_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1307_A_0494_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1311_A_0495_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1315_A_0496_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1319_A_0497_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/131_A_0046_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1323_A_0498_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1327_A_0500_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1331_A_0501_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1335_A_0502_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1339_A_0503_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1343_A_0504_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1347_A_0505_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1351_A_0508_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1355_A_0509_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1359_A_0510_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/135_A_0048_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1363_A_0511_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1367_A_0512_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1371_A_0513_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1375_A_0514_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1379_A_0515_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1383_A_0516_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1387_A_0517_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1391_A_0518_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1395_A_0519_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1399_A_0521_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/139_A_0049_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1403_A_0522_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1407_A_0523_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1411_A_0524_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1415_A_0525_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1419_A_0526_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1423_A_0527_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1427_A_0528_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1431_A_0529_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1435_A_0531_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1439_A_0532_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/143_A_0050_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1443_A_0534_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1447_A_0539_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1451_A_0541_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1455_A_0542_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1459_A_0543_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1463_A_0565_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1467_A_0566_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1471_A_0567_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1475_A_0568_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1479_A_0569_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/147_A_0051_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1483_A_0570_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1487_A_0571_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1491_A_0572_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1495_A_0573_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1499_A_0574_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1503_A_0575_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1507_A_0576_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1511_A_0578_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1515_A_0580_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1519_A_0581_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/151_A_0052_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1523_A_0583_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1527_A_0584_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1531_A_0585_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1535_A_0586_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1539_A_0587_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1543_A_0588_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1547_A_0589_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1551_A_0591_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1555_A_0594_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1559_A_0595_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/155_A_0053_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1563_A_0596_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1567_A_0597_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1571_A_0598_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1575_A_0599_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1579_A_0600_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1583_A_0601_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1587_A_0602_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1591_A_0603_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1595_A_0604_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1599_A_0605_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/159_A_0055_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/15_A_0006_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1603_A_0606_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1607_A_0607_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1611_A_0608_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1615_A_0609_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1619_A_0610_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1623_A_0611_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1627_A_0613_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1631_A_0614_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1635_A_0615_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1639_A_0616_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/163_A_0056_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1643_A_0617_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1647_A_0618_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1651_A_0619_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1655_A_0620_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1659_A_0621_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1663_A_0623_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1667_A_0702_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1671_A_0703_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1675_A_0704_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1679_A_0705_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/167_A_0057_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1683_A_0706_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1687_A_0707_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1691_A_0708_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1695_A_0710_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1699_D_4500_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1703_D_4501_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1707_D_4502_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1711_D_4503_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1715_D_4505_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1719_D_4506_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/171_A_0058_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1723_D_4508_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1727_D_4509_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1731_D_4510_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1735_D_4511_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1739_D_4512_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1743_D_4513_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1747_D_4514_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1751_D_4515_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1755_D_4516_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1759_D_4517_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/175_A_0059_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1763_D_4518_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1767_D_4519_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1771_D_4520_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1775_D_4521_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1779_D_4522_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1783_D_4523_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1787_D_4524_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1791_D_4525_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1795_D_4526_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1799_D_4527_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/179_A_0061_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1803_D_4528_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1807_D_4529_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1811_D_4530_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1815_D_4532_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1819_D_4533_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1823_D_4534_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1827_D_4536_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1831_D_4537_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1835_D_4538_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1839_D_4539_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/183_A_0062_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1843_D_4540_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1847_D_4541_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1851_D_4542_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1855_D_4543_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1859_D_4544_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1863_D_4545_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1867_D_4546_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1871_D_4547_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1875_D_4551_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1879_D_4552_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/187_A_0063_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1883_D_4553_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1887_D_4555_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1891_D_4557_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1895_D_4558_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1899_D_4559_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1903_D_4560_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1907_D_4561_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1911_D_4562_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1915_D_4563_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1919_D_4565_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/191_A_0064_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1923_D_4566_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1927_D_4567_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1931_D_4570_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1935_D_4571_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1939_D_4572_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1943_D_4574_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1947_D_4575_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1951_D_4576_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1955_D_4577_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1959_D_4582_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/195_A_0067_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1963_D_4583_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1967_D_4584_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1971_D_4585_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1975_D_4587_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1979_D_4588_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1983_D_4589_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1987_D_4590_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1991_D_4591_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1995_D_4592_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1999_D_4593_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/199_A_0068_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/19_A_0009_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2027_D_4568_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2035_D_4578_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2039_D_4579_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/203_A_0069_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/207_A_0070_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/211_A_0071_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/215_A_0072_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/219_A_0073_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/223_A_0074_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/227_A_0075_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/231_A_0076_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/235_A_0077_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# ...
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/683_A_0264_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/687_A_0265_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/691_A_0266_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/695_A_0267_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/699_A_0268_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/703_A_0269_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/707_A_0270_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/711_A_0271_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/715_A_0272_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/719_A_0273_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/71_A_0027_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/723_A_0274_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/727_A_0275_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/731_A_0276_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/735_A_0277_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/739_A_0278_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/743_A_0279_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/747_A_0280_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/751_A_0282_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/755_A_0283_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/759_A_0284_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/75_A_0030_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/763_A_0285_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/767_A_0286_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/771_A_0287_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/775_A_0290_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/779_A_0292_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/783_A_0293_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/787_A_0294_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/791_A_0295_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/795_A_0296_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/799_A_0297_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/79_A_0031_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/7_A_0003_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/803_A_0298_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/807_A_0299_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/811_A_0302_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/815_A_0303_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/819_A_0304_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/823_A_0305_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/827_A_0306_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/831_A_0307_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/835_A_0309_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/839_A_0310_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/83_A_0032_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/843_A_0311_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/847_A_0312_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/851_A_0313_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/855_A_0314_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/859_A_0315_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/863_A_0317_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/867_A_0318_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/871_A_0319_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/875_A_0320_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/879_A_0321_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/87_A_0034_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/883_A_0322_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/887_A_0323_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/891_A_0325_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/895_A_0326_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/899_A_0327_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/903_A_0328_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/907_A_0330_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/911_A_0331_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/915_A_0333_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/919_A_0334_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/91_A_0035_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/923_A_0335_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/927_A_0336_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/931_A_0337_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/935_A_0338_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/939_A_0339_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/943_A_0341_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/947_A_0342_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/951_A_0343_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/955_A_0344_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/959_A_0345_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/95_A_0036_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/963_A_0347_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/967_A_0348_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/971_A_0349_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/975_A_0351_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/979_A_0352_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/983_A_0354_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/987_A_0355_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/991_A_0356_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/995_A_0357_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/999_A_0358_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/99_A_0037_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal

# %%
print("Length of dataset = ",len(labels))
# Out:
# Length of dataset =  6338

# %%
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
print(labels[0])
# Out:
# [0 1 0]

# %%
(xtrain,xtest,ytrain,ytest)=train_test_split(data,labels,test_size=0.2,random_state=42)
print(xtrain.shape, xtest.shape)
# Out:
# (5070, 128, 128, 3) (1268, 128, 128, 3)

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)


datagen.fit(xtrain)
# Fits-the-model
history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=128),
               steps_per_epoch=xtrain.shape[0] //128,
               epochs=150, #try 100
               verbose=2,
               callbacks=[anne, checkpoint],
               validation_data=(xtrain, ytrain))
# Out:
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 1.16157, saving model to model.h5
# 39/39 - 44s - loss: 1.4996 - accuracy: 0.4897 - val_loss: 1.1616 - val_accuracy: 0.4893 - lr: 0.0010 - 44s/epoch - 1s/step
# Epoch 2/150
#
# Epoch 2: val_loss improved from 1.16157 to 0.73791, saving model to model.h5
# 39/39 - 23s - loss: 1.0847 - accuracy: 0.5573 - val_loss: 0.7379 - val_accuracy: 0.6345 - lr: 0.0010 - 23s/epoch - 587ms/step
# Epoch 3/150
#
# Epoch 3: val_loss improved from 0.73791 to 0.69486, saving model to model.h5
# 39/39 - 23s - loss: 0.9504 - accuracy: 0.5773 - val_loss: 0.6949 - val_accuracy: 0.6767 - lr: 0.0010 - 23s/epoch - 587ms/step
# Epoch 4/150
#
# Epoch 4: val_loss improved from 0.69486 to 0.64750, saving model to model.h5
# 39/39 - 23s - loss: 0.8715 - accuracy: 0.5994 - val_loss: 0.6475 - val_accuracy: 0.7059 - lr: 0.0010 - 23s/epoch - 586ms/step
# Epoch 5/150
#
# Epoch 5: val_loss improved from 0.64750 to 0.62383, saving model to model.h5
# 39/39 - 23s - loss: 0.8183 - accuracy: 0.6188 - val_loss: 0.6238 - val_accuracy: 0.7351 - lr: 0.0010 - 23s/epoch - 588ms/step
# Epoch 6/150
#
# Epoch 6: val_loss improved from 0.62383 to 0.60074, saving model to model.h5
# 39/39 - 23s - loss: 0.7827 - accuracy: 0.6246 - val_loss: 0.6007 - val_accuracy: 0.7479 - lr: 0.0010 - 23s/epoch - 589ms/step
# Epoch 7/150
#
# Epoch 7: val_loss improved from 0.60074 to 0.57618, saving model to model.h5
# 39/39 - 23s - loss: 0.7325 - accuracy: 0.6540 - val_loss: 0.5762 - val_accuracy: 0.7684 - lr: 0.0010 - 23s/epoch - 591ms/step
# Epoch 8/150
#
# Epoch 8: val_loss improved from 0.57618 to 0.57023, saving model to model.h5
# 39/39 - 23s - loss: 0.7265 - accuracy: 0.6580 - val_loss: 0.5702 - val_accuracy: 0.7679 - lr: 0.0010 - 23s/epoch - 593ms/step
# Epoch 9/150
#
# Epoch 9: val_loss improved from 0.57023 to 0.56309, saving model to model.h5
# 39/39 - 23s - loss: 0.7032 - accuracy: 0.6692 - val_loss: 0.5631 - val_accuracy: 0.7840 - lr: 0.0010 - 23s/epoch - 588ms/step
# Epoch 10/150
#
# Epoch 10: val_loss improved from 0.56309 to 0.53304, saving model to model.h5
# 39/39 - 23s - loss: 0.7055 - accuracy: 0.6641 - val_loss: 0.5330 - val_accuracy: 0.7931 - lr: 0.0010 - 23s/epoch - 587ms/step
# Epoch 11/150
#
# Epoch 11: val_loss improved from 0.53304 to 0.52848, saving model to model.h5
# 39/39 - 23s - loss: 0.6860 - accuracy: 0.6819 - val_loss: 0.5285 - val_accuracy: 0.7974 - lr: 0.0010 - 23s/epoch - 588ms/step
# Epoch 12/150
#
# Epoch 12: val_loss improved from 0.52848 to 0.51910, saving model to model.h5
# 39/39 - 23s - loss: 0.6756 - accuracy: 0.6817 - val_loss: 0.5191 - val_accuracy: 0.7915 - lr: 0.0010 - 23s/epoch - 586ms/step
# Epoch 13/150
#
# Epoch 13: val_loss improved from 0.51910 to 0.49689, saving model to model.h5
# 39/39 - 23s - loss: 0.6531 - accuracy: 0.6983 - val_loss: 0.4969 - val_accuracy: 0.8065 - lr: 0.0010 - 23s/epoch - 587ms/step
# Epoch 14/150
#
# Epoch 14: val_loss improved from 0.49689 to 0.49029, saving model to model.h5
# 39/39 - 23s - loss: 0.6748 - accuracy: 0.6833 - val_loss: 0.4903 - val_accuracy: 0.7953 - lr: 0.0010 - 23s/epoch - 587ms/step
# Epoch 15/150
#
# Epoch 15: val_loss improved from 0.49029 to 0.48299, saving model to model.h5
# 39/39 - 23s - loss: 0.6457 - accuracy: 0.6912 - val_loss: 0.4830 - val_accuracy: 0.8061 - lr: 0.0010 - 23s/epoch - 581ms/step
# Epoch 16/150
#
# Epoch 16: val_loss did not improve from 0.48299
# 39/39 - 22s - loss: 0.6367 - accuracy: 0.7001 - val_loss: 0.4910 - val_accuracy: 0.7937 - lr: 0.0010 - 22s/epoch - 556ms/step
# Epoch 17/150
#
# Epoch 17: val_loss improved from 0.48299 to 0.46034, saving model to model.h5
# 39/39 - 23s - loss: 0.6276 - accuracy: 0.7135 - val_loss: 0.4603 - val_accuracy: 0.8189 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 18/150
#
# Epoch 18: val_loss improved from 0.46034 to 0.41766, saving model to model.h5
# 39/39 - 23s - loss: 0.6249 - accuracy: 0.7125 - val_loss: 0.4177 - val_accuracy: 0.8389 - lr: 0.0010 - 23s/epoch - 580ms/step
# Epoch 19/150
#
# Epoch 19: val_loss improved from 0.41766 to 0.40325, saving model to model.h5
# 39/39 - 23s - loss: 0.6208 - accuracy: 0.7165 - val_loss: 0.4032 - val_accuracy: 0.8493 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 20/150
#
# Epoch 20: val_loss did not improve from 0.40325
# 39/39 - 22s - loss: 0.6083 - accuracy: 0.7181 - val_loss: 0.4043 - val_accuracy: 0.8456 - lr: 0.0010 - 22s/epoch - 554ms/step
# Epoch 21/150
#
# Epoch 21: val_loss improved from 0.40325 to 0.40279, saving model to model.h5
# 39/39 - 23s - loss: 0.6021 - accuracy: 0.7191 - val_loss: 0.4028 - val_accuracy: 0.8416 - lr: 0.0010 - 23s/epoch - 577ms/step
# Epoch 22/150
#
# Epoch 22: val_loss improved from 0.40279 to 0.38910, saving model to model.h5
# 39/39 - 23s - loss: 0.5840 - accuracy: 0.7394 - val_loss: 0.3891 - val_accuracy: 0.8452 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 23/150
#
# Epoch 23: val_loss improved from 0.38910 to 0.38758, saving model to model.h5
# 39/39 - 23s - loss: 0.5822 - accuracy: 0.7404 - val_loss: 0.3876 - val_accuracy: 0.8505 - lr: 0.0010 - 23s/epoch - 580ms/step
# Epoch 24/150
#
# Epoch 24: val_loss improved from 0.38758 to 0.38071, saving model to model.h5
# 39/39 - 23s - loss: 0.5881 - accuracy: 0.7325 - val_loss: 0.3807 - val_accuracy: 0.8519 - lr: 0.0010 - 23s/epoch - 583ms/step
# Epoch 25/150
#
# Epoch 25: val_loss improved from 0.38071 to 0.36831, saving model to model.h5
# 39/39 - 23s - loss: 0.5802 - accuracy: 0.7450 - val_loss: 0.3683 - val_accuracy: 0.8525 - lr: 0.0010 - 23s/epoch - 584ms/step
# Epoch 26/150
#
# Epoch 26: val_loss did not improve from 0.36831
# 39/39 - 22s - loss: 0.5702 - accuracy: 0.7367 - val_loss: 0.3887 - val_accuracy: 0.8398 - lr: 0.0010 - 22s/epoch - 553ms/step
# Epoch 27/150
#
# Epoch 27: val_loss did not improve from 0.36831
# 39/39 - 22s - loss: 0.5726 - accuracy: 0.7465 - val_loss: 0.3841 - val_accuracy: 0.8481 - lr: 0.0010 - 22s/epoch - 554ms/step
# Epoch 28/150
#
# Epoch 28: val_loss did not improve from 0.36831
# 39/39 - 22s - loss: 0.5511 - accuracy: 0.7544 - val_loss: 0.3720 - val_accuracy: 0.8475 - lr: 0.0010 - 22s/epoch - 556ms/step
# Epoch 29/150
#
# Epoch 29: val_loss improved from 0.36831 to 0.33662, saving model to model.h5
# 39/39 - 23s - loss: 0.5792 - accuracy: 0.7339 - val_loss: 0.3366 - val_accuracy: 0.8773 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 30/150
#
# Epoch 30: val_loss improved from 0.33662 to 0.32789, saving model to model.h5
# 39/39 - 23s - loss: 0.5407 - accuracy: 0.7590 - val_loss: 0.3279 - val_accuracy: 0.8710 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 31/150
#
# Epoch 31: val_loss improved from 0.32789 to 0.32472, saving model to model.h5
# 39/39 - 23s - loss: 0.5309 - accuracy: 0.7590 - val_loss: 0.3247 - val_accuracy: 0.8712 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 32/150
#
# Epoch 32: val_loss did not improve from 0.32472
# 39/39 - 22s - loss: 0.5275 - accuracy: 0.7699 - val_loss: 0.3364 - val_accuracy: 0.8686 - lr: 0.0010 - 22s/epoch - 557ms/step
# Epoch 33/150
#
# Epoch 33: val_loss improved from 0.32472 to 0.31561, saving model to model.h5
# 39/39 - 23s - loss: 0.5196 - accuracy: 0.7720 - val_loss: 0.3156 - val_accuracy: 0.8874 - lr: 0.0010 - 23s/epoch - 586ms/step
# Epoch 34/150
#
# Epoch 34: val_loss improved from 0.31561 to 0.30613, saving model to model.h5
# 39/39 - 23s - loss: 0.5309 - accuracy: 0.7641 - val_loss: 0.3061 - val_accuracy: 0.8886 - lr: 0.0010 - 23s/epoch - 581ms/step
# Epoch 35/150
#
# Epoch 35: val_loss improved from 0.30613 to 0.30115, saving model to model.h5
# 39/39 - 23s - loss: 0.5254 - accuracy: 0.7707 - val_loss: 0.3012 - val_accuracy: 0.8892 - lr: 0.0010 - 23s/epoch - 580ms/step
# Epoch 36/150
#
# Epoch 36: val_loss improved from 0.30115 to 0.29786, saving model to model.h5
# 39/39 - 23s - loss: 0.5086 - accuracy: 0.7794 - val_loss: 0.2979 - val_accuracy: 0.8937 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 37/150
#
# Epoch 37: val_loss did not improve from 0.29786
# 39/39 - 22s - loss: 0.5153 - accuracy: 0.7772 - val_loss: 0.3035 - val_accuracy: 0.8880 - lr: 0.0010 - 22s/epoch - 555ms/step
# Epoch 38/150
#
# Epoch 38: val_loss improved from 0.29786 to 0.28014, saving model to model.h5
# 39/39 - 23s - loss: 0.5027 - accuracy: 0.7819 - val_loss: 0.2801 - val_accuracy: 0.9014 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 39/150
#
# Epoch 39: val_loss improved from 0.28014 to 0.27738, saving model to model.h5
# 39/39 - 23s - loss: 0.5185 - accuracy: 0.7744 - val_loss: 0.2774 - val_accuracy: 0.9053 - lr: 0.0010 - 23s/epoch - 584ms/step
# Epoch 40/150
#
# Epoch 40: val_loss improved from 0.27738 to 0.25919, saving model to model.h5
# 39/39 - 22s - loss: 0.4811 - accuracy: 0.7936 - val_loss: 0.2592 - val_accuracy: 0.9087 - lr: 0.0010 - 22s/epoch - 577ms/step
# Epoch 41/150
#
# Epoch 41: val_loss improved from 0.25919 to 0.25699, saving model to model.h5
# 39/39 - 22s - loss: 0.4927 - accuracy: 0.7853 - val_loss: 0.2570 - val_accuracy: 0.9107 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 42/150
#
# Epoch 42: val_loss improved from 0.25699 to 0.24442, saving model to model.h5
# 39/39 - 23s - loss: 0.4698 - accuracy: 0.7979 - val_loss: 0.2444 - val_accuracy: 0.9132 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 43/150
#
# Epoch 43: val_loss improved from 0.24442 to 0.23572, saving model to model.h5
# 39/39 - 23s - loss: 0.4788 - accuracy: 0.7960 - val_loss: 0.2357 - val_accuracy: 0.9254 - lr: 0.0010 - 23s/epoch - 577ms/step
# Epoch 44/150
#
# Epoch 44: val_loss did not improve from 0.23572
# 39/39 - 22s - loss: 0.4709 - accuracy: 0.7960 - val_loss: 0.2778 - val_accuracy: 0.8899 - lr: 0.0010 - 22s/epoch - 556ms/step
# Epoch 45/150
#
# Epoch 45: val_loss did not improve from 0.23572
# 39/39 - 22s - loss: 0.4525 - accuracy: 0.8088 - val_loss: 0.2596 - val_accuracy: 0.9081 - lr: 0.0010 - 22s/epoch - 555ms/step
# Epoch 46/150
#
# Epoch 46: val_loss improved from 0.23572 to 0.23277, saving model to model.h5
# 39/39 - 23s - loss: 0.4706 - accuracy: 0.8019 - val_loss: 0.2328 - val_accuracy: 0.9179 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 47/150
#
# Epoch 47: val_loss did not improve from 0.23277
# 39/39 - 22s - loss: 0.4550 - accuracy: 0.8076 - val_loss: 0.2339 - val_accuracy: 0.9203 - lr: 0.0010 - 22s/epoch - 552ms/step
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.23277 to 0.22222, saving model to model.h5
# 39/39 - 23s - loss: 0.4421 - accuracy: 0.8124 - val_loss: 0.2222 - val_accuracy: 0.9239 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 49/150
#
# Epoch 49: val_loss improved from 0.22222 to 0.20978, saving model to model.h5
# 39/39 - 22s - loss: 0.4202 - accuracy: 0.8238 - val_loss: 0.2098 - val_accuracy: 0.9274 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 50/150
#
# Epoch 50: val_loss did not improve from 0.20978
# 39/39 - 22s - loss: 0.4367 - accuracy: 0.8201 - val_loss: 0.2102 - val_accuracy: 0.9339 - lr: 0.0010 - 22s/epoch - 556ms/step
# Epoch 51/150
#
# Epoch 51: val_loss did not improve from 0.20978
# 39/39 - 22s - loss: 0.4259 - accuracy: 0.8177 - val_loss: 0.2267 - val_accuracy: 0.9199 - lr: 0.0010 - 22s/epoch - 554ms/step
# Epoch 52/150
#
# Epoch 52: val_loss improved from 0.20978 to 0.20536, saving model to model.h5
# 39/39 - 22s - loss: 0.4277 - accuracy: 0.8201 - val_loss: 0.2054 - val_accuracy: 0.9349 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 53/150
#
# Epoch 53: val_loss improved from 0.20536 to 0.19282, saving model to model.h5
# 39/39 - 23s - loss: 0.4205 - accuracy: 0.8157 - val_loss: 0.1928 - val_accuracy: 0.9438 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 54/150
#
# Epoch 54: val_loss improved from 0.19282 to 0.19010, saving model to model.h5
# 39/39 - 22s - loss: 0.4257 - accuracy: 0.8215 - val_loss: 0.1901 - val_accuracy: 0.9387 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 55/150
#
# Epoch 55: val_loss improved from 0.19010 to 0.18810, saving model to model.h5
# 39/39 - 22s - loss: 0.4214 - accuracy: 0.8217 - val_loss: 0.1881 - val_accuracy: 0.9414 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 56/150
#
# Epoch 56: val_loss improved from 0.18810 to 0.17271, saving model to model.h5
# 39/39 - 22s - loss: 0.4089 - accuracy: 0.8276 - val_loss: 0.1727 - val_accuracy: 0.9479 - lr: 0.0010 - 22s/epoch - 577ms/step
# Epoch 57/150
#
# Epoch 57: val_loss improved from 0.17271 to 0.17159, saving model to model.h5
# 39/39 - 23s - loss: 0.4106 - accuracy: 0.8357 - val_loss: 0.1716 - val_accuracy: 0.9495 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 58/150
#
# Epoch 58: val_loss improved from 0.17159 to 0.16748, saving model to model.h5
# 39/39 - 23s - loss: 0.4177 - accuracy: 0.8262 - val_loss: 0.1675 - val_accuracy: 0.9491 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 59/150
#
# Epoch 59: val_loss did not improve from 0.16748
# 39/39 - 21s - loss: 0.3920 - accuracy: 0.8424 - val_loss: 0.1770 - val_accuracy: 0.9424 - lr: 0.0010 - 21s/epoch - 551ms/step
# Epoch 60/150
#
# Epoch 60: val_loss did not improve from 0.16748
# 39/39 - 22s - loss: 0.3863 - accuracy: 0.8427 - val_loss: 0.1755 - val_accuracy: 0.9430 - lr: 0.0010 - 22s/epoch - 558ms/step
# Epoch 61/150
#
# Epoch 61: val_loss improved from 0.16748 to 0.15592, saving model to model.h5
# 39/39 - 22s - loss: 0.3826 - accuracy: 0.8448 - val_loss: 0.1559 - val_accuracy: 0.9489 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 62/150
#
# Epoch 62: val_loss did not improve from 0.15592
# 39/39 - 22s - loss: 0.3826 - accuracy: 0.8436 - val_loss: 0.1637 - val_accuracy: 0.9454 - lr: 0.0010 - 22s/epoch - 552ms/step
# Epoch 63/150
#
# Epoch 63: val_loss did not improve from 0.15592
# 39/39 - 22s - loss: 0.3948 - accuracy: 0.8365 - val_loss: 0.1615 - val_accuracy: 0.9519 - lr: 0.0010 - 22s/epoch - 551ms/step
# Epoch 64/150
#
# Epoch 64: val_loss improved from 0.15592 to 0.14077, saving model to model.h5
# 39/39 - 22s - loss: 0.3596 - accuracy: 0.8545 - val_loss: 0.1408 - val_accuracy: 0.9574 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 65/150
#
# Epoch 65: val_loss did not improve from 0.14077
# 39/39 - 22s - loss: 0.3513 - accuracy: 0.8608 - val_loss: 0.1541 - val_accuracy: 0.9517 - lr: 0.0010 - 22s/epoch - 552ms/step
# Epoch 66/150
#
# Epoch 66: val_loss did not improve from 0.14077
# 39/39 - 21s - loss: 0.3655 - accuracy: 0.8478 - val_loss: 0.1428 - val_accuracy: 0.9542 - lr: 0.0010 - 21s/epoch - 551ms/step
# Epoch 67/150
#
# Epoch 67: val_loss did not improve from 0.14077
# 39/39 - 22s - loss: 0.3539 - accuracy: 0.8543 - val_loss: 0.1489 - val_accuracy: 0.9507 - lr: 0.0010 - 22s/epoch - 552ms/step
# Epoch 68/150
#
# Epoch 68: val_loss did not improve from 0.14077
# 39/39 - 21s - loss: 0.3702 - accuracy: 0.8460 - val_loss: 0.1555 - val_accuracy: 0.9507 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 69/150
#
# Epoch 69: val_loss did not improve from 0.14077
# 39/39 - 21s - loss: 0.3657 - accuracy: 0.8549 - val_loss: 0.1510 - val_accuracy: 0.9548 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 70/150
#
# Epoch 70: val_loss improved from 0.14077 to 0.13649, saving model to model.h5
# 39/39 - 22s - loss: 0.3553 - accuracy: 0.8537 - val_loss: 0.1365 - val_accuracy: 0.9617 - lr: 0.0010 - 22s/epoch - 577ms/step
# Epoch 71/150
#
# Epoch 71: val_loss improved from 0.13649 to 0.13397, saving model to model.h5
# 39/39 - 22s - loss: 0.3398 - accuracy: 0.8640 - val_loss: 0.1340 - val_accuracy: 0.9586 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 72/150
#
# Epoch 72: val_loss improved from 0.13397 to 0.12682, saving model to model.h5
# 39/39 - 22s - loss: 0.3408 - accuracy: 0.8602 - val_loss: 0.1268 - val_accuracy: 0.9661 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 73/150
#
# Epoch 73: val_loss did not improve from 0.12682
# 39/39 - 22s - loss: 0.3442 - accuracy: 0.8545 - val_loss: 0.1284 - val_accuracy: 0.9651 - lr: 0.0010 - 22s/epoch - 551ms/step
# Epoch 74/150
#
# Epoch 74: val_loss improved from 0.12682 to 0.12647, saving model to model.h5
# 39/39 - 22s - loss: 0.3307 - accuracy: 0.8681 - val_loss: 0.1265 - val_accuracy: 0.9647 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 75/150
#
# Epoch 75: val_loss did not improve from 0.12647
# 39/39 - 22s - loss: 0.3451 - accuracy: 0.8582 - val_loss: 0.1274 - val_accuracy: 0.9629 - lr: 0.0010 - 22s/epoch - 552ms/step
# Epoch 76/150
#
# Epoch 76: val_loss improved from 0.12647 to 0.11821, saving model to model.h5
# 39/39 - 22s - loss: 0.3224 - accuracy: 0.8754 - val_loss: 0.1182 - val_accuracy: 0.9663 - lr: 0.0010 - 22s/epoch - 577ms/step
# Epoch 77/150
#
# Epoch 77: val_loss improved from 0.11821 to 0.11040, saving model to model.h5
# 39/39 - 22s - loss: 0.3340 - accuracy: 0.8630 - val_loss: 0.1104 - val_accuracy: 0.9716 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 78/150
#
# Epoch 78: val_loss improved from 0.11040 to 0.10952, saving model to model.h5
# 39/39 - 22s - loss: 0.3133 - accuracy: 0.8731 - val_loss: 0.1095 - val_accuracy: 0.9686 - lr: 0.0010 - 22s/epoch - 577ms/step
# Epoch 79/150
#
# Epoch 79: val_loss improved from 0.10952 to 0.10474, saving model to model.h5
# 39/39 - 23s - loss: 0.3205 - accuracy: 0.8723 - val_loss: 0.1047 - val_accuracy: 0.9710 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 80/150
#
# Epoch 80: val_loss improved from 0.10474 to 0.10367, saving model to model.h5
# 39/39 - 23s - loss: 0.3244 - accuracy: 0.8731 - val_loss: 0.1037 - val_accuracy: 0.9698 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 81/150
#
# Epoch 81: val_loss improved from 0.10367 to 0.10061, saving model to model.h5
# 39/39 - 22s - loss: 0.2996 - accuracy: 0.8808 - val_loss: 0.1006 - val_accuracy: 0.9710 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 82/150
#
# Epoch 82: val_loss improved from 0.10061 to 0.09614, saving model to model.h5
# 39/39 - 22s - loss: 0.3104 - accuracy: 0.8796 - val_loss: 0.0961 - val_accuracy: 0.9712 - lr: 0.0010 - 22s/epoch - 577ms/step
# Epoch 83/150
#
# Epoch 83: val_loss did not improve from 0.09614
# 39/39 - 22s - loss: 0.3100 - accuracy: 0.8749 - val_loss: 0.1000 - val_accuracy: 0.9702 - lr: 0.0010 - 22s/epoch - 553ms/step
# Epoch 84/150
#
# Epoch 84: val_loss did not improve from 0.09614
# 39/39 - 21s - loss: 0.3274 - accuracy: 0.8658 - val_loss: 0.1069 - val_accuracy: 0.9667 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 85/150
#
# Epoch 85: val_loss did not improve from 0.09614
# 39/39 - 22s - loss: 0.3079 - accuracy: 0.8762 - val_loss: 0.1007 - val_accuracy: 0.9696 - lr: 0.0010 - 22s/epoch - 552ms/step
# Epoch 86/150
#
# Epoch 86: val_loss did not improve from 0.09614
# 39/39 - 21s - loss: 0.3041 - accuracy: 0.8764 - val_loss: 0.1042 - val_accuracy: 0.9669 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 87/150
#
# Epoch 87: val_loss improved from 0.09614 to 0.09124, saving model to model.h5
# 39/39 - 22s - loss: 0.2914 - accuracy: 0.8855 - val_loss: 0.0912 - val_accuracy: 0.9738 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 88/150
#
# Epoch 88: val_loss did not improve from 0.09124
# 39/39 - 21s - loss: 0.3175 - accuracy: 0.8778 - val_loss: 0.0985 - val_accuracy: 0.9720 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 89/150
#
# Epoch 89: val_loss did not improve from 0.09124
# 39/39 - 21s - loss: 0.2843 - accuracy: 0.8903 - val_loss: 0.0940 - val_accuracy: 0.9726 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 90/150
#
# Epoch 90: val_loss did not improve from 0.09124
# 39/39 - 21s - loss: 0.2775 - accuracy: 0.8974 - val_loss: 0.0938 - val_accuracy: 0.9728 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 91/150
#
# Epoch 91: val_loss did not improve from 0.09124
# 39/39 - 21s - loss: 0.2901 - accuracy: 0.8889 - val_loss: 0.0931 - val_accuracy: 0.9742 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 92/150
#
# Epoch 92: val_loss did not improve from 0.09124
# 39/39 - 21s - loss: 0.3059 - accuracy: 0.8756 - val_loss: 0.0962 - val_accuracy: 0.9704 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 93/150
#
# Epoch 93: val_loss improved from 0.09124 to 0.08609, saving model to model.h5
# 39/39 - 22s - loss: 0.2931 - accuracy: 0.8875 - val_loss: 0.0861 - val_accuracy: 0.9746 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 94/150
#
# Epoch 94: val_loss improved from 0.08609 to 0.08180, saving model to model.h5
# 39/39 - 22s - loss: 0.2614 - accuracy: 0.8998 - val_loss: 0.0818 - val_accuracy: 0.9726 - lr: 0.0010 - 22s/epoch - 571ms/step
# Epoch 95/150
#
# Epoch 95: val_loss did not improve from 0.08180
# 39/39 - 21s - loss: 0.2774 - accuracy: 0.8893 - val_loss: 0.0882 - val_accuracy: 0.9728 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 96/150
#
# Epoch 96: val_loss improved from 0.08180 to 0.07703, saving model to model.h5
# 39/39 - 22s - loss: 0.2757 - accuracy: 0.8974 - val_loss: 0.0770 - val_accuracy: 0.9783 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 97/150
#
# Epoch 97: val_loss did not improve from 0.07703
# 39/39 - 21s - loss: 0.2714 - accuracy: 0.8980 - val_loss: 0.0819 - val_accuracy: 0.9763 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 98/150
#
# Epoch 98: val_loss did not improve from 0.07703
# 39/39 - 21s - loss: 0.2688 - accuracy: 0.8948 - val_loss: 0.0776 - val_accuracy: 0.9777 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 99/150
#
# Epoch 99: val_loss improved from 0.07703 to 0.07084, saving model to model.h5
# 39/39 - 22s - loss: 0.2898 - accuracy: 0.8869 - val_loss: 0.0708 - val_accuracy: 0.9821 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 100/150
#
# Epoch 100: val_loss did not improve from 0.07084
# 39/39 - 22s - loss: 0.2818 - accuracy: 0.8913 - val_loss: 0.0845 - val_accuracy: 0.9757 - lr: 0.0010 - 22s/epoch - 551ms/step
# Epoch 101/150
#
# Epoch 101: val_loss improved from 0.07084 to 0.07003, saving model to model.h5
# 39/39 - 22s - loss: 0.2611 - accuracy: 0.8928 - val_loss: 0.0700 - val_accuracy: 0.9819 - lr: 0.0010 - 22s/epoch - 571ms/step
# Epoch 102/150
#
# Epoch 102: val_loss did not improve from 0.07003
# 39/39 - 21s - loss: 0.2408 - accuracy: 0.9051 - val_loss: 0.0711 - val_accuracy: 0.9795 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 103/150
#
# Epoch 103: val_loss improved from 0.07003 to 0.06852, saving model to model.h5
# 39/39 - 22s - loss: 0.2673 - accuracy: 0.8964 - val_loss: 0.0685 - val_accuracy: 0.9781 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 104/150
#
# Epoch 104: val_loss improved from 0.06852 to 0.06436, saving model to model.h5
# 39/39 - 22s - loss: 0.2564 - accuracy: 0.8998 - val_loss: 0.0644 - val_accuracy: 0.9842 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 105/150
#
# Epoch 105: val_loss did not improve from 0.06436
# 39/39 - 22s - loss: 0.2650 - accuracy: 0.8954 - val_loss: 0.0683 - val_accuracy: 0.9830 - lr: 0.0010 - 22s/epoch - 553ms/step
# Epoch 106/150
#
# Epoch 106: val_loss did not improve from 0.06436
# 39/39 - 21s - loss: 0.2566 - accuracy: 0.8980 - val_loss: 0.0674 - val_accuracy: 0.9801 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 107/150
#
# Epoch 107: val_loss improved from 0.06436 to 0.06286, saving model to model.h5
# 39/39 - 22s - loss: 0.2583 - accuracy: 0.8968 - val_loss: 0.0629 - val_accuracy: 0.9846 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 108/150
#
# Epoch 108: val_loss did not improve from 0.06286
# 39/39 - 21s - loss: 0.2292 - accuracy: 0.9106 - val_loss: 0.0715 - val_accuracy: 0.9783 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 109/150
#
# Epoch 109: val_loss did not improve from 0.06286
# 39/39 - 21s - loss: 0.2516 - accuracy: 0.8998 - val_loss: 0.0668 - val_accuracy: 0.9799 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 110/150
#
# Epoch 110: val_loss improved from 0.06286 to 0.05897, saving model to model.h5
# 39/39 - 22s - loss: 0.2329 - accuracy: 0.9100 - val_loss: 0.0590 - val_accuracy: 0.9866 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 111/150
#
# Epoch 111: val_loss did not improve from 0.05897
# 39/39 - 21s - loss: 0.2422 - accuracy: 0.9067 - val_loss: 0.0659 - val_accuracy: 0.9805 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 112/150
#
# Epoch 112: val_loss did not improve from 0.05897
# 39/39 - 21s - loss: 0.2598 - accuracy: 0.9015 - val_loss: 0.0628 - val_accuracy: 0.9813 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 113/150
#
# Epoch 113: val_loss improved from 0.05897 to 0.05646, saving model to model.h5
# 39/39 - 22s - loss: 0.2605 - accuracy: 0.8984 - val_loss: 0.0565 - val_accuracy: 0.9844 - lr: 0.0010 - 22s/epoch - 571ms/step
# Epoch 114/150
#
# Epoch 114: val_loss did not improve from 0.05646
# 39/39 - 21s - loss: 0.2602 - accuracy: 0.9002 - val_loss: 0.0622 - val_accuracy: 0.9822 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 115/150
#
# Epoch 115: val_loss did not improve from 0.05646
# 39/39 - 22s - loss: 0.2357 - accuracy: 0.9075 - val_loss: 0.0623 - val_accuracy: 0.9838 - lr: 0.0010 - 22s/epoch - 552ms/step
# Epoch 116/150
#
# Epoch 116: val_loss improved from 0.05646 to 0.05489, saving model to model.h5
# 39/39 - 22s - loss: 0.2365 - accuracy: 0.9118 - val_loss: 0.0549 - val_accuracy: 0.9842 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 117/150
#
# Epoch 117: val_loss improved from 0.05489 to 0.05318, saving model to model.h5
# 39/39 - 22s - loss: 0.2318 - accuracy: 0.9146 - val_loss: 0.0532 - val_accuracy: 0.9874 - lr: 0.0010 - 22s/epoch - 567ms/step
# Epoch 118/150
#
# Epoch 118: val_loss did not improve from 0.05318
# 39/39 - 21s - loss: 0.2173 - accuracy: 0.9132 - val_loss: 0.0539 - val_accuracy: 0.9850 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 119/150
#
# Epoch 119: val_loss did not improve from 0.05318
# 39/39 - 21s - loss: 0.2315 - accuracy: 0.9118 - val_loss: 0.0562 - val_accuracy: 0.9824 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 120/150
#
# Epoch 120: val_loss improved from 0.05318 to 0.05183, saving model to model.h5
# 39/39 - 22s - loss: 0.2351 - accuracy: 0.9093 - val_loss: 0.0518 - val_accuracy: 0.9874 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 121/150
#
# Epoch 121: val_loss did not improve from 0.05183
# 39/39 - 21s - loss: 0.2244 - accuracy: 0.9136 - val_loss: 0.0541 - val_accuracy: 0.9832 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 122/150
#
# Epoch 122: val_loss did not improve from 0.05183
# 39/39 - 21s - loss: 0.2196 - accuracy: 0.9142 - val_loss: 0.0543 - val_accuracy: 0.9856 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 123/150
#
# Epoch 123: val_loss did not improve from 0.05183
# 39/39 - 21s - loss: 0.2246 - accuracy: 0.9138 - val_loss: 0.0578 - val_accuracy: 0.9824 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 124/150
#
# Epoch 124: val_loss did not improve from 0.05183
# 39/39 - 21s - loss: 0.2122 - accuracy: 0.9243 - val_loss: 0.0526 - val_accuracy: 0.9864 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 125/150
#
# Epoch 125: val_loss did not improve from 0.05183
# 39/39 - 21s - loss: 0.2267 - accuracy: 0.9104 - val_loss: 0.0526 - val_accuracy: 0.9854 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 126/150
#
# Epoch 126: val_loss improved from 0.05183 to 0.05093, saving model to model.h5
# 39/39 - 22s - loss: 0.2203 - accuracy: 0.9146 - val_loss: 0.0509 - val_accuracy: 0.9858 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 127/150
#
# Epoch 127: val_loss did not improve from 0.05093
# 39/39 - 21s - loss: 0.2032 - accuracy: 0.9233 - val_loss: 0.0557 - val_accuracy: 0.9813 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 128/150
#
# Epoch 128: val_loss improved from 0.05093 to 0.04274, saving model to model.h5
# 39/39 - 22s - loss: 0.2166 - accuracy: 0.9180 - val_loss: 0.0427 - val_accuracy: 0.9903 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 129/150
#
# Epoch 129: val_loss did not improve from 0.04274
# 39/39 - 21s - loss: 0.2141 - accuracy: 0.9138 - val_loss: 0.0467 - val_accuracy: 0.9886 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 130/150
#
# Epoch 130: val_loss improved from 0.04274 to 0.04055, saving model to model.h5
# 39/39 - 22s - loss: 0.2088 - accuracy: 0.9233 - val_loss: 0.0405 - val_accuracy: 0.9911 - lr: 0.0010 - 22s/epoch - 571ms/step
# Epoch 131/150
#
# Epoch 131: val_loss did not improve from 0.04055
# 39/39 - 21s - loss: 0.2172 - accuracy: 0.9233 - val_loss: 0.0421 - val_accuracy: 0.9892 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 132/150
#
# Epoch 132: val_loss did not improve from 0.04055
# 39/39 - 21s - loss: 0.2061 - accuracy: 0.9211 - val_loss: 0.0429 - val_accuracy: 0.9897 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 133/150
#
# Epoch 133: val_loss improved from 0.04055 to 0.03909, saving model to model.h5
# 39/39 - 22s - loss: 0.1942 - accuracy: 0.9233 - val_loss: 0.0391 - val_accuracy: 0.9905 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 134/150
#
# Epoch 134: val_loss did not improve from 0.03909
# 39/39 - 21s - loss: 0.2094 - accuracy: 0.9193 - val_loss: 0.0392 - val_accuracy: 0.9909 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 135/150
#
# Epoch 135: val_loss did not improve from 0.03909
# 39/39 - 22s - loss: 0.2016 - accuracy: 0.9197 - val_loss: 0.0447 - val_accuracy: 0.9899 - lr: 0.0010 - 22s/epoch - 553ms/step
# Epoch 136/150
#
# Epoch 136: val_loss improved from 0.03909 to 0.03756, saving model to model.h5
# 39/39 - 23s - loss: 0.2002 - accuracy: 0.9241 - val_loss: 0.0376 - val_accuracy: 0.9907 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 137/150
#
# Epoch 137: val_loss did not improve from 0.03756
# 39/39 - 21s - loss: 0.1821 - accuracy: 0.9302 - val_loss: 0.0380 - val_accuracy: 0.9909 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 138/150
#
# Epoch 138: val_loss improved from 0.03756 to 0.03552, saving model to model.h5
# 39/39 - 22s - loss: 0.1921 - accuracy: 0.9225 - val_loss: 0.0355 - val_accuracy: 0.9915 - lr: 0.0010 - 22s/epoch - 571ms/step
# Epoch 139/150
#
# Epoch 139: val_loss did not improve from 0.03552
# 39/39 - 21s - loss: 0.2056 - accuracy: 0.9237 - val_loss: 0.0373 - val_accuracy: 0.9905 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 140/150
#
# Epoch 140: val_loss did not improve from 0.03552
# 39/39 - 21s - loss: 0.1977 - accuracy: 0.9265 - val_loss: 0.0358 - val_accuracy: 0.9915 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 141/150
#
# Epoch 141: val_loss did not improve from 0.03552
# 39/39 - 21s - loss: 0.1925 - accuracy: 0.9251 - val_loss: 0.0409 - val_accuracy: 0.9886 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 142/150
#
# Epoch 142: val_loss did not improve from 0.03552
# 39/39 - 21s - loss: 0.2039 - accuracy: 0.9221 - val_loss: 0.0370 - val_accuracy: 0.9884 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 143/150
#
# Epoch 143: val_loss did not improve from 0.03552
# 39/39 - 21s - loss: 0.1935 - accuracy: 0.9272 - val_loss: 0.0360 - val_accuracy: 0.9925 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 144/150
#
# Epoch 144: val_loss improved from 0.03552 to 0.03273, saving model to model.h5
# 39/39 - 22s - loss: 0.1822 - accuracy: 0.9310 - val_loss: 0.0327 - val_accuracy: 0.9935 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 145/150
#
# Epoch 145: val_loss did not improve from 0.03273
# 39/39 - 21s - loss: 0.1931 - accuracy: 0.9294 - val_loss: 0.0336 - val_accuracy: 0.9933 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 146/150
#
# Epoch 146: val_loss improved from 0.03273 to 0.03190, saving model to model.h5
# 39/39 - 22s - loss: 0.1857 - accuracy: 0.9294 - val_loss: 0.0319 - val_accuracy: 0.9933 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 147/150
#
# Epoch 147: val_loss improved from 0.03190 to 0.03154, saving model to model.h5
# 39/39 - 22s - loss: 0.1936 - accuracy: 0.9255 - val_loss: 0.0315 - val_accuracy: 0.9921 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 148/150
#
# Epoch 148: val_loss improved from 0.03154 to 0.02980, saving model to model.h5
# 39/39 - 22s - loss: 0.1856 - accuracy: 0.9294 - val_loss: 0.0298 - val_accuracy: 0.9933 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 149/150
#
# Epoch 149: val_loss did not improve from 0.02980
# 39/39 - 21s - loss: 0.1914 - accuracy: 0.9296 - val_loss: 0.0322 - val_accuracy: 0.9929 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 150/150
#
# Epoch 150: val_loss did not improve from 0.02980
# 39/39 - 21s - loss: 0.1913 - accuracy: 0.9282 - val_loss: 0.0366 - val_accuracy: 0.9901 - lr: 0.0010 - 21s/epoch - 551ms/step

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper left')
plt.show()

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper right')
plt.show()

# %%
model.save('/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/ML_Models/DenseNet_150_epoch/DenseNet121/Case_4_Left_CC/model.h5')

# %%
ypred = model.predict(xtest)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(ypred)):
    if np.argmax(ypred[i]) == np.argmax(ytest[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Total-test-data; 1268 	accurately-predicted-data: 1193 	 wrongly-predicted-data:  75
# Accuracy: 94.085 %

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(accurateindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(wrongindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
Ypred = model.predict(xtest)

Ypred = np.argmax(Ypred, axis=1)
Ytrue = np.argmax(ytest, axis=1)

cm = confusion_matrix(Ytrue, Ypred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')
