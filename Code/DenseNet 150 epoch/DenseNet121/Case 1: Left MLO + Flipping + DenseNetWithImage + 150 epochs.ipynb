# %%
import tensorflow 

import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import models

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("Tensorflow-version:", tensorflow.__version__)
# Out:
# Tensorflow-version: 2.8.0

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(8,activation='softmax')(x) #FC-layer
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 1s 0us/step
# 29097984/29084464 [==============================] - 1s 0us/step

# %%
model_d=DenseNet121(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(3,activation='softmax')(x) #FC-layer

# %%
model=Model(inputs=model_d.input,outputs=preds)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 4, 4, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 4, 4, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 4, 4, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 4, 4, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 4, 4, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 4, 4, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 4, 4, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 4, 4, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 4, 4, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 4, 4, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 4, 4, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 4, 4, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 4, 4, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 4, 4, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 4, 4, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 4, 4, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 4, 4, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 4, 4, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 4, 4, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 4, 4, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 4, 4, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 4, 4, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 4, 4, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 4, 4, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 4, 4, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 4, 4, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 4, 4, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 4, 4, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1024)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1024)        4096        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1049600     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 8,619,587
# Trainable params: 8,532,867
# Non-trainable params: 86,720
# __________________________________________________________________________________________________

# %%
for layer in model.layers[:-8]:
    layer.trainable=False
    
for layer in model.layers[-8:]:
    layer.trainable=True

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 4, 4, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 4, 4, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 4, 4, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 4, 4, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 4, 4, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 4, 4, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 4, 4, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 4, 4, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 4, 4, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 4, 4, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 4, 4, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 4, 4, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 4, 4, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 4, 4, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 4, 4, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 4, 4, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 4, 4, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 4, 4, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 4, 4, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 4, 4, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 4, 4, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 4, 4, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 4, 4, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 4, 4, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 4, 4, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 4, 4, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 4, 4, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 4, 4, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1024)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1024)        4096        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1049600     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 8,619,587
# Trainable params: 1,579,011
# Non-trainable params: 7,040,576
# __________________________________________________________________________________________________

# %%
data=[]
labels=[]
random.seed(42)
# imagePaths = sorted(list(os.listdir("/content/drive/MyDrive/Mini_DDSM_Upload")))
imagePaths = ['Benign','Cancer','Normal']
random.shuffle(imagePaths)
print(imagePaths)
# Out:
# ['Cancer', 'Benign', 'Normal']

# %%
for img in imagePaths:
    path=sorted(list(os.listdir("/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img)))
    for i in path:
      if("LEFT_MLO" in i):
        #Considereing original and flipped image
        for flip in range(2):
          if(flip == 0):
            print("\n****************************************")
            print("Original")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            print(image_path)
            # print("Reading image")
            image = cv2.imread(image_path)
            
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResized Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            # print("Label - ",l)
            labels.append(l)
          else:
            print("\n\n")
            print("FLIPPED")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            # print("Image Path - ",image_path)
            # print("Reading image ",i)
            image = cv2.imread(image_path)
            # print("Flipping Image")
            image = cv2.flip(image,1)
            
            # print("\nResizing the flipped image")
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResizing Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            print("Label - ",l)
            labels.append(l)
        else:
          continue
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/145_A_0051_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1461_A_0565_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1465_A_0566_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1469_A_0567_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1473_A_0568_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1477_A_0569_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1481_A_0570_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1485_A_0571_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1489_A_0572_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1493_A_0573_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1497_A_0574_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/149_A_0052_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1501_A_0575_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1505_A_0576_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1509_A_0578_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1513_A_0580_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1517_A_0581_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1521_A_0583_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1525_A_0584_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1529_A_0585_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1533_A_0586_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1537_A_0587_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/153_A_0053_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1541_A_0588_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1545_A_0589_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1549_A_0591_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1553_A_0594_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1557_A_0595_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1561_A_0596_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1565_A_0597_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1569_A_0598_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1573_A_0599_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1577_A_0600_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/157_A_0055_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1581_A_0601_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1585_A_0602_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1589_A_0603_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1593_A_0604_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1597_A_0605_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1601_A_0606_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1605_A_0607_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1609_A_0608_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1613_A_0609_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1617_A_0610_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/161_A_0056_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1621_A_0611_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1625_A_0613_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1629_A_0614_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1633_A_0615_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1637_A_0616_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1641_A_0617_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1645_A_0618_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1649_A_0619_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1653_A_0620_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1657_A_0621_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/165_A_0057_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1661_A_0623_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1665_A_0702_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1669_A_0703_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1673_A_0704_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1677_A_0705_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1681_A_0706_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1685_A_0707_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1689_A_0708_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1693_A_0710_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1697_D_4500_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/169_A_0058_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1701_D_4501_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1705_D_4502_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1709_D_4503_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1713_D_4505_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1717_D_4506_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1721_D_4508_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1725_D_4509_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1729_D_4510_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1733_D_4511_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1737_D_4512_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/173_A_0059_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1741_D_4513_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1745_D_4514_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1749_D_4515_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1753_D_4516_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1757_D_4517_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1761_D_4518_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1765_D_4519_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1769_D_4520_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1773_D_4521_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1777_D_4522_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/177_A_0061_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1781_D_4523_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1785_D_4524_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1789_D_4525_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1793_D_4526_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1797_D_4527_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/17_A_0009_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1801_D_4528_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1805_D_4529_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1809_D_4530_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1813_D_4532_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1817_D_4533_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/181_A_0062_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1821_D_4534_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1825_D_4536_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1829_D_4537_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1833_D_4538_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1837_D_4539_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1841_D_4540_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1845_D_4541_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1849_D_4542_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1853_D_4543_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1857_D_4544_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/185_A_0063_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1861_D_4545_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1865_D_4546_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1869_D_4547_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1873_D_4551_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1877_D_4552_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1881_D_4553_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1885_D_4555_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1889_D_4557_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1893_D_4558_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1897_D_4559_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/189_A_0064_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1901_D_4560_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1905_D_4561_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1909_D_4562_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1913_D_4563_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1917_D_4565_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1921_D_4566_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1925_D_4567_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1929_D_4570_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1933_D_4571_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1937_D_4572_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/193_A_0067_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1941_D_4574_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1945_D_4575_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1949_D_4576_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1953_D_4577_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1957_D_4582_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1961_D_4583_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1965_D_4584_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1969_D_4585_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1973_D_4587_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1977_D_4588_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/197_A_0068_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1981_D_4589_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1985_D_4590_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1989_D_4591_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1993_D_4592_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1997_D_4593_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1_A_0002_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2002_D_4548_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2006_D_4549_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2010_D_4550_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2014_D_4554_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2018_D_4556_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/201_A_0069_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2022_D_4564_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2025_D_4568_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2030_D_4573_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2033_D_4578_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2037_D_4579_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2042_D_4580_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2046_D_4581_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2050_D_4586_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2054_D_4596_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2058_D_4597_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/205_A_0070_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2062_D_4598_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2066_D_4599_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2070_D_4600_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2074_D_4601_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2078_D_4602_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2082_D_4603_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2086_D_4604_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2090_D_4605_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2094_D_4606_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2098_D_4607_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/209_A_0071_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2102_D_4608_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2106_B_3600_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2110_B_3601_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2114_B_3602_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2118_B_3603_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2122_B_3604_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2126_B_3605_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2130_B_3606_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2134_B_3607_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2138_B_3608_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/213_A_0072_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2142_B_3609_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2146_B_3610_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2150_B_3611_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2154_B_3612_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2158_B_3613_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2162_B_3614_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2166_B_3615_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2170_B_3616_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2174_B_3617_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2178_B_3618_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/217_A_0073_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2182_B_3619_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2186_B_3620_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2190_B_3621_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2194_B_3622_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2198_B_3623_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/21_A_0010_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2202_B_3624_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2206_B_3625_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2210_B_3626_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2214_B_3627_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2218_B_3628_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/221_A_0074_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2222_B_3629_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2226_B_3630_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2230_B_3631_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2234_B_3632_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2238_B_3633_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2242_B_3634_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2246_B_3635_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2250_B_3636_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2254_B_3637_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2258_B_3638_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/225_A_0075_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2262_B_3639_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2266_B_3640_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2270_B_3641_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2274_B_3642_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2278_B_3643_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2282_B_3644_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2286_B_3645_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2290_B_3646_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2294_B_3647_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2298_B_3648_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/229_A_0076_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2302_B_3649_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2306_B_3650_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2310_B_3651_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2314_B_3652_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2318_B_3653_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2322_B_3654_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2326_B_3655_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2330_B_3656_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2334_B_3657_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2338_B_3660_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/233_A_0077_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2342_B_3661_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2346_B_3662_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2350_B_3663_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2354_B_3664_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2358_B_3665_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2362_B_3666_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2366_B_3667_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2370_B_3668_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2374_B_3669_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2378_B_3670_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/237_A_0079_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2382_B_3671_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2386_B_3672_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2390_B_3673_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2394_B_3674_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2398_B_3675_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2402_B_3676_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2406_B_3677_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2410_B_3678_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# ...
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/681_A_0264_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/685_A_0265_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/689_A_0266_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/693_A_0267_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/697_A_0268_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/69_A_0027_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/701_A_0269_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/705_A_0270_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/709_A_0271_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/713_A_0272_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/717_A_0273_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/721_A_0274_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/725_A_0275_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/729_A_0276_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/733_A_0277_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/737_A_0278_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/73_A_0030_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/741_A_0279_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/745_A_0280_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/749_A_0282_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/753_A_0283_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/757_A_0284_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/761_A_0285_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/765_A_0286_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/769_A_0287_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/773_A_0290_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/777_A_0292_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/77_A_0031_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/781_A_0293_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/785_A_0294_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/789_A_0295_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/793_A_0296_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/797_A_0297_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/801_A_0298_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/805_A_0299_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/809_A_0302_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/813_A_0303_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/817_A_0304_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/81_A_0032_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/821_A_0305_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/825_A_0306_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/829_A_0307_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/833_A_0309_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/837_A_0310_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/841_A_0311_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/845_A_0312_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/849_A_0313_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/853_A_0314_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/857_A_0315_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/85_A_0034_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/861_A_0317_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/865_A_0318_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/869_A_0319_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/873_A_0320_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/877_A_0321_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/881_A_0322_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/885_A_0323_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/889_A_0325_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/893_A_0326_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/897_A_0327_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/89_A_0035_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/901_A_0328_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/905_A_0330_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/909_A_0331_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/913_A_0333_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/917_A_0334_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/921_A_0335_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/925_A_0336_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/929_A_0337_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/933_A_0338_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/937_A_0339_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/93_A_0036_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/941_A_0341_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/945_A_0342_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/949_A_0343_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/953_A_0344_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/957_A_0345_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/961_A_0347_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/965_A_0348_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/969_A_0349_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/973_A_0351_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/977_A_0352_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/97_A_0037_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/981_A_0354_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/985_A_0355_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/989_A_0356_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/993_A_0357_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/997_A_0358_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/9_A_0005_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal

# %%
print("Length of dataset = ",len(labels))
# Out:
# Length of dataset =  4848

# %%
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
print(labels[0])
# Out:
# [0 1 0]

# %%
(xtrain,xtest,ytrain,ytest)=train_test_split(data,labels,test_size=0.2,random_state=42)
print(xtrain.shape, xtest.shape)
# Out:
# (3878, 128, 128, 3) (970, 128, 128, 3)

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)


datagen.fit(xtrain)
# Fits-the-model
history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=128),
               steps_per_epoch=xtrain.shape[0] //128,
               epochs=150, #try 100
               verbose=2,
               callbacks=[anne, checkpoint],
               validation_data=(xtrain, ytrain))
# Out:
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 1.04374, saving model to model.h5
# 30/30 - 127s - loss: 1.5136 - accuracy: 0.5021 - val_loss: 1.0437 - val_accuracy: 0.5008 - lr: 0.0010 - 127s/epoch - 4s/step
# Epoch 2/150
#
# Epoch 2: val_loss improved from 1.04374 to 0.77695, saving model to model.h5
# 30/30 - 115s - loss: 1.1357 - accuracy: 0.5627 - val_loss: 0.7770 - val_accuracy: 0.6158 - lr: 0.0010 - 115s/epoch - 4s/step
# Epoch 3/150
#
# Epoch 3: val_loss did not improve from 0.77695
# 30/30 - 113s - loss: 1.0165 - accuracy: 0.5672 - val_loss: 0.8150 - val_accuracy: 0.5931 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 4/150
#
# Epoch 4: val_loss improved from 0.77695 to 0.75511, saving model to model.h5
# 30/30 - 115s - loss: 0.9068 - accuracy: 0.6045 - val_loss: 0.7551 - val_accuracy: 0.6377 - lr: 0.0010 - 115s/epoch - 4s/step
# Epoch 5/150
#
# Epoch 5: val_loss improved from 0.75511 to 0.68576, saving model to model.h5
# 30/30 - 111s - loss: 0.8607 - accuracy: 0.6192 - val_loss: 0.6858 - val_accuracy: 0.6870 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 6/150
#
# Epoch 6: val_loss improved from 0.68576 to 0.64401, saving model to model.h5
# 30/30 - 114s - loss: 0.7940 - accuracy: 0.6301 - val_loss: 0.6440 - val_accuracy: 0.7166 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 7/150
#
# Epoch 7: val_loss improved from 0.64401 to 0.62660, saving model to model.h5
# 30/30 - 114s - loss: 0.7711 - accuracy: 0.6453 - val_loss: 0.6266 - val_accuracy: 0.7316 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 8/150
#
# Epoch 8: val_loss improved from 0.62660 to 0.62626, saving model to model.h5
# 30/30 - 114s - loss: 0.7517 - accuracy: 0.6480 - val_loss: 0.6263 - val_accuracy: 0.7329 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 9/150
#
# Epoch 9: val_loss improved from 0.62626 to 0.61702, saving model to model.h5
# 30/30 - 114s - loss: 0.7524 - accuracy: 0.6456 - val_loss: 0.6170 - val_accuracy: 0.7326 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 10/150
#
# Epoch 10: val_loss improved from 0.61702 to 0.59577, saving model to model.h5
# 30/30 - 114s - loss: 0.7213 - accuracy: 0.6613 - val_loss: 0.5958 - val_accuracy: 0.7486 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 11/150
#
# Epoch 11: val_loss improved from 0.59577 to 0.58072, saving model to model.h5
# 30/30 - 114s - loss: 0.7145 - accuracy: 0.6672 - val_loss: 0.5807 - val_accuracy: 0.7653 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 12/150
#
# Epoch 12: val_loss improved from 0.58072 to 0.55632, saving model to model.h5
# 30/30 - 115s - loss: 0.7138 - accuracy: 0.6691 - val_loss: 0.5563 - val_accuracy: 0.7754 - lr: 0.0010 - 115s/epoch - 4s/step
# Epoch 13/150
#
# Epoch 13: val_loss did not improve from 0.55632
# 30/30 - 112s - loss: 0.6959 - accuracy: 0.6691 - val_loss: 0.5659 - val_accuracy: 0.7610 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 14/150
#
# Epoch 14: val_loss improved from 0.55632 to 0.55561, saving model to model.h5
# 30/30 - 113s - loss: 0.7087 - accuracy: 0.6640 - val_loss: 0.5556 - val_accuracy: 0.7633 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 15/150
#
# Epoch 15: val_loss did not improve from 0.55561
# 30/30 - 110s - loss: 0.6793 - accuracy: 0.6867 - val_loss: 0.5734 - val_accuracy: 0.7592 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 16/150
#
# Epoch 16: val_loss improved from 0.55561 to 0.53699, saving model to model.h5
# 30/30 - 113s - loss: 0.6736 - accuracy: 0.6915 - val_loss: 0.5370 - val_accuracy: 0.7816 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 17/150
#
# Epoch 17: val_loss improved from 0.53699 to 0.50484, saving model to model.h5
# 30/30 - 113s - loss: 0.6505 - accuracy: 0.7064 - val_loss: 0.5048 - val_accuracy: 0.7960 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 18/150
#
# Epoch 18: val_loss improved from 0.50484 to 0.49750, saving model to model.h5
# 30/30 - 113s - loss: 0.6552 - accuracy: 0.6992 - val_loss: 0.4975 - val_accuracy: 0.7965 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 19/150
#
# Epoch 19: val_loss improved from 0.49750 to 0.48644, saving model to model.h5
# 30/30 - 113s - loss: 0.6457 - accuracy: 0.7069 - val_loss: 0.4864 - val_accuracy: 0.7927 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 20/150
#
# Epoch 20: val_loss improved from 0.48644 to 0.48022, saving model to model.h5
# 30/30 - 112s - loss: 0.6479 - accuracy: 0.7048 - val_loss: 0.4802 - val_accuracy: 0.8061 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 21/150
#
# Epoch 21: val_loss improved from 0.48022 to 0.45547, saving model to model.h5
# 30/30 - 113s - loss: 0.6386 - accuracy: 0.7053 - val_loss: 0.4555 - val_accuracy: 0.8210 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 22/150
#
# Epoch 22: val_loss improved from 0.45547 to 0.44639, saving model to model.h5
# 30/30 - 112s - loss: 0.6209 - accuracy: 0.7248 - val_loss: 0.4464 - val_accuracy: 0.8223 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 23/150
#
# Epoch 23: val_loss improved from 0.44639 to 0.43265, saving model to model.h5
# 30/30 - 113s - loss: 0.6147 - accuracy: 0.7184 - val_loss: 0.4326 - val_accuracy: 0.8226 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 24/150
#
# Epoch 24: val_loss improved from 0.43265 to 0.42150, saving model to model.h5
# 30/30 - 114s - loss: 0.6177 - accuracy: 0.7224 - val_loss: 0.4215 - val_accuracy: 0.8342 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 25/150
#
# Epoch 25: val_loss did not improve from 0.42150
# 30/30 - 112s - loss: 0.6173 - accuracy: 0.7155 - val_loss: 0.4339 - val_accuracy: 0.8332 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 26/150
#
# Epoch 26: val_loss improved from 0.42150 to 0.41979, saving model to model.h5
# 30/30 - 113s - loss: 0.6211 - accuracy: 0.7189 - val_loss: 0.4198 - val_accuracy: 0.8345 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 27/150
#
# Epoch 27: val_loss did not improve from 0.41979
# 30/30 - 112s - loss: 0.5817 - accuracy: 0.7379 - val_loss: 0.4227 - val_accuracy: 0.8285 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 28/150
#
# Epoch 28: val_loss improved from 0.41979 to 0.38978, saving model to model.h5
# 30/30 - 112s - loss: 0.5935 - accuracy: 0.7323 - val_loss: 0.3898 - val_accuracy: 0.8577 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 29/150
#
# Epoch 29: val_loss did not improve from 0.38978
# 30/30 - 112s - loss: 0.5940 - accuracy: 0.7357 - val_loss: 0.4113 - val_accuracy: 0.8481 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 30/150
#
# Epoch 30: val_loss improved from 0.38978 to 0.38246, saving model to model.h5
# 30/30 - 113s - loss: 0.5765 - accuracy: 0.7467 - val_loss: 0.3825 - val_accuracy: 0.8455 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 31/150
#
# Epoch 31: val_loss did not improve from 0.38246
# 30/30 - 112s - loss: 0.5935 - accuracy: 0.7325 - val_loss: 0.4120 - val_accuracy: 0.8396 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 32/150
#
# Epoch 32: val_loss improved from 0.38246 to 0.36491, saving model to model.h5
# 30/30 - 113s - loss: 0.5871 - accuracy: 0.7413 - val_loss: 0.3649 - val_accuracy: 0.8770 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 33/150
#
# Epoch 33: val_loss did not improve from 0.36491
# 30/30 - 111s - loss: 0.5757 - accuracy: 0.7475 - val_loss: 0.4003 - val_accuracy: 0.8455 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 34/150
#
# Epoch 34: val_loss did not improve from 0.36491
# 30/30 - 113s - loss: 0.5645 - accuracy: 0.7573 - val_loss: 0.4109 - val_accuracy: 0.8401 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 35/150
#
# Epoch 35: val_loss did not improve from 0.36491
# 30/30 - 115s - loss: 0.5705 - accuracy: 0.7456 - val_loss: 0.3796 - val_accuracy: 0.8530 - lr: 0.0010 - 115s/epoch - 4s/step
# Epoch 36/150
#
# Epoch 36: val_loss did not improve from 0.36491
# 30/30 - 113s - loss: 0.5436 - accuracy: 0.7557 - val_loss: 0.3937 - val_accuracy: 0.8296 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 37/150
#
# Epoch 37: val_loss did not improve from 0.36491
# 30/30 - 114s - loss: 0.5512 - accuracy: 0.7539 - val_loss: 0.3736 - val_accuracy: 0.8540 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 38/150
#
# Epoch 38: val_loss did not improve from 0.36491
# 30/30 - 113s - loss: 0.5523 - accuracy: 0.7573 - val_loss: 0.4016 - val_accuracy: 0.8528 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 39/150
#
# Epoch 39: val_loss improved from 0.36491 to 0.36081, saving model to model.h5
# 30/30 - 111s - loss: 0.5514 - accuracy: 0.7560 - val_loss: 0.3608 - val_accuracy: 0.8669 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 40/150
#
# Epoch 40: val_loss improved from 0.36081 to 0.32891, saving model to model.h5
# 30/30 - 113s - loss: 0.5249 - accuracy: 0.7744 - val_loss: 0.3289 - val_accuracy: 0.8682 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 41/150
#
# Epoch 41: val_loss did not improve from 0.32891
# 30/30 - 112s - loss: 0.5567 - accuracy: 0.7613 - val_loss: 0.3522 - val_accuracy: 0.8744 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 42/150
#
# Epoch 42: val_loss improved from 0.32891 to 0.32875, saving model to model.h5
# 30/30 - 114s - loss: 0.5254 - accuracy: 0.7667 - val_loss: 0.3288 - val_accuracy: 0.8845 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 43/150
#
# Epoch 43: val_loss improved from 0.32875 to 0.30810, saving model to model.h5
# 30/30 - 111s - loss: 0.5143 - accuracy: 0.7773 - val_loss: 0.3081 - val_accuracy: 0.8858 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 44/150
#
# Epoch 44: val_loss did not improve from 0.30810
# 30/30 - 112s - loss: 0.5107 - accuracy: 0.7757 - val_loss: 0.3190 - val_accuracy: 0.8801 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 45/150
#
# Epoch 45: val_loss did not improve from 0.30810
# 30/30 - 113s - loss: 0.5214 - accuracy: 0.7696 - val_loss: 0.3431 - val_accuracy: 0.8703 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 46/150
#
# Epoch 46: val_loss did not improve from 0.30810
# 30/30 - 112s - loss: 0.5183 - accuracy: 0.7720 - val_loss: 0.3247 - val_accuracy: 0.8765 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 47/150
#
# Epoch 47: val_loss improved from 0.30810 to 0.28762, saving model to model.h5
# 30/30 - 114s - loss: 0.4957 - accuracy: 0.7864 - val_loss: 0.2876 - val_accuracy: 0.9030 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.28762 to 0.27696, saving model to model.h5
# 30/30 - 112s - loss: 0.5087 - accuracy: 0.7808 - val_loss: 0.2770 - val_accuracy: 0.9126 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 49/150
#
# Epoch 49: val_loss did not improve from 0.27696
# 30/30 - 112s - loss: 0.5025 - accuracy: 0.7856 - val_loss: 0.2904 - val_accuracy: 0.9092 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 50/150
#
# Epoch 50: val_loss did not improve from 0.27696
# 30/30 - 112s - loss: 0.4864 - accuracy: 0.7813 - val_loss: 0.2843 - val_accuracy: 0.8909 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 51/150
#
# Epoch 51: val_loss improved from 0.27696 to 0.27377, saving model to model.h5
# 30/30 - 113s - loss: 0.4876 - accuracy: 0.7901 - val_loss: 0.2738 - val_accuracy: 0.9046 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 52/150
#
# Epoch 52: val_loss improved from 0.27377 to 0.26090, saving model to model.h5
# 30/30 - 114s - loss: 0.4827 - accuracy: 0.7960 - val_loss: 0.2609 - val_accuracy: 0.9154 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 53/150
#
# Epoch 53: val_loss improved from 0.26090 to 0.25580, saving model to model.h5
# 30/30 - 111s - loss: 0.4810 - accuracy: 0.7915 - val_loss: 0.2558 - val_accuracy: 0.9180 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 54/150
#
# Epoch 54: val_loss did not improve from 0.25580
# 30/30 - 112s - loss: 0.4525 - accuracy: 0.8101 - val_loss: 0.2799 - val_accuracy: 0.8994 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 55/150
#
# Epoch 55: val_loss improved from 0.25580 to 0.24800, saving model to model.h5
# 30/30 - 113s - loss: 0.4676 - accuracy: 0.7973 - val_loss: 0.2480 - val_accuracy: 0.9167 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 56/150
#
# Epoch 56: val_loss improved from 0.24800 to 0.24668, saving model to model.h5
# 30/30 - 113s - loss: 0.4838 - accuracy: 0.7907 - val_loss: 0.2467 - val_accuracy: 0.9216 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 57/150
#
# Epoch 57: val_loss did not improve from 0.24668
# 30/30 - 112s - loss: 0.4399 - accuracy: 0.8093 - val_loss: 0.2485 - val_accuracy: 0.9177 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 58/150
#
# Epoch 58: val_loss improved from 0.24668 to 0.21885, saving model to model.h5
# 30/30 - 112s - loss: 0.4514 - accuracy: 0.8141 - val_loss: 0.2189 - val_accuracy: 0.9275 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 59/150
#
# Epoch 59: val_loss improved from 0.21885 to 0.21207, saving model to model.h5
# 30/30 - 110s - loss: 0.4402 - accuracy: 0.8080 - val_loss: 0.2121 - val_accuracy: 0.9360 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 60/150
#
# Epoch 60: val_loss did not improve from 0.21207
# 30/30 - 112s - loss: 0.4551 - accuracy: 0.8035 - val_loss: 0.2168 - val_accuracy: 0.9355 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 61/150
#
# Epoch 61: val_loss did not improve from 0.21207
# 30/30 - 113s - loss: 0.4416 - accuracy: 0.8171 - val_loss: 0.2288 - val_accuracy: 0.9244 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 62/150
#
# Epoch 62: val_loss did not improve from 0.21207
# 30/30 - 112s - loss: 0.4240 - accuracy: 0.8248 - val_loss: 0.2157 - val_accuracy: 0.9299 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 63/150
#
# Epoch 63: val_loss did not improve from 0.21207
# 30/30 - 112s - loss: 0.4474 - accuracy: 0.8141 - val_loss: 0.2170 - val_accuracy: 0.9270 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 64/150
#
# Epoch 64: val_loss did not improve from 0.21207
# 30/30 - 112s - loss: 0.4340 - accuracy: 0.8096 - val_loss: 0.2209 - val_accuracy: 0.9288 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 65/150
#
# Epoch 65: val_loss improved from 0.21207 to 0.20968, saving model to model.h5
# 30/30 - 113s - loss: 0.4231 - accuracy: 0.8245 - val_loss: 0.2097 - val_accuracy: 0.9366 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 66/150
#
# Epoch 66: val_loss improved from 0.20968 to 0.18806, saving model to model.h5
# 30/30 - 112s - loss: 0.4184 - accuracy: 0.8280 - val_loss: 0.1881 - val_accuracy: 0.9479 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 67/150
#
# Epoch 67: val_loss did not improve from 0.18806
# 30/30 - 113s - loss: 0.4347 - accuracy: 0.8152 - val_loss: 0.2090 - val_accuracy: 0.9340 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 68/150
#
# Epoch 68: val_loss improved from 0.18806 to 0.17838, saving model to model.h5
# 30/30 - 112s - loss: 0.3995 - accuracy: 0.8304 - val_loss: 0.1784 - val_accuracy: 0.9448 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 69/150
#
# Epoch 69: val_loss did not improve from 0.17838
# 30/30 - 111s - loss: 0.4104 - accuracy: 0.8245 - val_loss: 0.1895 - val_accuracy: 0.9371 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 70/150
#
# Epoch 70: val_loss did not improve from 0.17838
# 30/30 - 112s - loss: 0.4149 - accuracy: 0.8309 - val_loss: 0.2199 - val_accuracy: 0.9263 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 71/150
#
# Epoch 71: val_loss did not improve from 0.17838
# 30/30 - 110s - loss: 0.4153 - accuracy: 0.8269 - val_loss: 0.1846 - val_accuracy: 0.9477 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 72/150
#
# Epoch 72: val_loss did not improve from 0.17838
# 30/30 - 113s - loss: 0.3910 - accuracy: 0.8405 - val_loss: 0.1911 - val_accuracy: 0.9443 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 73/150
#
# Epoch 73: val_loss did not improve from 0.17838
# 30/30 - 111s - loss: 0.3889 - accuracy: 0.8475 - val_loss: 0.1880 - val_accuracy: 0.9448 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 74/150
#
# Epoch 74: val_loss improved from 0.17838 to 0.17156, saving model to model.h5
# 30/30 - 112s - loss: 0.3877 - accuracy: 0.8453 - val_loss: 0.1716 - val_accuracy: 0.9515 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 75/150
#
# Epoch 75: val_loss improved from 0.17156 to 0.16934, saving model to model.h5
# 30/30 - 113s - loss: 0.3938 - accuracy: 0.8357 - val_loss: 0.1693 - val_accuracy: 0.9556 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 76/150
#
# Epoch 76: val_loss did not improve from 0.16934
# 30/30 - 111s - loss: 0.3862 - accuracy: 0.8437 - val_loss: 0.1740 - val_accuracy: 0.9520 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 77/150
#
# Epoch 77: val_loss improved from 0.16934 to 0.16147, saving model to model.h5
# 30/30 - 114s - loss: 0.3759 - accuracy: 0.8490 - val_loss: 0.1615 - val_accuracy: 0.9538 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 78/150
#
# Epoch 78: val_loss did not improve from 0.16147
# 30/30 - 108s - loss: 0.3785 - accuracy: 0.8456 - val_loss: 0.1706 - val_accuracy: 0.9531 - lr: 0.0010 - 108s/epoch - 4s/step
# Epoch 79/150
#
# Epoch 79: val_loss improved from 0.16147 to 0.16091, saving model to model.h5
# 30/30 - 113s - loss: 0.3754 - accuracy: 0.8421 - val_loss: 0.1609 - val_accuracy: 0.9518 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 80/150
#
# Epoch 80: val_loss improved from 0.16091 to 0.14917, saving model to model.h5
# 30/30 - 112s - loss: 0.3773 - accuracy: 0.8456 - val_loss: 0.1492 - val_accuracy: 0.9603 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 81/150
#
# Epoch 81: val_loss did not improve from 0.14917
# 30/30 - 111s - loss: 0.3545 - accuracy: 0.8563 - val_loss: 0.1565 - val_accuracy: 0.9549 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 82/150
#
# Epoch 82: val_loss did not improve from 0.14917
# 30/30 - 112s - loss: 0.3581 - accuracy: 0.8592 - val_loss: 0.1530 - val_accuracy: 0.9551 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 83/150
#
# Epoch 83: val_loss did not improve from 0.14917
# 30/30 - 112s - loss: 0.3684 - accuracy: 0.8547 - val_loss: 0.1493 - val_accuracy: 0.9505 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 84/150
#
# Epoch 84: val_loss did not improve from 0.14917
# 30/30 - 111s - loss: 0.3658 - accuracy: 0.8517 - val_loss: 0.1671 - val_accuracy: 0.9464 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 85/150
#
# Epoch 85: val_loss improved from 0.14917 to 0.14122, saving model to model.h5
# 30/30 - 112s - loss: 0.3488 - accuracy: 0.8624 - val_loss: 0.1412 - val_accuracy: 0.9585 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 86/150
#
# Epoch 86: val_loss did not improve from 0.14122
# 30/30 - 112s - loss: 0.3684 - accuracy: 0.8480 - val_loss: 0.1432 - val_accuracy: 0.9549 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 87/150
#
# Epoch 87: val_loss improved from 0.14122 to 0.13233, saving model to model.h5
# 30/30 - 114s - loss: 0.3407 - accuracy: 0.8608 - val_loss: 0.1323 - val_accuracy: 0.9647 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 88/150
#
# Epoch 88: val_loss did not improve from 0.13233
# 30/30 - 112s - loss: 0.3273 - accuracy: 0.8680 - val_loss: 0.1389 - val_accuracy: 0.9603 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 89/150
#
# Epoch 89: val_loss did not improve from 0.13233
# 30/30 - 112s - loss: 0.3374 - accuracy: 0.8643 - val_loss: 0.1447 - val_accuracy: 0.9546 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 90/150
#
# Epoch 90: val_loss did not improve from 0.13233
# 30/30 - 113s - loss: 0.3356 - accuracy: 0.8664 - val_loss: 0.1462 - val_accuracy: 0.9518 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 91/150
#
# Epoch 91: val_loss did not improve from 0.13233
# 30/30 - 113s - loss: 0.3564 - accuracy: 0.8536 - val_loss: 0.1413 - val_accuracy: 0.9585 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 92/150
#
# Epoch 92: val_loss improved from 0.13233 to 0.12658, saving model to model.h5
# 30/30 - 113s - loss: 0.3204 - accuracy: 0.8720 - val_loss: 0.1266 - val_accuracy: 0.9685 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 93/150
#
# Epoch 93: val_loss improved from 0.12658 to 0.11306, saving model to model.h5
# 30/30 - 123s - loss: 0.3359 - accuracy: 0.8664 - val_loss: 0.1131 - val_accuracy: 0.9740 - lr: 0.0010 - 123s/epoch - 4s/step
# Epoch 94/150
#
# Epoch 94: val_loss did not improve from 0.11306
# 30/30 - 123s - loss: 0.3492 - accuracy: 0.8552 - val_loss: 0.1154 - val_accuracy: 0.9719 - lr: 0.0010 - 123s/epoch - 4s/step
# Epoch 95/150
#
# Epoch 95: val_loss did not improve from 0.11306
# 30/30 - 123s - loss: 0.3600 - accuracy: 0.8555 - val_loss: 0.1213 - val_accuracy: 0.9685 - lr: 0.0010 - 123s/epoch - 4s/step
# Epoch 96/150
#
# Epoch 96: val_loss did not improve from 0.11306
# 30/30 - 122s - loss: 0.3424 - accuracy: 0.8624 - val_loss: 0.1361 - val_accuracy: 0.9621 - lr: 0.0010 - 122s/epoch - 4s/step
# Epoch 97/150
#
# Epoch 97: val_loss did not improve from 0.11306
# 30/30 - 112s - loss: 0.3287 - accuracy: 0.8688 - val_loss: 0.1182 - val_accuracy: 0.9701 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 98/150
#
# Epoch 98: val_loss did not improve from 0.11306
# 30/30 - 112s - loss: 0.3140 - accuracy: 0.8765 - val_loss: 0.1147 - val_accuracy: 0.9703 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 99/150
#
# Epoch 99: val_loss did not improve from 0.11306
# 30/30 - 112s - loss: 0.3400 - accuracy: 0.8637 - val_loss: 0.1331 - val_accuracy: 0.9639 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 100/150
#
# Epoch 100: val_loss did not improve from 0.11306
# 30/30 - 113s - loss: 0.3247 - accuracy: 0.8725 - val_loss: 0.1185 - val_accuracy: 0.9652 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 101/150
#
# Epoch 101: val_loss improved from 0.11306 to 0.10138, saving model to model.h5
# 30/30 - 114s - loss: 0.3011 - accuracy: 0.8845 - val_loss: 0.1014 - val_accuracy: 0.9737 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 102/150
#
# Epoch 102: val_loss did not improve from 0.10138
# 30/30 - 114s - loss: 0.3165 - accuracy: 0.8784 - val_loss: 0.1030 - val_accuracy: 0.9711 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 103/150
#
# Epoch 103: val_loss did not improve from 0.10138
# 30/30 - 113s - loss: 0.3221 - accuracy: 0.8741 - val_loss: 0.1165 - val_accuracy: 0.9703 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 104/150
#
# Epoch 104: val_loss did not improve from 0.10138
# 30/30 - 113s - loss: 0.2972 - accuracy: 0.8883 - val_loss: 0.1082 - val_accuracy: 0.9693 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 105/150
#
# Epoch 105: val_loss improved from 0.10138 to 0.09085, saving model to model.h5
# 30/30 - 111s - loss: 0.2804 - accuracy: 0.8947 - val_loss: 0.0908 - val_accuracy: 0.9755 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 106/150
#
# Epoch 106: val_loss did not improve from 0.09085
# 30/30 - 111s - loss: 0.2781 - accuracy: 0.8896 - val_loss: 0.0954 - val_accuracy: 0.9734 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 107/150
#
# Epoch 107: val_loss did not improve from 0.09085
# 30/30 - 112s - loss: 0.2918 - accuracy: 0.8861 - val_loss: 0.1098 - val_accuracy: 0.9662 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 108/150
#
# Epoch 108: val_loss did not improve from 0.09085
# 30/30 - 112s - loss: 0.3087 - accuracy: 0.8795 - val_loss: 0.0924 - val_accuracy: 0.9745 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 109/150
#
# Epoch 109: val_loss did not improve from 0.09085
# 30/30 - 111s - loss: 0.2928 - accuracy: 0.8883 - val_loss: 0.1147 - val_accuracy: 0.9639 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 110/150
#
# Epoch 110: val_loss did not improve from 0.09085
# 30/30 - 112s - loss: 0.2934 - accuracy: 0.8856 - val_loss: 0.0981 - val_accuracy: 0.9698 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 111/150
#
# Epoch 111: val_loss did not improve from 0.09085
# 30/30 - 110s - loss: 0.2929 - accuracy: 0.8869 - val_loss: 0.0958 - val_accuracy: 0.9745 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 112/150
#
# Epoch 112: val_loss improved from 0.09085 to 0.08641, saving model to model.h5
# 30/30 - 112s - loss: 0.2855 - accuracy: 0.8939 - val_loss: 0.0864 - val_accuracy: 0.9781 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 113/150
#
# Epoch 113: val_loss did not improve from 0.08641
# 30/30 - 111s - loss: 0.3018 - accuracy: 0.8805 - val_loss: 0.0904 - val_accuracy: 0.9750 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 114/150
#
# Epoch 114: val_loss did not improve from 0.08641
# 30/30 - 111s - loss: 0.2799 - accuracy: 0.8923 - val_loss: 0.0955 - val_accuracy: 0.9747 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 115/150
#
# Epoch 115: val_loss did not improve from 0.08641
# 30/30 - 111s - loss: 0.2821 - accuracy: 0.8891 - val_loss: 0.0868 - val_accuracy: 0.9755 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 116/150
#
# Epoch 116: val_loss did not improve from 0.08641
# 30/30 - 111s - loss: 0.2843 - accuracy: 0.8917 - val_loss: 0.0883 - val_accuracy: 0.9765 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 117/150
#
# Epoch 117: val_loss improved from 0.08641 to 0.08389, saving model to model.h5
# 30/30 - 112s - loss: 0.3079 - accuracy: 0.8773 - val_loss: 0.0839 - val_accuracy: 0.9796 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 118/150
#
# Epoch 118: val_loss did not improve from 0.08389
# 30/30 - 113s - loss: 0.2787 - accuracy: 0.8965 - val_loss: 0.0895 - val_accuracy: 0.9771 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 119/150
#
# Epoch 119: val_loss did not improve from 0.08389
# 30/30 - 112s - loss: 0.2520 - accuracy: 0.9024 - val_loss: 0.0876 - val_accuracy: 0.9760 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 120/150
#
# Epoch 120: val_loss improved from 0.08389 to 0.08386, saving model to model.h5
# 30/30 - 111s - loss: 0.2866 - accuracy: 0.8875 - val_loss: 0.0839 - val_accuracy: 0.9763 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 121/150
#
# Epoch 121: val_loss improved from 0.08386 to 0.07978, saving model to model.h5
# 30/30 - 111s - loss: 0.2867 - accuracy: 0.8880 - val_loss: 0.0798 - val_accuracy: 0.9791 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 122/150
#
# Epoch 122: val_loss did not improve from 0.07978
# 30/30 - 110s - loss: 0.2675 - accuracy: 0.8997 - val_loss: 0.0879 - val_accuracy: 0.9734 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 123/150
#
# Epoch 123: val_loss improved from 0.07978 to 0.07368, saving model to model.h5
# 30/30 - 112s - loss: 0.2723 - accuracy: 0.8992 - val_loss: 0.0737 - val_accuracy: 0.9814 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 124/150
#
# Epoch 124: val_loss did not improve from 0.07368
# 30/30 - 111s - loss: 0.2637 - accuracy: 0.8939 - val_loss: 0.0793 - val_accuracy: 0.9789 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 125/150
#
# Epoch 125: val_loss improved from 0.07368 to 0.06782, saving model to model.h5
# 30/30 - 114s - loss: 0.2630 - accuracy: 0.8906 - val_loss: 0.0678 - val_accuracy: 0.9825 - lr: 0.0010 - 114s/epoch - 4s/step
# Epoch 126/150
#
# Epoch 126: val_loss did not improve from 0.06782
# 30/30 - 111s - loss: 0.2597 - accuracy: 0.8992 - val_loss: 0.0802 - val_accuracy: 0.9773 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 127/150
#
# Epoch 127: val_loss did not improve from 0.06782
# 30/30 - 110s - loss: 0.2534 - accuracy: 0.8955 - val_loss: 0.0797 - val_accuracy: 0.9773 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 128/150
#
# Epoch 128: val_loss did not improve from 0.06782
# 30/30 - 112s - loss: 0.2655 - accuracy: 0.9013 - val_loss: 0.0969 - val_accuracy: 0.9701 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 129/150
#
# Epoch 129: val_loss did not improve from 0.06782
# 30/30 - 113s - loss: 0.2586 - accuracy: 0.8964 - val_loss: 0.0730 - val_accuracy: 0.9804 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 130/150
#
# Epoch 130: val_loss improved from 0.06782 to 0.06041, saving model to model.h5
# 30/30 - 111s - loss: 0.2496 - accuracy: 0.9024 - val_loss: 0.0604 - val_accuracy: 0.9861 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 131/150
#
# Epoch 131: val_loss did not improve from 0.06041
# 30/30 - 109s - loss: 0.2509 - accuracy: 0.9059 - val_loss: 0.0632 - val_accuracy: 0.9840 - lr: 0.0010 - 109s/epoch - 4s/step
# Epoch 132/150
#
# Epoch 132: val_loss did not improve from 0.06041
# 30/30 - 111s - loss: 0.2372 - accuracy: 0.9104 - val_loss: 0.0613 - val_accuracy: 0.9832 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 133/150
#
# Epoch 133: val_loss did not improve from 0.06041
# 30/30 - 116s - loss: 0.2437 - accuracy: 0.9101 - val_loss: 0.0709 - val_accuracy: 0.9804 - lr: 0.0010 - 116s/epoch - 4s/step
# Epoch 134/150
#
# Epoch 134: val_loss did not improve from 0.06041
# 30/30 - 112s - loss: 0.2454 - accuracy: 0.9061 - val_loss: 0.0623 - val_accuracy: 0.9830 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 135/150
#
# Epoch 135: val_loss did not improve from 0.06041
# 30/30 - 113s - loss: 0.2347 - accuracy: 0.9133 - val_loss: 0.0675 - val_accuracy: 0.9822 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 136/150
#
# Epoch 136: val_loss did not improve from 0.06041
# 30/30 - 111s - loss: 0.2277 - accuracy: 0.9080 - val_loss: 0.0618 - val_accuracy: 0.9840 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 137/150
#
# Epoch 137: val_loss improved from 0.06041 to 0.05330, saving model to model.h5
# 30/30 - 112s - loss: 0.2351 - accuracy: 0.9133 - val_loss: 0.0533 - val_accuracy: 0.9879 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 138/150
#
# Epoch 138: val_loss did not improve from 0.05330
# 30/30 - 111s - loss: 0.2211 - accuracy: 0.9125 - val_loss: 0.0545 - val_accuracy: 0.9868 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 139/150
#
# Epoch 139: val_loss did not improve from 0.05330
# 30/30 - 110s - loss: 0.2466 - accuracy: 0.9099 - val_loss: 0.0561 - val_accuracy: 0.9843 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 140/150
#
# Epoch 140: val_loss did not improve from 0.05330
# 30/30 - 110s - loss: 0.2318 - accuracy: 0.9085 - val_loss: 0.0668 - val_accuracy: 0.9822 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 141/150
#
# Epoch 141: val_loss did not improve from 0.05330
# 30/30 - 110s - loss: 0.2297 - accuracy: 0.9117 - val_loss: 0.0571 - val_accuracy: 0.9866 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 142/150
#
# Epoch 142: val_loss did not improve from 0.05330
# 30/30 - 112s - loss: 0.2478 - accuracy: 0.9061 - val_loss: 0.0576 - val_accuracy: 0.9843 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 143/150
#
# Epoch 143: val_loss did not improve from 0.05330
# 30/30 - 111s - loss: 0.2546 - accuracy: 0.9045 - val_loss: 0.0594 - val_accuracy: 0.9858 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 144/150
#
# Epoch 144: val_loss improved from 0.05330 to 0.05312, saving model to model.h5
# 30/30 - 113s - loss: 0.2271 - accuracy: 0.9128 - val_loss: 0.0531 - val_accuracy: 0.9884 - lr: 0.0010 - 113s/epoch - 4s/step
# Epoch 145/150
#
# Epoch 145: val_loss did not improve from 0.05312
# 30/30 - 111s - loss: 0.2444 - accuracy: 0.9056 - val_loss: 0.0608 - val_accuracy: 0.9838 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 146/150
#
# Epoch 146: val_loss did not improve from 0.05312
# 30/30 - 112s - loss: 0.2060 - accuracy: 0.9232 - val_loss: 0.0576 - val_accuracy: 0.9830 - lr: 0.0010 - 112s/epoch - 4s/step
# Epoch 147/150
#
# Epoch 147: val_loss did not improve from 0.05312
# 30/30 - 110s - loss: 0.2501 - accuracy: 0.9083 - val_loss: 0.0645 - val_accuracy: 0.9786 - lr: 0.0010 - 110s/epoch - 4s/step
# Epoch 148/150
#
# Epoch 148: val_loss improved from 0.05312 to 0.05174, saving model to model.h5
# 30/30 - 111s - loss: 0.2113 - accuracy: 0.9208 - val_loss: 0.0517 - val_accuracy: 0.9874 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 149/150
#
# Epoch 149: val_loss did not improve from 0.05174
# 30/30 - 111s - loss: 0.2467 - accuracy: 0.9056 - val_loss: 0.0642 - val_accuracy: 0.9825 - lr: 0.0010 - 111s/epoch - 4s/step
# Epoch 150/150
#
# Epoch 150: val_loss did not improve from 0.05174
# 30/30 - 110s - loss: 0.2191 - accuracy: 0.9171 - val_loss: 0.0548 - val_accuracy: 0.9848 - lr: 0.0010 - 110s/epoch - 4s/step

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper left')
plt.show()

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper right')
plt.show()

# %%
model.save('/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/ML_Models/DenseNet_150_epoch/DenseNet121/Case_1_Left_MLO/model.h5')

# %%
ypred = model.predict(xtest)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(ypred)):
    if np.argmax(ypred[i]) == np.argmax(ytest[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Total-test-data; 970 	accurately-predicted-data: 882 	 wrongly-predicted-data:  88
# Accuracy: 90.928 %

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(accurateindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(wrongindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
Ypred = model.predict(xtest)

Ypred = np.argmax(Ypred, axis=1)
Ytrue = np.argmax(ytest, axis=1)

cm = confusion_matrix(Ytrue, Ypred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')
