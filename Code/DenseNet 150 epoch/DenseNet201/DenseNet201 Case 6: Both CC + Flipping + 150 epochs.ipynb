# %%
import tensorflow 

import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import models

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("Tensorflow-version:", tensorflow.__version__)
# Out:
# Tensorflow-version: 2.8.0

# %%
model_d=DenseNet201(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(8,activation='softmax')(x) #FC-layer
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step

# %%
model_d=DenseNet201(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(3,activation='softmax')(x) #FC-layer

# %%
model=Model(inputs=model_d.input,outputs=preds)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 4, 4, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 4, 4, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 4, 4, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 4, 4, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 4, 4, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 4, 4, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 4, 4, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 4, 4, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 4, 4, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 4, 4, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 4, 4, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 4, 4, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 4, 4, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 4, 4, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 4, 4, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 4, 4, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 4, 4, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 4, 4, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 4, 4, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 4, 4, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 4, 4, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 4, 4, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 4, 4, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 4, 4, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 4, 4, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 4, 4, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 4, 4, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 4, 4, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1920)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1920)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1920)        7680        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1920)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1967104     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 20,825,155
# Trainable params: 20,591,235
# Non-trainable params: 233,920
# __________________________________________________________________________________________________

# %%
for layer in model.layers[:-8]:
    layer.trainable=False
    
for layer in model.layers[-8:]:
    layer.trainable=True

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 4, 4, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 4, 4, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 4, 4, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 4, 4, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 4, 4, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 4, 4, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 4, 4, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 4, 4, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 4, 4, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 4, 4, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 4, 4, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 4, 4, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 4, 4, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 4, 4, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 4, 4, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 4, 4, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 4, 4, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 4, 4, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 4, 4, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 4, 4, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 4, 4, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 4, 4, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 4, 4, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 4, 4, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 4, 4, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 4, 4, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 4, 4, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 4, 4, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1920)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1920)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1920)        7680        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1920)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1967104     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 20,825,155
# Trainable params: 2,498,307
# Non-trainable params: 18,326,848
# __________________________________________________________________________________________________

# %%
data=[]
labels=[]
random.seed(42)
# imagePaths = sorted(list(os.listdir("/content/drive/MyDrive/Mini_DDSM_Upload")))
imagePaths = ['Benign','Cancer','Normal']
random.shuffle(imagePaths)
print(imagePaths)
# Out:
# ['Cancer', 'Benign', 'Normal']

# %%
for img in imagePaths:
    path=sorted(list(os.listdir("/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img)))
    for i in path:
      if("CC" in i):
        #Considereing original and flipped image
        for flip in range(2):
          if(flip == 0):
            print("\n****************************************")
            print("Original")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            print(image_path)
            # print("Reading image")
            image = cv2.imread(image_path)
            # print("Imread ", i)
            # # print(image)
            # if('RIGHT' in i):
            #   print("Image is right sided. It has to be flipped")
            #   image = cv2.flip(image,1)
            #   print("Image has been flipped")
              
              #For Rotation
            # height, width = image.shape[:2]
            # center = (width/2, height/2)
            # M = cv2.getRotationMatrix2D(center, angle, 1.0)
            # image = cv2.warpAffine(image, M, (width, height))     
            # print("\nDirectly Resizing image")
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResized Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            # print("Label - ",l)
            labels.append(l)
          else:
            print("\n\n")
            print("FLIPPED")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            # print("Image Path - ",image_path)
            # print("Reading image ",i)
            image = cv2.imread(image_path)
            # print("Flipping Image")
            image = cv2.flip(image,1)
            
            # print("\nResizing the flipped image")
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResizing Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            print("Label - ",l)
            labels.append(l)
        else:
          continue
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2459_A_1963_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2460_A_1963_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2463_A_1964_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2464_A_1964_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2467_A_1965_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2468_A_1965_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2471_A_1966_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2472_A_1966_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2475_A_1967_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2476_A_1967_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2479_A_1968_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/247_A_0089_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2480_A_1968_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2483_A_1969_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2484_A_1969_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2487_A_1970_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2488_A_1970_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/248_A_0089_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2491_A_1971_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2492_A_1971_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2495_A_1972_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2496_A_1972_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2499_A_1973_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/24_A_0010_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2500_A_1973_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2503_A_1974_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2504_A_1974_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2507_A_1975_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2508_A_1975_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2511_A_1976_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2512_A_1976_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2515_A_1977_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2516_A_1977_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2519_A_1978_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/251_A_0090_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2520_A_1978_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2523_A_1979_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2524_A_1979_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2527_A_1980_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2528_A_1980_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/252_A_0090_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2531_A_1988_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2532_A_1988_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2535_A_1989_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2536_A_1989_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2539_A_1990_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2540_A_1990_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2543_A_1991_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2544_A_1991_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2547_A_1992_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2548_A_1992_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2551_A_1993_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2552_A_1993_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2555_A_1994_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2556_A_1994_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2559_A_1995_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/255_A_0091_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2560_A_1995_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2563_A_1996_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2564_A_1996_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2567_A_1997_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2568_A_1997_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/256_A_0091_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2571_A_1998_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2572_A_1998_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2575_A_2002_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2576_A_2002_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2579_A_2003_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2580_A_2003_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2583_A_2004_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2584_A_2004_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2587_A_2005_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2588_A_2005_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2591_A_2006_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2592_A_2006_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2595_A_2007_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2596_A_2007_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2599_A_2008_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/259_A_0092_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2600_A_2008_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2603_A_2009_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2604_A_2009_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2607_A_2010_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2608_A_2010_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/260_A_0092_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2611_A_2011_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2612_A_2011_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2615_A_2012_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2616_A_2012_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2619_A_2013_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2620_A_2013_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2623_A_2014_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2624_A_2014_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2627_A_2015_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2628_A_2015_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2631_A_2016_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2632_A_2016_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2635_A_2017_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2636_A_2017_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2639_A_2018_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/263_A_0093_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2640_A_2018_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2643_A_2019_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2644_A_2019_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2647_A_2020_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2648_A_2020_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/264_A_0093_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2651_A_2021_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2652_A_2021_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2655_A_2023_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2656_A_2023_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2659_A_2024_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2660_A_2024_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2663_A_2026_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2664_A_2026_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2667_A_2027_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2668_A_2027_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2671_A_2028_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2672_A_2028_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2675_A_2029_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2676_A_2029_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2679_A_2030_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/267_A_0094_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2680_A_2030_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2683_A_2031_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2684_A_2031_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2687_A_2032_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2688_A_2032_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/268_A_0094_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2691_A_2033_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2692_A_2033_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2695_A_2034_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2696_A_2034_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2699_A_2035_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2700_A_2035_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2703_A_2036_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2704_A_2036_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2707_A_2037_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2708_A_2037_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2711_A_2038_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2712_A_2038_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2715_A_2039_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2716_A_2039_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2719_A_2040_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/271_A_0095_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2720_A_2040_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2723_A_2041_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2724_A_2041_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2727_A_2042_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2728_A_2042_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/272_A_0095_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/275_A_0096_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/276_A_0096_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/279_A_0097_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/27_A_0011_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/280_A_0097_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/283_A_0099_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/284_A_0099_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/287_A_0108_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/288_A_0108_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/28_A_0011_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/291_A_0109_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/292_A_0109_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/295_A_0110_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/296_A_0110_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/299_A_0111_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/300_A_0111_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/303_A_0112_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/304_A_0112_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/307_A_0114_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/308_A_0114_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/311_A_0115_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/312_A_0115_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/315_A_0116_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/316_A_0116_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/319_A_0119_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/31_A_0012_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/320_A_0119_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/323_A_0121_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/324_A_0121_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/327_A_0123_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/328_A_0123_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/32_A_0012_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/331_A_0124_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/332_A_0124_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/335_A_0126_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/336_A_0126_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/339_A_0127_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/340_A_0127_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/343_A_0128_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/344_A_0128_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/347_A_0130_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/348_A_0130_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/351_A_0131_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/352_A_0131_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/355_A_0133_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/356_A_0133_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/359_A_0135_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/35_A_0013_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/360_A_0135_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/363_A_0136_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/364_A_0136_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/367_A_0137_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/368_A_0137_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/36_A_0013_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/371_A_0139_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/372_A_0139_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/375_A_0142_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/376_A_0142_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/379_A_0143_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/380_A_0143_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/383_A_0144_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/384_A_0144_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/387_A_0145_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/388_A_0145_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/391_A_0146_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/392_A_0146_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/395_A_0147_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/396_A_0147_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/399_A_0148_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/39_A_0014_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/3_A_0002_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/400_A_0148_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/403_A_0149_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/404_A_0149_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/407_A_0150_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/408_A_0150_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/40_A_0014_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/411_A_0151_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/412_A_0151_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/415_A_0152_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/416_A_0152_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/419_A_0154_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/420_A_0154_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/423_A_0155_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/424_A_0155_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/427_A_0156_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/428_A_0156_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/431_A_0157_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/432_A_0157_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/435_A_0158_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/436_A_0158_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/439_A_0159_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/43_A_0015_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/440_A_0159_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/443_A_0200_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/444_A_0200_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/447_A_0201_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/448_A_0201_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/44_A_0015_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/451_A_0202_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/452_A_0202_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/455_A_0203_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/456_A_0203_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/459_A_0204_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/460_A_0204_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/463_A_0205_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/464_A_0205_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/467_A_0206_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/468_A_0206_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/471_A_0207_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/472_A_0207_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/475_A_0208_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/476_A_0208_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/479_A_0209_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/47_A_0016_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# ...
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/840_A_0310_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/843_A_0311_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/844_A_0311_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/847_A_0312_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/848_A_0312_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/84_A_0032_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/851_A_0313_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/852_A_0313_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/855_A_0314_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/856_A_0314_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/859_A_0315_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/860_A_0315_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/863_A_0317_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/864_A_0317_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/867_A_0318_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/868_A_0318_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/871_A_0319_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/872_A_0319_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/875_A_0320_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/876_A_0320_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/879_A_0321_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/87_A_0034_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/880_A_0321_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/883_A_0322_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/884_A_0322_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/887_A_0323_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/888_A_0323_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/88_A_0034_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/891_A_0325_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/892_A_0325_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/895_A_0326_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/896_A_0326_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/899_A_0327_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/8_A_0003_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/900_A_0327_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/903_A_0328_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/904_A_0328_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/907_A_0330_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/908_A_0330_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/911_A_0331_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/912_A_0331_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/915_A_0333_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/916_A_0333_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/919_A_0334_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/91_A_0035_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/920_A_0334_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/923_A_0335_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/924_A_0335_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/927_A_0336_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/928_A_0336_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/92_A_0035_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/931_A_0337_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/932_A_0337_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/935_A_0338_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/936_A_0338_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/939_A_0339_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/940_A_0339_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/943_A_0341_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/944_A_0341_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/947_A_0342_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/948_A_0342_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/951_A_0343_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/952_A_0343_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/955_A_0344_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/956_A_0344_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/959_A_0345_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/95_A_0036_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/960_A_0345_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/963_A_0347_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/964_A_0347_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/967_A_0348_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/968_A_0348_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/96_A_0036_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/971_A_0349_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/972_A_0349_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/975_A_0351_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/976_A_0351_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/979_A_0352_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/980_A_0352_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/983_A_0354_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/984_A_0354_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/987_A_0355_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/988_A_0355_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/991_A_0356_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/992_A_0356_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/995_A_0357_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/996_A_0357_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/999_A_0358_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/99_A_0037_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal

# %%
print("Length of dataset = ",len(labels))
# Out:
# Length of dataset =  9696

# %%
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
print(labels[0])
# Out:
# [0 1 0]

# %%
(xtrain,xtest,ytrain,ytest)=train_test_split(data,labels,test_size=0.2,random_state=42)
print(xtrain.shape, xtest.shape)
# Out:
# (7756, 128, 128, 3) (1940, 128, 128, 3)

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)


datagen.fit(xtrain)
# Fits-the-model
history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=128),
               steps_per_epoch=xtrain.shape[0] //128,
               epochs=150, #try 100
               verbose=2,
               callbacks=[anne, checkpoint],
               validation_data=(xtrain, ytrain))
# Out:
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 0.90943, saving model to model.h5
# 60/60 - 57s - loss: 1.3625 - accuracy: 0.5325 - val_loss: 0.9094 - val_accuracy: 0.5721 - lr: 0.0010 - 57s/epoch - 954ms/step
# Epoch 2/150
#
# Epoch 2: val_loss improved from 0.90943 to 0.72601, saving model to model.h5
# 60/60 - 34s - loss: 1.0024 - accuracy: 0.5730 - val_loss: 0.7260 - val_accuracy: 0.6498 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 3/150
#
# Epoch 3: val_loss improved from 0.72601 to 0.70567, saving model to model.h5
# 60/60 - 34s - loss: 0.8659 - accuracy: 0.6085 - val_loss: 0.7057 - val_accuracy: 0.6501 - lr: 0.0010 - 34s/epoch - 565ms/step
# Epoch 4/150
#
# Epoch 4: val_loss improved from 0.70567 to 0.64651, saving model to model.h5
# 60/60 - 34s - loss: 0.7958 - accuracy: 0.6310 - val_loss: 0.6465 - val_accuracy: 0.7082 - lr: 0.0010 - 34s/epoch - 566ms/step
# Epoch 5/150
#
# Epoch 5: val_loss improved from 0.64651 to 0.62289, saving model to model.h5
# 60/60 - 35s - loss: 0.7632 - accuracy: 0.6445 - val_loss: 0.6229 - val_accuracy: 0.7228 - lr: 0.0010 - 35s/epoch - 577ms/step
# Epoch 6/150
#
# Epoch 6: val_loss improved from 0.62289 to 0.60863, saving model to model.h5
# 60/60 - 34s - loss: 0.7568 - accuracy: 0.6386 - val_loss: 0.6086 - val_accuracy: 0.7317 - lr: 0.0010 - 34s/epoch - 574ms/step
# Epoch 7/150
#
# Epoch 7: val_loss improved from 0.60863 to 0.59105, saving model to model.h5
# 60/60 - 34s - loss: 0.7256 - accuracy: 0.6614 - val_loss: 0.5911 - val_accuracy: 0.7392 - lr: 0.0010 - 34s/epoch - 564ms/step
# Epoch 8/150
#
# Epoch 8: val_loss improved from 0.59105 to 0.57638, saving model to model.h5
# 60/60 - 34s - loss: 0.6986 - accuracy: 0.6741 - val_loss: 0.5764 - val_accuracy: 0.7491 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 9/150
#
# Epoch 9: val_loss improved from 0.57638 to 0.56565, saving model to model.h5
# 60/60 - 34s - loss: 0.6960 - accuracy: 0.6755 - val_loss: 0.5656 - val_accuracy: 0.7503 - lr: 0.0010 - 34s/epoch - 566ms/step
# Epoch 10/150
#
# Epoch 10: val_loss improved from 0.56565 to 0.55717, saving model to model.h5
# 60/60 - 34s - loss: 0.6853 - accuracy: 0.6807 - val_loss: 0.5572 - val_accuracy: 0.7524 - lr: 0.0010 - 34s/epoch - 565ms/step
# Epoch 11/150
#
# Epoch 11: val_loss improved from 0.55717 to 0.50888, saving model to model.h5
# 60/60 - 34s - loss: 0.6766 - accuracy: 0.6921 - val_loss: 0.5089 - val_accuracy: 0.7935 - lr: 0.0010 - 34s/epoch - 573ms/step
# Epoch 12/150
#
# Epoch 12: val_loss improved from 0.50888 to 0.50123, saving model to model.h5
# 60/60 - 34s - loss: 0.6594 - accuracy: 0.6923 - val_loss: 0.5012 - val_accuracy: 0.7924 - lr: 0.0010 - 34s/epoch - 569ms/step
# Epoch 13/150
#
# Epoch 13: val_loss did not improve from 0.50123
# 60/60 - 33s - loss: 0.6483 - accuracy: 0.7002 - val_loss: 0.5156 - val_accuracy: 0.7860 - lr: 0.0010 - 33s/epoch - 551ms/step
# Epoch 14/150
#
# Epoch 14: val_loss did not improve from 0.50123
# 60/60 - 33s - loss: 0.6492 - accuracy: 0.7031 - val_loss: 0.5419 - val_accuracy: 0.7628 - lr: 0.0010 - 33s/epoch - 553ms/step
# Epoch 15/150
#
# Epoch 15: val_loss improved from 0.50123 to 0.46156, saving model to model.h5
# 60/60 - 34s - loss: 0.6456 - accuracy: 0.7036 - val_loss: 0.4616 - val_accuracy: 0.8128 - lr: 0.0010 - 34s/epoch - 562ms/step
# Epoch 16/150
#
# Epoch 16: val_loss improved from 0.46156 to 0.44323, saving model to model.h5
# 60/60 - 34s - loss: 0.6244 - accuracy: 0.7234 - val_loss: 0.4432 - val_accuracy: 0.8194 - lr: 0.0010 - 34s/epoch - 569ms/step
# Epoch 17/150
#
# Epoch 17: val_loss did not improve from 0.44323
# 60/60 - 33s - loss: 0.6328 - accuracy: 0.7122 - val_loss: 0.4536 - val_accuracy: 0.8146 - lr: 0.0010 - 33s/epoch - 552ms/step
# Epoch 18/150
#
# Epoch 18: val_loss improved from 0.44323 to 0.42657, saving model to model.h5
# 60/60 - 34s - loss: 0.6053 - accuracy: 0.7238 - val_loss: 0.4266 - val_accuracy: 0.8330 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 19/150
#
# Epoch 19: val_loss did not improve from 0.42657
# 60/60 - 33s - loss: 0.6065 - accuracy: 0.7290 - val_loss: 0.4285 - val_accuracy: 0.8150 - lr: 0.0010 - 33s/epoch - 548ms/step
# Epoch 20/150
#
# Epoch 20: val_loss improved from 0.42657 to 0.42068, saving model to model.h5
# 60/60 - 34s - loss: 0.6008 - accuracy: 0.7261 - val_loss: 0.4207 - val_accuracy: 0.8310 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 21/150
#
# Epoch 21: val_loss improved from 0.42068 to 0.39946, saving model to model.h5
# 60/60 - 34s - loss: 0.5846 - accuracy: 0.7343 - val_loss: 0.3995 - val_accuracy: 0.8431 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 22/150
#
# Epoch 22: val_loss improved from 0.39946 to 0.38629, saving model to model.h5
# 60/60 - 34s - loss: 0.5830 - accuracy: 0.7389 - val_loss: 0.3863 - val_accuracy: 0.8568 - lr: 0.0010 - 34s/epoch - 565ms/step
# Epoch 23/150
#
# Epoch 23: val_loss did not improve from 0.38629
# 60/60 - 33s - loss: 0.5623 - accuracy: 0.7526 - val_loss: 0.4241 - val_accuracy: 0.8268 - lr: 0.0010 - 33s/epoch - 547ms/step
# Epoch 24/150
#
# Epoch 24: val_loss did not improve from 0.38629
# 60/60 - 33s - loss: 0.5628 - accuracy: 0.7558 - val_loss: 0.4042 - val_accuracy: 0.8307 - lr: 0.0010 - 33s/epoch - 545ms/step
# Epoch 25/150
#
# Epoch 25: val_loss improved from 0.38629 to 0.34955, saving model to model.h5
# 60/60 - 34s - loss: 0.5554 - accuracy: 0.7568 - val_loss: 0.3495 - val_accuracy: 0.8684 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 26/150
#
# Epoch 26: val_loss improved from 0.34955 to 0.34267, saving model to model.h5
# 60/60 - 34s - loss: 0.5351 - accuracy: 0.7661 - val_loss: 0.3427 - val_accuracy: 0.8755 - lr: 0.0010 - 34s/epoch - 566ms/step
# Epoch 27/150
#
# Epoch 27: val_loss improved from 0.34267 to 0.33161, saving model to model.h5
# 60/60 - 34s - loss: 0.5539 - accuracy: 0.7576 - val_loss: 0.3316 - val_accuracy: 0.8793 - lr: 0.0010 - 34s/epoch - 559ms/step
# Epoch 28/150
#
# Epoch 28: val_loss did not improve from 0.33161
# 60/60 - 33s - loss: 0.5218 - accuracy: 0.7758 - val_loss: 0.3355 - val_accuracy: 0.8713 - lr: 0.0010 - 33s/epoch - 558ms/step
# Epoch 29/150
#
# Epoch 29: val_loss improved from 0.33161 to 0.31444, saving model to model.h5
# 60/60 - 34s - loss: 0.5294 - accuracy: 0.7693 - val_loss: 0.3144 - val_accuracy: 0.8869 - lr: 0.0010 - 34s/epoch - 562ms/step
# Epoch 30/150
#
# Epoch 30: val_loss did not improve from 0.31444
# 60/60 - 33s - loss: 0.5035 - accuracy: 0.7825 - val_loss: 0.3300 - val_accuracy: 0.8739 - lr: 0.0010 - 33s/epoch - 547ms/step
# Epoch 31/150
#
# Epoch 31: val_loss improved from 0.31444 to 0.29377, saving model to model.h5
# 60/60 - 34s - loss: 0.5070 - accuracy: 0.7840 - val_loss: 0.2938 - val_accuracy: 0.8987 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 32/150
#
# Epoch 32: val_loss did not improve from 0.29377
# 60/60 - 33s - loss: 0.4902 - accuracy: 0.7881 - val_loss: 0.3090 - val_accuracy: 0.8940 - lr: 0.0010 - 33s/epoch - 544ms/step
# Epoch 33/150
#
# Epoch 33: val_loss improved from 0.29377 to 0.28605, saving model to model.h5
# 60/60 - 34s - loss: 0.4882 - accuracy: 0.7960 - val_loss: 0.2860 - val_accuracy: 0.8930 - lr: 0.0010 - 34s/epoch - 574ms/step
# Epoch 34/150
#
# Epoch 34: val_loss did not improve from 0.28605
# 60/60 - 33s - loss: 0.4867 - accuracy: 0.7955 - val_loss: 0.2987 - val_accuracy: 0.8935 - lr: 0.0010 - 33s/epoch - 543ms/step
# Epoch 35/150
#
# Epoch 35: val_loss did not improve from 0.28605
# 60/60 - 33s - loss: 0.4768 - accuracy: 0.7948 - val_loss: 0.2887 - val_accuracy: 0.8972 - lr: 0.0010 - 33s/epoch - 547ms/step
# Epoch 36/150
#
# Epoch 36: val_loss improved from 0.28605 to 0.27516, saving model to model.h5
# 60/60 - 34s - loss: 0.4619 - accuracy: 0.8115 - val_loss: 0.2752 - val_accuracy: 0.8999 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 37/150
#
# Epoch 37: val_loss improved from 0.27516 to 0.26811, saving model to model.h5
# 60/60 - 34s - loss: 0.4728 - accuracy: 0.8017 - val_loss: 0.2681 - val_accuracy: 0.9051 - lr: 0.0010 - 34s/epoch - 567ms/step
# Epoch 38/150
#
# Epoch 38: val_loss improved from 0.26811 to 0.24706, saving model to model.h5
# 60/60 - 34s - loss: 0.4544 - accuracy: 0.8095 - val_loss: 0.2471 - val_accuracy: 0.9134 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 39/150
#
# Epoch 39: val_loss improved from 0.24706 to 0.23939, saving model to model.h5
# 60/60 - 34s - loss: 0.4314 - accuracy: 0.8212 - val_loss: 0.2394 - val_accuracy: 0.9244 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 40/150
#
# Epoch 40: val_loss improved from 0.23939 to 0.23358, saving model to model.h5
# 60/60 - 34s - loss: 0.4451 - accuracy: 0.8133 - val_loss: 0.2336 - val_accuracy: 0.9306 - lr: 0.0010 - 34s/epoch - 569ms/step
# Epoch 41/150
#
# Epoch 41: val_loss improved from 0.23358 to 0.22821, saving model to model.h5
# 60/60 - 34s - loss: 0.4307 - accuracy: 0.8199 - val_loss: 0.2282 - val_accuracy: 0.9282 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 42/150
#
# Epoch 42: val_loss improved from 0.22821 to 0.22531, saving model to model.h5
# 60/60 - 34s - loss: 0.4408 - accuracy: 0.8191 - val_loss: 0.2253 - val_accuracy: 0.9230 - lr: 0.0010 - 34s/epoch - 569ms/step
# Epoch 43/150
#
# Epoch 43: val_loss improved from 0.22531 to 0.21217, saving model to model.h5
# 60/60 - 34s - loss: 0.4311 - accuracy: 0.8283 - val_loss: 0.2122 - val_accuracy: 0.9314 - lr: 0.0010 - 34s/epoch - 563ms/step
# Epoch 44/150
#
# Epoch 44: val_loss did not improve from 0.21217
# 60/60 - 33s - loss: 0.4205 - accuracy: 0.8267 - val_loss: 0.2243 - val_accuracy: 0.9228 - lr: 0.0010 - 33s/epoch - 545ms/step
# Epoch 45/150
#
# Epoch 45: val_loss did not improve from 0.21217
# 60/60 - 33s - loss: 0.4192 - accuracy: 0.8246 - val_loss: 0.2144 - val_accuracy: 0.9284 - lr: 0.0010 - 33s/epoch - 548ms/step
# Epoch 46/150
#
# Epoch 46: val_loss improved from 0.21217 to 0.20650, saving model to model.h5
# 60/60 - 34s - loss: 0.4027 - accuracy: 0.8352 - val_loss: 0.2065 - val_accuracy: 0.9309 - lr: 0.0010 - 34s/epoch - 574ms/step
# Epoch 47/150
#
# Epoch 47: val_loss did not improve from 0.20650
# 60/60 - 33s - loss: 0.3951 - accuracy: 0.8347 - val_loss: 0.2316 - val_accuracy: 0.9139 - lr: 0.0010 - 33s/epoch - 550ms/step
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.20650 to 0.17975, saving model to model.h5
# 60/60 - 34s - loss: 0.3923 - accuracy: 0.8330 - val_loss: 0.1797 - val_accuracy: 0.9443 - lr: 0.0010 - 34s/epoch - 564ms/step
# Epoch 49/150
#
# Epoch 49: val_loss did not improve from 0.17975
# 60/60 - 33s - loss: 0.3916 - accuracy: 0.8408 - val_loss: 0.1842 - val_accuracy: 0.9419 - lr: 0.0010 - 33s/epoch - 543ms/step
# Epoch 50/150
#
# Epoch 50: val_loss did not improve from 0.17975
# 60/60 - 33s - loss: 0.3839 - accuracy: 0.8429 - val_loss: 0.1848 - val_accuracy: 0.9407 - lr: 0.0010 - 33s/epoch - 555ms/step
# Epoch 51/150
#
# Epoch 51: val_loss did not improve from 0.17975
# 60/60 - 33s - loss: 0.3909 - accuracy: 0.8343 - val_loss: 0.1866 - val_accuracy: 0.9402 - lr: 0.0010 - 33s/epoch - 547ms/step
# Epoch 52/150
#
# Epoch 52: val_loss did not improve from 0.17975
# 60/60 - 34s - loss: 0.3853 - accuracy: 0.8408 - val_loss: 0.1948 - val_accuracy: 0.9391 - lr: 0.0010 - 34s/epoch - 558ms/step
# Epoch 53/150
#
# Epoch 53: val_loss did not improve from 0.17975
# 60/60 - 33s - loss: 0.3983 - accuracy: 0.8357 - val_loss: 0.2013 - val_accuracy: 0.9321 - lr: 0.0010 - 33s/epoch - 550ms/step
# Epoch 54/150
#
# Epoch 54: val_loss improved from 0.17975 to 0.17756, saving model to model.h5
# 60/60 - 34s - loss: 0.3680 - accuracy: 0.8496 - val_loss: 0.1776 - val_accuracy: 0.9398 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 55/150
#
# Epoch 55: val_loss improved from 0.17756 to 0.17578, saving model to model.h5
# 60/60 - 35s - loss: 0.3523 - accuracy: 0.8599 - val_loss: 0.1758 - val_accuracy: 0.9395 - lr: 0.0010 - 35s/epoch - 577ms/step
# Epoch 56/150
#
# Epoch 56: val_loss improved from 0.17578 to 0.17126, saving model to model.h5
# 60/60 - 34s - loss: 0.3690 - accuracy: 0.8547 - val_loss: 0.1713 - val_accuracy: 0.9492 - lr: 0.0010 - 34s/epoch - 563ms/step
# Epoch 57/150
#
# Epoch 57: val_loss improved from 0.17126 to 0.16570, saving model to model.h5
# 60/60 - 34s - loss: 0.3713 - accuracy: 0.8529 - val_loss: 0.1657 - val_accuracy: 0.9532 - lr: 0.0010 - 34s/epoch - 572ms/step
# Epoch 58/150
#
# Epoch 58: val_loss did not improve from 0.16570
# 60/60 - 33s - loss: 0.3504 - accuracy: 0.8627 - val_loss: 0.1671 - val_accuracy: 0.9469 - lr: 0.0010 - 33s/epoch - 552ms/step
# Epoch 59/150
#
# Epoch 59: val_loss improved from 0.16570 to 0.16551, saving model to model.h5
# 60/60 - 34s - loss: 0.3486 - accuracy: 0.8582 - val_loss: 0.1655 - val_accuracy: 0.9489 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 60/150
#
# Epoch 60: val_loss improved from 0.16551 to 0.15783, saving model to model.h5
# 60/60 - 34s - loss: 0.3589 - accuracy: 0.8554 - val_loss: 0.1578 - val_accuracy: 0.9524 - lr: 0.0010 - 34s/epoch - 575ms/step
# Epoch 61/150
#
# Epoch 61: val_loss improved from 0.15783 to 0.12812, saving model to model.h5
# 60/60 - 34s - loss: 0.3250 - accuracy: 0.8672 - val_loss: 0.1281 - val_accuracy: 0.9631 - lr: 0.0010 - 34s/epoch - 564ms/step
# Epoch 62/150
#
# Epoch 62: val_loss did not improve from 0.12812
# 60/60 - 33s - loss: 0.3281 - accuracy: 0.8698 - val_loss: 0.1460 - val_accuracy: 0.9562 - lr: 0.0010 - 33s/epoch - 545ms/step
# Epoch 63/150
#
# Epoch 63: val_loss did not improve from 0.12812
# 60/60 - 33s - loss: 0.3342 - accuracy: 0.8651 - val_loss: 0.1418 - val_accuracy: 0.9540 - lr: 0.0010 - 33s/epoch - 544ms/step
# Epoch 64/150
#
# Epoch 64: val_loss did not improve from 0.12812
# 60/60 - 33s - loss: 0.3313 - accuracy: 0.8660 - val_loss: 0.1314 - val_accuracy: 0.9621 - lr: 0.0010 - 33s/epoch - 549ms/step
# Epoch 65/150
#
# Epoch 65: val_loss did not improve from 0.12812
# 60/60 - 33s - loss: 0.3287 - accuracy: 0.8709 - val_loss: 0.1402 - val_accuracy: 0.9569 - lr: 0.0010 - 33s/epoch - 554ms/step
# Epoch 66/150
#
# Epoch 66: val_loss did not improve from 0.12812
# 60/60 - 33s - loss: 0.3139 - accuracy: 0.8736 - val_loss: 0.1351 - val_accuracy: 0.9626 - lr: 0.0010 - 33s/epoch - 552ms/step
# Epoch 67/150
#
# Epoch 67: val_loss improved from 0.12812 to 0.12741, saving model to model.h5
# 60/60 - 34s - loss: 0.3229 - accuracy: 0.8677 - val_loss: 0.1274 - val_accuracy: 0.9620 - lr: 0.0010 - 34s/epoch - 571ms/step
# Epoch 68/150
#
# Epoch 68: val_loss improved from 0.12741 to 0.12208, saving model to model.h5
# 60/60 - 34s - loss: 0.3125 - accuracy: 0.8758 - val_loss: 0.1221 - val_accuracy: 0.9652 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 69/150
#
# Epoch 69: val_loss improved from 0.12208 to 0.11917, saving model to model.h5
# 60/60 - 34s - loss: 0.3058 - accuracy: 0.8802 - val_loss: 0.1192 - val_accuracy: 0.9642 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 70/150
#
# Epoch 70: val_loss did not improve from 0.11917
# 60/60 - 33s - loss: 0.3161 - accuracy: 0.8722 - val_loss: 0.1372 - val_accuracy: 0.9535 - lr: 0.0010 - 33s/epoch - 549ms/step
# Epoch 71/150
#
# Epoch 71: val_loss did not improve from 0.11917
# 60/60 - 33s - loss: 0.3063 - accuracy: 0.8743 - val_loss: 0.1204 - val_accuracy: 0.9613 - lr: 0.0010 - 33s/epoch - 549ms/step
# Epoch 72/150
#
# Epoch 72: val_loss improved from 0.11917 to 0.11752, saving model to model.h5
# 60/60 - 34s - loss: 0.3018 - accuracy: 0.8772 - val_loss: 0.1175 - val_accuracy: 0.9671 - lr: 0.0010 - 34s/epoch - 569ms/step
# Epoch 73/150
#
# Epoch 73: val_loss improved from 0.11752 to 0.11455, saving model to model.h5
# 60/60 - 35s - loss: 0.2901 - accuracy: 0.8846 - val_loss: 0.1146 - val_accuracy: 0.9665 - lr: 0.0010 - 35s/epoch - 585ms/step
# Epoch 74/150
#
# Epoch 74: val_loss improved from 0.11455 to 0.10811, saving model to model.h5
# 60/60 - 34s - loss: 0.2977 - accuracy: 0.8802 - val_loss: 0.1081 - val_accuracy: 0.9712 - lr: 0.0010 - 34s/epoch - 566ms/step
# Epoch 75/150
#
# Epoch 75: val_loss did not improve from 0.10811
# 60/60 - 33s - loss: 0.2919 - accuracy: 0.8846 - val_loss: 0.1111 - val_accuracy: 0.9685 - lr: 0.0010 - 33s/epoch - 550ms/step
# Epoch 76/150
#
# Epoch 76: val_loss improved from 0.10811 to 0.10802, saving model to model.h5
# 60/60 - 34s - loss: 0.2873 - accuracy: 0.8856 - val_loss: 0.1080 - val_accuracy: 0.9709 - lr: 0.0010 - 34s/epoch - 569ms/step
# Epoch 77/150
#
# Epoch 77: val_loss did not improve from 0.10802
# 60/60 - 33s - loss: 0.2892 - accuracy: 0.8871 - val_loss: 0.1151 - val_accuracy: 0.9642 - lr: 0.0010 - 33s/epoch - 554ms/step
# Epoch 78/150
#
# Epoch 78: val_loss did not improve from 0.10802
# 60/60 - 33s - loss: 0.2740 - accuracy: 0.8894 - val_loss: 0.1092 - val_accuracy: 0.9643 - lr: 0.0010 - 33s/epoch - 553ms/step
# Epoch 79/150
#
# Epoch 79: val_loss improved from 0.10802 to 0.10419, saving model to model.h5
# 60/60 - 34s - loss: 0.2815 - accuracy: 0.8867 - val_loss: 0.1042 - val_accuracy: 0.9693 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 80/150
#
# Epoch 80: val_loss improved from 0.10419 to 0.10132, saving model to model.h5
# 60/60 - 34s - loss: 0.2786 - accuracy: 0.8897 - val_loss: 0.1013 - val_accuracy: 0.9729 - lr: 0.0010 - 34s/epoch - 567ms/step
# Epoch 81/150
#
# Epoch 81: val_loss did not improve from 0.10132
# 60/60 - 33s - loss: 0.2743 - accuracy: 0.8915 - val_loss: 0.1089 - val_accuracy: 0.9703 - lr: 0.0010 - 33s/epoch - 551ms/step
# Epoch 82/150
#
# Epoch 82: val_loss improved from 0.10132 to 0.09674, saving model to model.h5
# 60/60 - 34s - loss: 0.2746 - accuracy: 0.8939 - val_loss: 0.0967 - val_accuracy: 0.9729 - lr: 0.0010 - 34s/epoch - 569ms/step
# Epoch 83/150
#
# Epoch 83: val_loss improved from 0.09674 to 0.08967, saving model to model.h5
# 60/60 - 34s - loss: 0.2678 - accuracy: 0.8938 - val_loss: 0.0897 - val_accuracy: 0.9776 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 84/150
#
# Epoch 84: val_loss did not improve from 0.08967
# 60/60 - 33s - loss: 0.2542 - accuracy: 0.9050 - val_loss: 0.0915 - val_accuracy: 0.9745 - lr: 0.0010 - 33s/epoch - 549ms/step
# Epoch 85/150
#
# Epoch 85: val_loss improved from 0.08967 to 0.08497, saving model to model.h5
# 60/60 - 34s - loss: 0.2531 - accuracy: 0.8983 - val_loss: 0.0850 - val_accuracy: 0.9768 - lr: 0.0010 - 34s/epoch - 567ms/step
# Epoch 86/150
#
# Epoch 86: val_loss did not improve from 0.08497
# 60/60 - 33s - loss: 0.2652 - accuracy: 0.8946 - val_loss: 0.0900 - val_accuracy: 0.9763 - lr: 0.0010 - 33s/epoch - 554ms/step
# Epoch 87/150
#
# Epoch 87: val_loss did not improve from 0.08497
# 60/60 - 33s - loss: 0.2619 - accuracy: 0.8955 - val_loss: 0.0878 - val_accuracy: 0.9754 - lr: 0.0010 - 33s/epoch - 546ms/step
# Epoch 88/150
#
# Epoch 88: val_loss did not improve from 0.08497
# 60/60 - 33s - loss: 0.2612 - accuracy: 0.8975 - val_loss: 0.0863 - val_accuracy: 0.9774 - lr: 0.0010 - 33s/epoch - 548ms/step
# Epoch 89/150
#
# Epoch 89: val_loss did not improve from 0.08497
# 60/60 - 33s - loss: 0.2505 - accuracy: 0.9025 - val_loss: 0.0911 - val_accuracy: 0.9732 - lr: 0.0010 - 33s/epoch - 550ms/step
# Epoch 90/150
#
# Epoch 90: val_loss improved from 0.08497 to 0.08442, saving model to model.h5
# 60/60 - 34s - loss: 0.2522 - accuracy: 0.8995 - val_loss: 0.0844 - val_accuracy: 0.9786 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 91/150
#
# Epoch 91: val_loss improved from 0.08442 to 0.08246, saving model to model.h5
# 60/60 - 34s - loss: 0.2530 - accuracy: 0.8998 - val_loss: 0.0825 - val_accuracy: 0.9782 - lr: 0.0010 - 34s/epoch - 571ms/step
# Epoch 92/150
#
# Epoch 92: val_loss did not improve from 0.08246
# 60/60 - 33s - loss: 0.2562 - accuracy: 0.9010 - val_loss: 0.0879 - val_accuracy: 0.9725 - lr: 0.0010 - 33s/epoch - 551ms/step
# Epoch 93/150
#
# Epoch 93: val_loss did not improve from 0.08246
# 60/60 - 33s - loss: 0.2518 - accuracy: 0.9014 - val_loss: 0.0867 - val_accuracy: 0.9764 - lr: 0.0010 - 33s/epoch - 552ms/step
# Epoch 94/150
#
# Epoch 94: val_loss improved from 0.08246 to 0.07336, saving model to model.h5
# 60/60 - 34s - loss: 0.2405 - accuracy: 0.9047 - val_loss: 0.0734 - val_accuracy: 0.9799 - lr: 0.0010 - 34s/epoch - 569ms/step
# Epoch 95/150
#
# Epoch 95: val_loss did not improve from 0.07336
# 60/60 - 33s - loss: 0.2310 - accuracy: 0.9136 - val_loss: 0.0758 - val_accuracy: 0.9789 - lr: 0.0010 - 33s/epoch - 557ms/step
# Epoch 96/150
#
# Epoch 96: val_loss did not improve from 0.07336
# 60/60 - 33s - loss: 0.2361 - accuracy: 0.9089 - val_loss: 0.0743 - val_accuracy: 0.9801 - lr: 0.0010 - 33s/epoch - 549ms/step
# Epoch 97/150
#
# Epoch 97: val_loss improved from 0.07336 to 0.07269, saving model to model.h5
# 60/60 - 34s - loss: 0.2462 - accuracy: 0.9056 - val_loss: 0.0727 - val_accuracy: 0.9816 - lr: 0.0010 - 34s/epoch - 571ms/step
# Epoch 98/150
#
# Epoch 98: val_loss did not improve from 0.07269
# 60/60 - 33s - loss: 0.2328 - accuracy: 0.9116 - val_loss: 0.0791 - val_accuracy: 0.9747 - lr: 0.0010 - 33s/epoch - 553ms/step
# Epoch 99/150
#
# Epoch 99: val_loss did not improve from 0.07269
# 60/60 - 33s - loss: 0.2415 - accuracy: 0.9107 - val_loss: 0.0751 - val_accuracy: 0.9780 - lr: 0.0010 - 33s/epoch - 544ms/step
# Epoch 100/150
#
# Epoch 100: val_loss did not improve from 0.07269
# 60/60 - 33s - loss: 0.2311 - accuracy: 0.9115 - val_loss: 0.0855 - val_accuracy: 0.9751 - lr: 0.0010 - 33s/epoch - 549ms/step
# Epoch 101/150
#
# Epoch 101: val_loss improved from 0.07269 to 0.07114, saving model to model.h5
# 60/60 - 34s - loss: 0.2278 - accuracy: 0.9102 - val_loss: 0.0711 - val_accuracy: 0.9804 - lr: 0.0010 - 34s/epoch - 563ms/step
# Epoch 102/150
#
# Epoch 102: val_loss did not improve from 0.07114
# 60/60 - 33s - loss: 0.2249 - accuracy: 0.9137 - val_loss: 0.0721 - val_accuracy: 0.9801 - lr: 0.0010 - 33s/epoch - 556ms/step
# Epoch 103/150
#
# Epoch 103: val_loss did not improve from 0.07114
# 60/60 - 33s - loss: 0.2223 - accuracy: 0.9137 - val_loss: 0.0736 - val_accuracy: 0.9785 - lr: 0.0010 - 33s/epoch - 549ms/step
# Epoch 104/150
#
# Epoch 104: val_loss did not improve from 0.07114
# 60/60 - 33s - loss: 0.2201 - accuracy: 0.9158 - val_loss: 0.0790 - val_accuracy: 0.9767 - lr: 0.0010 - 33s/epoch - 543ms/step
# Epoch 105/150
#
# Epoch 105: val_loss improved from 0.07114 to 0.06763, saving model to model.h5
# 60/60 - 34s - loss: 0.2373 - accuracy: 0.9088 - val_loss: 0.0676 - val_accuracy: 0.9826 - lr: 0.0010 - 34s/epoch - 572ms/step
# Epoch 106/150
#
# Epoch 106: val_loss did not improve from 0.06763
# 60/60 - 33s - loss: 0.2373 - accuracy: 0.9101 - val_loss: 0.0723 - val_accuracy: 0.9809 - lr: 0.0010 - 33s/epoch - 543ms/step
# Epoch 107/150
#
# Epoch 107: val_loss improved from 0.06763 to 0.06727, saving model to model.h5
# 60/60 - 34s - loss: 0.2165 - accuracy: 0.9173 - val_loss: 0.0673 - val_accuracy: 0.9831 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 108/150
#
# Epoch 108: val_loss improved from 0.06727 to 0.06492, saving model to model.h5
# 60/60 - 35s - loss: 0.2186 - accuracy: 0.9162 - val_loss: 0.0649 - val_accuracy: 0.9809 - lr: 0.0010 - 35s/epoch - 578ms/step
# Epoch 109/150
#
# Epoch 109: val_loss improved from 0.06492 to 0.06179, saving model to model.h5
# 60/60 - 34s - loss: 0.2085 - accuracy: 0.9182 - val_loss: 0.0618 - val_accuracy: 0.9831 - lr: 0.0010 - 34s/epoch - 564ms/step
# Epoch 110/150
#
# Epoch 110: val_loss improved from 0.06179 to 0.06142, saving model to model.h5
# 60/60 - 34s - loss: 0.2056 - accuracy: 0.9240 - val_loss: 0.0614 - val_accuracy: 0.9831 - lr: 0.0010 - 34s/epoch - 567ms/step
# Epoch 111/150
#
# Epoch 111: val_loss did not improve from 0.06142
# 60/60 - 33s - loss: 0.2127 - accuracy: 0.9174 - val_loss: 0.0654 - val_accuracy: 0.9821 - lr: 0.0010 - 33s/epoch - 542ms/step
# Epoch 112/150
#
# Epoch 112: val_loss did not improve from 0.06142
# 60/60 - 33s - loss: 0.2305 - accuracy: 0.9123 - val_loss: 0.0627 - val_accuracy: 0.9835 - lr: 0.0010 - 33s/epoch - 547ms/step
# Epoch 113/150
#
# Epoch 113: val_loss did not improve from 0.06142
# 60/60 - 33s - loss: 0.2150 - accuracy: 0.9215 - val_loss: 0.0686 - val_accuracy: 0.9822 - lr: 0.0010 - 33s/epoch - 553ms/step
# Epoch 114/150
#
# Epoch 114: val_loss improved from 0.06142 to 0.05986, saving model to model.h5
# 60/60 - 34s - loss: 0.2137 - accuracy: 0.9196 - val_loss: 0.0599 - val_accuracy: 0.9853 - lr: 0.0010 - 34s/epoch - 572ms/step
# Epoch 115/150
#
# Epoch 115: val_loss did not improve from 0.05986
# 60/60 - 33s - loss: 0.2152 - accuracy: 0.9211 - val_loss: 0.0634 - val_accuracy: 0.9822 - lr: 0.0010 - 33s/epoch - 554ms/step
# Epoch 116/150
#
# Epoch 116: val_loss improved from 0.05986 to 0.05623, saving model to model.h5
# 60/60 - 34s - loss: 0.2110 - accuracy: 0.9173 - val_loss: 0.0562 - val_accuracy: 0.9865 - lr: 0.0010 - 34s/epoch - 564ms/step
# Epoch 117/150
#
# Epoch 117: val_loss did not improve from 0.05623
# 60/60 - 33s - loss: 0.2020 - accuracy: 0.9246 - val_loss: 0.0577 - val_accuracy: 0.9852 - lr: 0.0010 - 33s/epoch - 551ms/step
# Epoch 118/150
#
# Epoch 118: val_loss improved from 0.05623 to 0.05513, saving model to model.h5
# 60/60 - 34s - loss: 0.1986 - accuracy: 0.9241 - val_loss: 0.0551 - val_accuracy: 0.9858 - lr: 0.0010 - 34s/epoch - 565ms/step
# Epoch 119/150
#
# Epoch 119: val_loss did not improve from 0.05513
# 60/60 - 33s - loss: 0.2015 - accuracy: 0.9245 - val_loss: 0.0556 - val_accuracy: 0.9843 - lr: 0.0010 - 33s/epoch - 550ms/step
# Epoch 120/150
#
# Epoch 120: val_loss improved from 0.05513 to 0.05155, saving model to model.h5
# 60/60 - 34s - loss: 0.2038 - accuracy: 0.9223 - val_loss: 0.0515 - val_accuracy: 0.9859 - lr: 0.0010 - 34s/epoch - 568ms/step
# Epoch 121/150
#
# Epoch 121: val_loss did not improve from 0.05155
# 60/60 - 33s - loss: 0.2023 - accuracy: 0.9224 - val_loss: 0.0554 - val_accuracy: 0.9857 - lr: 0.0010 - 33s/epoch - 551ms/step
# Epoch 122/150
#
# Epoch 122: val_loss did not improve from 0.05155
# 60/60 - 33s - loss: 0.2010 - accuracy: 0.9251 - val_loss: 0.0571 - val_accuracy: 0.9821 - lr: 0.0010 - 33s/epoch - 550ms/step
# Epoch 123/150
#
# Epoch 123: val_loss did not improve from 0.05155
# 60/60 - 33s - loss: 0.1914 - accuracy: 0.9278 - val_loss: 0.0591 - val_accuracy: 0.9821 - lr: 0.0010 - 33s/epoch - 543ms/step
# Epoch 124/150
#
# Epoch 124: val_loss improved from 0.05155 to 0.04648, saving model to model.h5
# 60/60 - 34s - loss: 0.2058 - accuracy: 0.9219 - val_loss: 0.0465 - val_accuracy: 0.9883 - lr: 0.0010 - 34s/epoch - 571ms/step
# Epoch 125/150
#
# Epoch 125: val_loss did not improve from 0.04648
# 60/60 - 33s - loss: 0.1894 - accuracy: 0.9279 - val_loss: 0.0549 - val_accuracy: 0.9845 - lr: 0.0010 - 33s/epoch - 554ms/step
# Epoch 126/150
#
# Epoch 126: val_loss did not improve from 0.04648
# 60/60 - 32s - loss: 0.2003 - accuracy: 0.9248 - val_loss: 0.0500 - val_accuracy: 0.9861 - lr: 0.0010 - 32s/epoch - 540ms/step
# Epoch 127/150
#
# Epoch 127: val_loss did not improve from 0.04648
# 60/60 - 34s - loss: 0.1988 - accuracy: 0.9255 - val_loss: 0.0547 - val_accuracy: 0.9841 - lr: 0.0010 - 34s/epoch - 558ms/step
# Epoch 128/150
#
# Epoch 128: val_loss did not improve from 0.04648
# 60/60 - 32s - loss: 0.1826 - accuracy: 0.9307 - val_loss: 0.0510 - val_accuracy: 0.9857 - lr: 0.0010 - 32s/epoch - 541ms/step
# Epoch 129/150
#
# Epoch 129: val_loss did not improve from 0.04648
# 60/60 - 33s - loss: 0.1953 - accuracy: 0.9237 - val_loss: 0.0496 - val_accuracy: 0.9854 - lr: 0.0010 - 33s/epoch - 549ms/step
# Epoch 130/150
#
# Epoch 130: val_loss did not improve from 0.04648
# 60/60 - 33s - loss: 0.1984 - accuracy: 0.9227 - val_loss: 0.0553 - val_accuracy: 0.9821 - lr: 0.0010 - 33s/epoch - 547ms/step
# Epoch 131/150
#
# Epoch 131: val_loss did not improve from 0.04648
# 60/60 - 33s - loss: 0.1809 - accuracy: 0.9341 - val_loss: 0.0490 - val_accuracy: 0.9870 - lr: 0.0010 - 33s/epoch - 544ms/step
# Epoch 132/150
#
# Epoch 132: val_loss did not improve from 0.04648
# 60/60 - 33s - loss: 0.1888 - accuracy: 0.9292 - val_loss: 0.0474 - val_accuracy: 0.9865 - lr: 0.0010 - 33s/epoch - 545ms/step
# Epoch 133/150
#
# Epoch 133: val_loss did not improve from 0.04648
# 60/60 - 32s - loss: 0.1888 - accuracy: 0.9274 - val_loss: 0.0474 - val_accuracy: 0.9874 - lr: 0.0010 - 32s/epoch - 541ms/step
# Epoch 134/150
#
# Epoch 134: val_loss did not improve from 0.04648
# 60/60 - 33s - loss: 0.1862 - accuracy: 0.9289 - val_loss: 0.0494 - val_accuracy: 0.9849 - lr: 0.0010 - 33s/epoch - 550ms/step
# Epoch 135/150
#
# Epoch 135: val_loss did not improve from 0.04648
# 60/60 - 33s - loss: 0.1775 - accuracy: 0.9331 - val_loss: 0.0471 - val_accuracy: 0.9879 - lr: 0.0010 - 33s/epoch - 552ms/step
# Epoch 136/150
#
# Epoch 136: val_loss did not improve from 0.04648
# 60/60 - 33s - loss: 0.1915 - accuracy: 0.9276 - val_loss: 0.0494 - val_accuracy: 0.9876 - lr: 0.0010 - 33s/epoch - 558ms/step
# Epoch 137/150
#
# Epoch 137: val_loss improved from 0.04648 to 0.04380, saving model to model.h5
# 60/60 - 34s - loss: 0.1743 - accuracy: 0.9355 - val_loss: 0.0438 - val_accuracy: 0.9894 - lr: 0.0010 - 34s/epoch - 570ms/step
# Epoch 138/150
#
# Epoch 138: val_loss improved from 0.04380 to 0.04200, saving model to model.h5
# 60/60 - 34s - loss: 0.1805 - accuracy: 0.9322 - val_loss: 0.0420 - val_accuracy: 0.9897 - lr: 0.0010 - 34s/epoch - 567ms/step
# Epoch 139/150
#
# Epoch 139: val_loss did not improve from 0.04200
# 60/60 - 33s - loss: 0.1861 - accuracy: 0.9314 - val_loss: 0.0426 - val_accuracy: 0.9885 - lr: 0.0010 - 33s/epoch - 548ms/step
# Epoch 140/150
#
# Epoch 140: val_loss did not improve from 0.04200
# 60/60 - 33s - loss: 0.1696 - accuracy: 0.9350 - val_loss: 0.0424 - val_accuracy: 0.9890 - lr: 0.0010 - 33s/epoch - 550ms/step
# Epoch 141/150
#
# Epoch 141: val_loss did not improve from 0.04200
# 60/60 - 33s - loss: 0.1783 - accuracy: 0.9351 - val_loss: 0.0435 - val_accuracy: 0.9898 - lr: 0.0010 - 33s/epoch - 551ms/step
# Epoch 142/150
#
# Epoch 142: val_loss did not improve from 0.04200
# 60/60 - 33s - loss: 0.1790 - accuracy: 0.9330 - val_loss: 0.0432 - val_accuracy: 0.9880 - lr: 0.0010 - 33s/epoch - 552ms/step
# Epoch 143/150
#
# Epoch 143: val_loss did not improve from 0.04200
# 60/60 - 33s - loss: 0.1781 - accuracy: 0.9330 - val_loss: 0.0438 - val_accuracy: 0.9874 - lr: 0.0010 - 33s/epoch - 544ms/step
# Epoch 144/150
#
# Epoch 144: val_loss improved from 0.04200 to 0.04142, saving model to model.h5
# 60/60 - 34s - loss: 0.1638 - accuracy: 0.9386 - val_loss: 0.0414 - val_accuracy: 0.9879 - lr: 0.0010 - 34s/epoch - 567ms/step
# Epoch 145/150
#
# Epoch 145: val_loss improved from 0.04142 to 0.03698, saving model to model.h5
# 60/60 - 34s - loss: 0.1706 - accuracy: 0.9348 - val_loss: 0.0370 - val_accuracy: 0.9890 - lr: 0.0010 - 34s/epoch - 573ms/step
# Epoch 146/150
#
# Epoch 146: val_loss improved from 0.03698 to 0.03642, saving model to model.h5
# 60/60 - 34s - loss: 0.1704 - accuracy: 0.9356 - val_loss: 0.0364 - val_accuracy: 0.9899 - lr: 0.0010 - 34s/epoch - 567ms/step
# Epoch 147/150
#
# Epoch 147: val_loss did not improve from 0.03642
# 60/60 - 33s - loss: 0.1713 - accuracy: 0.9367 - val_loss: 0.0397 - val_accuracy: 0.9878 - lr: 0.0010 - 33s/epoch - 552ms/step
# Epoch 148/150
#
# Epoch 148: val_loss did not improve from 0.03642
# 60/60 - 33s - loss: 0.1657 - accuracy: 0.9372 - val_loss: 0.0408 - val_accuracy: 0.9876 - lr: 0.0010 - 33s/epoch - 546ms/step
# Epoch 149/150
#
# Epoch 149: val_loss did not improve from 0.03642
# 60/60 - 33s - loss: 0.1657 - accuracy: 0.9402 - val_loss: 0.0366 - val_accuracy: 0.9905 - lr: 0.0010 - 33s/epoch - 548ms/step
# Epoch 150/150
#
# Epoch 150: val_loss did not improve from 0.03642
# 60/60 - 33s - loss: 0.1626 - accuracy: 0.9388 - val_loss: 0.0383 - val_accuracy: 0.9896 - lr: 0.0010 - 33s/epoch - 545ms/step

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper left')
plt.show()

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper right')
plt.show()

# %%
model.save('/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/ML_Models/DenseNet_150_epoch/DenseNet201/Case_6_Both_CC/model.h5')

# %%
ypred = model.predict(xtest)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(ypred)):
    if np.argmax(ypred[i]) == np.argmax(ytest[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Total-test-data; 1940 	accurately-predicted-data: 1843 	 wrongly-predicted-data:  97
# Accuracy: 95.0 %

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(accurateindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(wrongindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
Ypred = model.predict(xtest)

Ypred = np.argmax(Ypred, axis=1)
Ytrue = np.argmax(ytest, axis=1)

cm = confusion_matrix(Ytrue, Ypred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')
