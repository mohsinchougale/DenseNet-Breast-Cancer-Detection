# %%
import tensorflow 

import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import models

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("Tensorflow-version:", tensorflow.__version__)
# Out:
# Tensorflow-version: 2.8.0

# %%
model_d=DenseNet201(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(8,activation='softmax')(x) #FC-layer
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# 74850304/74836368 [==============================] - 0s 0us/step

# %%
model_d=DenseNet201(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(3,activation='softmax')(x) #FC-layer

# %%
model=Model(inputs=model_d.input,outputs=preds)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 4, 4, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 4, 4, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 4, 4, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 4, 4, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 4, 4, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 4, 4, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 4, 4, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 4, 4, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 4, 4, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 4, 4, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 4, 4, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 4, 4, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 4, 4, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 4, 4, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 4, 4, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 4, 4, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 4, 4, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 4, 4, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 4, 4, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 4, 4, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 4, 4, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 4, 4, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 4, 4, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 4, 4, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 4, 4, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 4, 4, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 4, 4, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 4, 4, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1920)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1920)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1920)        7680        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1920)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1967104     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 20,825,155
# Trainable params: 20,591,235
# Non-trainable params: 233,920
# __________________________________________________________________________________________________

# %%
for layer in model.layers[:-8]:
    layer.trainable=False
    
for layer in model.layers[-8:]:
    layer.trainable=True

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 4, 4, 1696)  6784        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 4, 4, 1696)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 4, 4, 128)    217088      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 4, 4, 1728)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 4, 4, 1728)  6912        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 4, 4, 1728)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 4, 4, 128)    221184      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 4, 4, 1760)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 4, 4, 1760)  7040        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 4, 4, 1760)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 4, 4, 128)    225280      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 4, 4, 1792)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 4, 4, 1792)  7168        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 4, 4, 1792)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 4, 4, 128)    229376      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 4, 4, 1824)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 4, 4, 1824)  7296        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 4, 4, 1824)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 4, 4, 128)    233472      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 4, 4, 1856)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 4, 4, 1856)  7424        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 4, 4, 1856)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 4, 4, 128)    237568      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 4, 4, 1888)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 4, 4, 1888)  7552        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 4, 4, 1888)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 4, 4, 128)    241664      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 4, 4, 1920)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1920)   7680        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1920)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1920)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1920)        7680        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1920)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1967104     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 20,825,155
# Trainable params: 2,498,307
# Non-trainable params: 18,326,848
# __________________________________________________________________________________________________

# %%
data=[]
labels=[]
random.seed(42)
# imagePaths = sorted(list(os.listdir("/content/drive/MyDrive/Mini_DDSM_Upload")))
imagePaths = ['Benign','Cancer','Normal']
random.shuffle(imagePaths)
print(imagePaths)
# Out:
# ['Cancer', 'Benign', 'Normal']

# %%
for img in imagePaths:
    path=sorted(list(os.listdir("/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img)))
    for i in path:
      if("LEFT_CC" in i):
        #Considereing original and flipped image
        for flip in range(2):
          if(flip == 0):
            print("\n****************************************")
            print("Original")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            print(image_path)
            # print("Reading image")
            image = cv2.imread(image_path)
            
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResized Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            # print("Label - ",l)
            labels.append(l)
          else:
            print("\n\n")
            print("FLIPPED")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            # print("Image Path - ",image_path)
            # print("Reading image ",i)
            image = cv2.imread(image_path)
            # print("Flipping Image")
            image = cv2.flip(image,1)
            
            # print("\nResizing the flipped image")
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResizing Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            print("Label - ",l)
            labels.append(l)
        else:
          continue
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1091_A_0423_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1095_A_0424_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1099_A_0425_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1103_A_0426_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1107_A_0427_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1111_A_0431_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1115_A_0432_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1119_A_0433_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/111_A_0041_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1123_A_0434_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1127_A_0435_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1131_A_0436_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1135_A_0437_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1139_A_0438_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1143_A_0439_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1147_A_0440_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1151_A_0441_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1155_A_0442_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1159_A_0443_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/115_A_0042_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1163_A_0444_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1167_A_0445_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1171_A_0446_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1175_A_0447_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1179_A_0448_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1183_A_0449_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1187_A_0450_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1191_A_0451_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1195_A_0452_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1199_A_0453_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/119_A_0043_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/11_A_0005_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1203_A_0455_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1207_A_0456_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1211_A_0457_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1215_A_0462_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1219_A_0463_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1223_A_0464_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1227_A_0465_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1231_A_0466_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1235_A_0467_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1239_A_0468_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/123_A_0044_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1243_A_0469_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1247_A_0470_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1251_A_0471_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1255_A_0472_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1259_A_0473_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1263_A_0474_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1267_A_0475_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1271_A_0477_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1275_A_0478_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1279_A_0482_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/127_A_0045_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1283_A_0483_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1287_A_0484_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1291_A_0490_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1295_A_0491_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1299_A_0492_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1303_A_0493_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1307_A_0494_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1311_A_0495_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1315_A_0496_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1319_A_0497_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/131_A_0046_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1323_A_0498_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1327_A_0500_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1331_A_0501_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1335_A_0502_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1339_A_0503_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1343_A_0504_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1347_A_0505_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1351_A_0508_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1355_A_0509_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1359_A_0510_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/135_A_0048_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1363_A_0511_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1367_A_0512_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1371_A_0513_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1375_A_0514_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1379_A_0515_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1383_A_0516_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1387_A_0517_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1391_A_0518_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1395_A_0519_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1399_A_0521_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/139_A_0049_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1403_A_0522_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1407_A_0523_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1411_A_0524_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1415_A_0525_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1419_A_0526_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1423_A_0527_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1427_A_0528_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1431_A_0529_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1435_A_0531_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1439_A_0532_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/143_A_0050_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1443_A_0534_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1447_A_0539_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1451_A_0541_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1455_A_0542_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1459_A_0543_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1463_A_0565_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1467_A_0566_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1471_A_0567_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1475_A_0568_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1479_A_0569_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/147_A_0051_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1483_A_0570_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1487_A_0571_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1491_A_0572_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1495_A_0573_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1499_A_0574_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1503_A_0575_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1507_A_0576_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1511_A_0578_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1515_A_0580_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1519_A_0581_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/151_A_0052_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1523_A_0583_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1527_A_0584_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1531_A_0585_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1535_A_0586_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1539_A_0587_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1543_A_0588_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1547_A_0589_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1551_A_0591_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1555_A_0594_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1559_A_0595_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/155_A_0053_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1563_A_0596_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1567_A_0597_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1571_A_0598_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1575_A_0599_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1579_A_0600_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1583_A_0601_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1587_A_0602_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1591_A_0603_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1595_A_0604_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1599_A_0605_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/159_A_0055_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/15_A_0006_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1603_A_0606_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1607_A_0607_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1611_A_0608_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1615_A_0609_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1619_A_0610_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1623_A_0611_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1627_A_0613_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1631_A_0614_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1635_A_0615_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1639_A_0616_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/163_A_0056_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1643_A_0617_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1647_A_0618_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1651_A_0619_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1655_A_0620_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1659_A_0621_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1663_A_0623_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1667_A_0702_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1671_A_0703_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1675_A_0704_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1679_A_0705_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/167_A_0057_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1683_A_0706_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1687_A_0707_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1691_A_0708_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1695_A_0710_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1699_D_4500_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1703_D_4501_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1707_D_4502_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1711_D_4503_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1715_D_4505_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1719_D_4506_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/171_A_0058_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1723_D_4508_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1727_D_4509_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1731_D_4510_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1735_D_4511_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1739_D_4512_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1743_D_4513_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1747_D_4514_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1751_D_4515_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1755_D_4516_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1759_D_4517_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/175_A_0059_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1763_D_4518_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1767_D_4519_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1771_D_4520_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1775_D_4521_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1779_D_4522_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1783_D_4523_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1787_D_4524_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1791_D_4525_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1795_D_4526_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1799_D_4527_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/179_A_0061_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1803_D_4528_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1807_D_4529_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1811_D_4530_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1815_D_4532_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1819_D_4533_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1823_D_4534_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1827_D_4536_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1831_D_4537_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1835_D_4538_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1839_D_4539_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/183_A_0062_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1843_D_4540_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1847_D_4541_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1851_D_4542_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1855_D_4543_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1859_D_4544_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1863_D_4545_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1867_D_4546_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1871_D_4547_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1875_D_4551_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1879_D_4552_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/187_A_0063_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1883_D_4553_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1887_D_4555_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1891_D_4557_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1895_D_4558_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1899_D_4559_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1903_D_4560_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1907_D_4561_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1911_D_4562_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1915_D_4563_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1919_D_4565_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/191_A_0064_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1923_D_4566_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1927_D_4567_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1931_D_4570_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1935_D_4571_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1939_D_4572_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1943_D_4574_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1947_D_4575_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1951_D_4576_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1955_D_4577_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1959_D_4582_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/195_A_0067_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1963_D_4583_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1967_D_4584_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1971_D_4585_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1975_D_4587_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1979_D_4588_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1983_D_4589_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1987_D_4590_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1991_D_4591_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1995_D_4592_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/1999_D_4593_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/199_A_0068_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/19_A_0009_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2027_D_4568_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2035_D_4578_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/2039_D_4579_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/203_A_0069_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/207_A_0070_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/211_A_0071_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/215_A_0072_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/219_A_0073_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/223_A_0074_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/227_A_0075_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/231_A_0076_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/235_A_0077_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# ...
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/683_A_0264_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/687_A_0265_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/691_A_0266_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/695_A_0267_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/699_A_0268_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/703_A_0269_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/707_A_0270_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/711_A_0271_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/715_A_0272_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/719_A_0273_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/71_A_0027_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/723_A_0274_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/727_A_0275_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/731_A_0276_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/735_A_0277_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/739_A_0278_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/743_A_0279_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/747_A_0280_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/751_A_0282_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/755_A_0283_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/759_A_0284_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/75_A_0030_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/763_A_0285_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/767_A_0286_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/771_A_0287_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/775_A_0290_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/779_A_0292_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/783_A_0293_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/787_A_0294_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/791_A_0295_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/795_A_0296_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/799_A_0297_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/79_A_0031_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/7_A_0003_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/803_A_0298_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/807_A_0299_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/811_A_0302_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/815_A_0303_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/819_A_0304_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/823_A_0305_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/827_A_0306_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/831_A_0307_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/835_A_0309_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/839_A_0310_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/83_A_0032_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/843_A_0311_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/847_A_0312_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/851_A_0313_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/855_A_0314_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/859_A_0315_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/863_A_0317_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/867_A_0318_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/871_A_0319_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/875_A_0320_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/879_A_0321_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/87_A_0034_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/883_A_0322_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/887_A_0323_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/891_A_0325_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/895_A_0326_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/899_A_0327_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/903_A_0328_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/907_A_0330_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/911_A_0331_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/915_A_0333_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/919_A_0334_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/91_A_0035_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/923_A_0335_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/927_A_0336_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/931_A_0337_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/935_A_0338_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/939_A_0339_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/943_A_0341_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/947_A_0342_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/951_A_0343_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/955_A_0344_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/959_A_0345_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/95_A_0036_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/963_A_0347_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/967_A_0348_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/971_A_0349_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/975_A_0351_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/979_A_0352_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/983_A_0354_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/987_A_0355_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/991_A_0356_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/995_A_0357_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/999_A_0358_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/99_A_0037_1.LEFT_CC.LJPEG.1_highpass.png
#
#
#
# FLIPPED
# Label -  Normal

# %%
print("Length of dataset = ",len(labels))
# Out:
# Length of dataset =  6338

# %%
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
print(labels[0])
# Out:
# [0 1 0]

# %%
(xtrain,xtest,ytrain,ytest)=train_test_split(data,labels,test_size=0.2,random_state=42)
print(xtrain.shape, xtest.shape)
# Out:
# (5070, 128, 128, 3) (1268, 128, 128, 3)

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)


datagen.fit(xtrain)
# Fits-the-model
history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=128),
               steps_per_epoch=xtrain.shape[0] //128,
               epochs=150, #try 100
               verbose=2,
               callbacks=[anne, checkpoint],
               validation_data=(xtrain, ytrain))
# Out:
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 0.85305, saving model to model.h5
# 39/39 - 49s - loss: 1.5204 - accuracy: 0.4943 - val_loss: 0.8530 - val_accuracy: 0.5402 - lr: 0.0010 - 49s/epoch - 1s/step
# Epoch 2/150
#
# Epoch 2: val_loss improved from 0.85305 to 0.82023, saving model to model.h5
# 39/39 - 22s - loss: 1.0670 - accuracy: 0.5488 - val_loss: 0.8202 - val_accuracy: 0.5882 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 3/150
#
# Epoch 3: val_loss improved from 0.82023 to 0.72132, saving model to model.h5
# 39/39 - 23s - loss: 0.9323 - accuracy: 0.5961 - val_loss: 0.7213 - val_accuracy: 0.6548 - lr: 0.0010 - 23s/epoch - 583ms/step
# Epoch 4/150
#
# Epoch 4: val_loss improved from 0.72132 to 0.68506, saving model to model.h5
# 39/39 - 22s - loss: 0.8791 - accuracy: 0.5937 - val_loss: 0.6851 - val_accuracy: 0.6690 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 5/150
#
# Epoch 5: val_loss improved from 0.68506 to 0.61418, saving model to model.h5
# 39/39 - 23s - loss: 0.8073 - accuracy: 0.6214 - val_loss: 0.6142 - val_accuracy: 0.7345 - lr: 0.0010 - 23s/epoch - 582ms/step
# Epoch 6/150
#
# Epoch 6: val_loss improved from 0.61418 to 0.59541, saving model to model.h5
# 39/39 - 22s - loss: 0.7828 - accuracy: 0.6218 - val_loss: 0.5954 - val_accuracy: 0.7501 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 7/150
#
# Epoch 7: val_loss improved from 0.59541 to 0.58569, saving model to model.h5
# 39/39 - 22s - loss: 0.7416 - accuracy: 0.6516 - val_loss: 0.5857 - val_accuracy: 0.7546 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 8/150
#
# Epoch 8: val_loss improved from 0.58569 to 0.57563, saving model to model.h5
# 39/39 - 22s - loss: 0.7277 - accuracy: 0.6562 - val_loss: 0.5756 - val_accuracy: 0.7533 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 9/150
#
# Epoch 9: val_loss improved from 0.57563 to 0.56611, saving model to model.h5
# 39/39 - 22s - loss: 0.7190 - accuracy: 0.6673 - val_loss: 0.5661 - val_accuracy: 0.7592 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 10/150
#
# Epoch 10: val_loss improved from 0.56611 to 0.53241, saving model to model.h5
# 39/39 - 22s - loss: 0.6917 - accuracy: 0.6775 - val_loss: 0.5324 - val_accuracy: 0.7923 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 11/150
#
# Epoch 11: val_loss improved from 0.53241 to 0.50730, saving model to model.h5
# 39/39 - 22s - loss: 0.6733 - accuracy: 0.6827 - val_loss: 0.5073 - val_accuracy: 0.8000 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 12/150
#
# Epoch 12: val_loss improved from 0.50730 to 0.49927, saving model to model.h5
# 39/39 - 22s - loss: 0.6724 - accuracy: 0.6953 - val_loss: 0.4993 - val_accuracy: 0.8059 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 13/150
#
# Epoch 13: val_loss improved from 0.49927 to 0.48506, saving model to model.h5
# 39/39 - 22s - loss: 0.6668 - accuracy: 0.6928 - val_loss: 0.4851 - val_accuracy: 0.8004 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 14/150
#
# Epoch 14: val_loss improved from 0.48506 to 0.44928, saving model to model.h5
# 39/39 - 22s - loss: 0.6486 - accuracy: 0.7009 - val_loss: 0.4493 - val_accuracy: 0.8282 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 15/150
#
# Epoch 15: val_loss improved from 0.44928 to 0.44638, saving model to model.h5
# 39/39 - 22s - loss: 0.6371 - accuracy: 0.7133 - val_loss: 0.4464 - val_accuracy: 0.8343 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 16/150
#
# Epoch 16: val_loss did not improve from 0.44638
# 39/39 - 21s - loss: 0.6294 - accuracy: 0.7208 - val_loss: 0.4630 - val_accuracy: 0.8233 - lr: 0.0010 - 21s/epoch - 551ms/step
# Epoch 17/150
#
# Epoch 17: val_loss improved from 0.44638 to 0.42156, saving model to model.h5
# 39/39 - 23s - loss: 0.6064 - accuracy: 0.7230 - val_loss: 0.4216 - val_accuracy: 0.8329 - lr: 0.0010 - 23s/epoch - 585ms/step
# Epoch 18/150
#
# Epoch 18: val_loss improved from 0.42156 to 0.41272, saving model to model.h5
# 39/39 - 22s - loss: 0.6197 - accuracy: 0.7137 - val_loss: 0.4127 - val_accuracy: 0.8337 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 19/150
#
# Epoch 19: val_loss did not improve from 0.41272
# 39/39 - 21s - loss: 0.5833 - accuracy: 0.7428 - val_loss: 0.4377 - val_accuracy: 0.8213 - lr: 0.0010 - 21s/epoch - 541ms/step
# Epoch 20/150
#
# Epoch 20: val_loss improved from 0.41272 to 0.39373, saving model to model.h5
# 39/39 - 22s - loss: 0.5923 - accuracy: 0.7353 - val_loss: 0.3937 - val_accuracy: 0.8430 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 21/150
#
# Epoch 21: val_loss improved from 0.39373 to 0.36292, saving model to model.h5
# 39/39 - 23s - loss: 0.5754 - accuracy: 0.7378 - val_loss: 0.3629 - val_accuracy: 0.8613 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 22/150
#
# Epoch 22: val_loss did not improve from 0.36292
# 39/39 - 21s - loss: 0.5785 - accuracy: 0.7503 - val_loss: 0.3638 - val_accuracy: 0.8637 - lr: 0.0010 - 21s/epoch - 539ms/step
# Epoch 23/150
#
# Epoch 23: val_loss improved from 0.36292 to 0.34291, saving model to model.h5
# 39/39 - 22s - loss: 0.5614 - accuracy: 0.7544 - val_loss: 0.3429 - val_accuracy: 0.8726 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 24/150
#
# Epoch 24: val_loss did not improve from 0.34291
# 39/39 - 21s - loss: 0.5438 - accuracy: 0.7501 - val_loss: 0.3911 - val_accuracy: 0.8394 - lr: 0.0010 - 21s/epoch - 543ms/step
# Epoch 25/150
#
# Epoch 25: val_loss improved from 0.34291 to 0.32709, saving model to model.h5
# 39/39 - 22s - loss: 0.5485 - accuracy: 0.7537 - val_loss: 0.3271 - val_accuracy: 0.8751 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 26/150
#
# Epoch 26: val_loss improved from 0.32709 to 0.32307, saving model to model.h5
# 39/39 - 22s - loss: 0.5331 - accuracy: 0.7620 - val_loss: 0.3231 - val_accuracy: 0.8724 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 27/150
#
# Epoch 27: val_loss improved from 0.32307 to 0.32046, saving model to model.h5
# 39/39 - 23s - loss: 0.5307 - accuracy: 0.7701 - val_loss: 0.3205 - val_accuracy: 0.8781 - lr: 0.0010 - 23s/epoch - 584ms/step
# Epoch 28/150
#
# Epoch 28: val_loss improved from 0.32046 to 0.29888, saving model to model.h5
# 39/39 - 22s - loss: 0.5169 - accuracy: 0.7691 - val_loss: 0.2989 - val_accuracy: 0.8961 - lr: 0.0010 - 22s/epoch - 577ms/step
# Epoch 29/150
#
# Epoch 29: val_loss did not improve from 0.29888
# 39/39 - 21s - loss: 0.5031 - accuracy: 0.7754 - val_loss: 0.3104 - val_accuracy: 0.8903 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 30/150
#
# Epoch 30: val_loss improved from 0.29888 to 0.28638, saving model to model.h5
# 39/39 - 23s - loss: 0.4971 - accuracy: 0.7847 - val_loss: 0.2864 - val_accuracy: 0.9006 - lr: 0.0010 - 23s/epoch - 577ms/step
# Epoch 31/150
#
# Epoch 31: val_loss did not improve from 0.28638
# 39/39 - 21s - loss: 0.4924 - accuracy: 0.7857 - val_loss: 0.2944 - val_accuracy: 0.8917 - lr: 0.0010 - 21s/epoch - 540ms/step
# Epoch 32/150
#
# Epoch 32: val_loss improved from 0.28638 to 0.26103, saving model to model.h5
# 39/39 - 22s - loss: 0.4929 - accuracy: 0.7849 - val_loss: 0.2610 - val_accuracy: 0.9108 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 33/150
#
# Epoch 33: val_loss improved from 0.26103 to 0.24781, saving model to model.h5
# 39/39 - 22s - loss: 0.4770 - accuracy: 0.7995 - val_loss: 0.2478 - val_accuracy: 0.9207 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 34/150
#
# Epoch 34: val_loss did not improve from 0.24781
# 39/39 - 21s - loss: 0.4811 - accuracy: 0.7944 - val_loss: 0.2480 - val_accuracy: 0.9211 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 35/150
#
# Epoch 35: val_loss did not improve from 0.24781
# 39/39 - 21s - loss: 0.4632 - accuracy: 0.8021 - val_loss: 0.2795 - val_accuracy: 0.9089 - lr: 0.0010 - 21s/epoch - 539ms/step
# Epoch 36/150
#
# Epoch 36: val_loss improved from 0.24781 to 0.23231, saving model to model.h5
# 39/39 - 22s - loss: 0.4682 - accuracy: 0.8027 - val_loss: 0.2323 - val_accuracy: 0.9260 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 37/150
#
# Epoch 37: val_loss improved from 0.23231 to 0.21962, saving model to model.h5
# 39/39 - 22s - loss: 0.4568 - accuracy: 0.8090 - val_loss: 0.2196 - val_accuracy: 0.9298 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 38/150
#
# Epoch 38: val_loss did not improve from 0.21962
# 39/39 - 21s - loss: 0.4505 - accuracy: 0.8175 - val_loss: 0.2306 - val_accuracy: 0.9183 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 39/150
#
# Epoch 39: val_loss improved from 0.21962 to 0.20545, saving model to model.h5
# 39/39 - 22s - loss: 0.4506 - accuracy: 0.8126 - val_loss: 0.2055 - val_accuracy: 0.9335 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 40/150
#
# Epoch 40: val_loss improved from 0.20545 to 0.20369, saving model to model.h5
# 39/39 - 23s - loss: 0.4073 - accuracy: 0.8268 - val_loss: 0.2037 - val_accuracy: 0.9359 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 41/150
#
# Epoch 41: val_loss did not improve from 0.20369
# 39/39 - 21s - loss: 0.4214 - accuracy: 0.8238 - val_loss: 0.2061 - val_accuracy: 0.9363 - lr: 0.0010 - 21s/epoch - 541ms/step
# Epoch 42/150
#
# Epoch 42: val_loss improved from 0.20369 to 0.19584, saving model to model.h5
# 39/39 - 22s - loss: 0.3998 - accuracy: 0.8363 - val_loss: 0.1958 - val_accuracy: 0.9369 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 43/150
#
# Epoch 43: val_loss improved from 0.19584 to 0.19145, saving model to model.h5
# 39/39 - 23s - loss: 0.4101 - accuracy: 0.8268 - val_loss: 0.1914 - val_accuracy: 0.9420 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 44/150
#
# Epoch 44: val_loss improved from 0.19145 to 0.18482, saving model to model.h5
# 39/39 - 22s - loss: 0.4005 - accuracy: 0.8306 - val_loss: 0.1848 - val_accuracy: 0.9434 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 45/150
#
# Epoch 45: val_loss did not improve from 0.18482
# 39/39 - 21s - loss: 0.3977 - accuracy: 0.8418 - val_loss: 0.1979 - val_accuracy: 0.9282 - lr: 0.0010 - 21s/epoch - 545ms/step
# Epoch 46/150
#
# Epoch 46: val_loss did not improve from 0.18482
# 39/39 - 21s - loss: 0.3897 - accuracy: 0.8377 - val_loss: 0.1906 - val_accuracy: 0.9446 - lr: 0.0010 - 21s/epoch - 545ms/step
# Epoch 47/150
#
# Epoch 47: val_loss improved from 0.18482 to 0.17755, saving model to model.h5
# 39/39 - 22s - loss: 0.3944 - accuracy: 0.8351 - val_loss: 0.1776 - val_accuracy: 0.9450 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.17755 to 0.17295, saving model to model.h5
# 39/39 - 22s - loss: 0.3749 - accuracy: 0.8430 - val_loss: 0.1729 - val_accuracy: 0.9452 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 49/150
#
# Epoch 49: val_loss improved from 0.17295 to 0.15471, saving model to model.h5
# 39/39 - 22s - loss: 0.3991 - accuracy: 0.8442 - val_loss: 0.1547 - val_accuracy: 0.9576 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 50/150
#
# Epoch 50: val_loss did not improve from 0.15471
# 39/39 - 21s - loss: 0.3784 - accuracy: 0.8385 - val_loss: 0.1642 - val_accuracy: 0.9542 - lr: 0.0010 - 21s/epoch - 541ms/step
# Epoch 51/150
#
# Epoch 51: val_loss improved from 0.15471 to 0.14459, saving model to model.h5
# 39/39 - 23s - loss: 0.3593 - accuracy: 0.8521 - val_loss: 0.1446 - val_accuracy: 0.9552 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 52/150
#
# Epoch 52: val_loss did not improve from 0.14459
# 39/39 - 21s - loss: 0.3451 - accuracy: 0.8626 - val_loss: 0.1519 - val_accuracy: 0.9503 - lr: 0.0010 - 21s/epoch - 541ms/step
# Epoch 53/150
#
# Epoch 53: val_loss improved from 0.14459 to 0.13664, saving model to model.h5
# 39/39 - 23s - loss: 0.3568 - accuracy: 0.8580 - val_loss: 0.1366 - val_accuracy: 0.9641 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 54/150
#
# Epoch 54: val_loss improved from 0.13664 to 0.13446, saving model to model.h5
# 39/39 - 22s - loss: 0.3547 - accuracy: 0.8575 - val_loss: 0.1345 - val_accuracy: 0.9653 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 55/150
#
# Epoch 55: val_loss did not improve from 0.13446
# 39/39 - 21s - loss: 0.3384 - accuracy: 0.8652 - val_loss: 0.1377 - val_accuracy: 0.9584 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 56/150
#
# Epoch 56: val_loss did not improve from 0.13446
# 39/39 - 21s - loss: 0.3585 - accuracy: 0.8555 - val_loss: 0.1436 - val_accuracy: 0.9538 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 57/150
#
# Epoch 57: val_loss did not improve from 0.13446
# 39/39 - 21s - loss: 0.3350 - accuracy: 0.8626 - val_loss: 0.1360 - val_accuracy: 0.9586 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 58/150
#
# Epoch 58: val_loss did not improve from 0.13446
# 39/39 - 21s - loss: 0.3312 - accuracy: 0.8632 - val_loss: 0.1393 - val_accuracy: 0.9548 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 59/150
#
# Epoch 59: val_loss improved from 0.13446 to 0.11978, saving model to model.h5
# 39/39 - 22s - loss: 0.3252 - accuracy: 0.8705 - val_loss: 0.1198 - val_accuracy: 0.9653 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 60/150
#
# Epoch 60: val_loss did not improve from 0.11978
# 39/39 - 21s - loss: 0.3247 - accuracy: 0.8692 - val_loss: 0.1270 - val_accuracy: 0.9572 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 61/150
#
# Epoch 61: val_loss did not improve from 0.11978
# 39/39 - 21s - loss: 0.3192 - accuracy: 0.8719 - val_loss: 0.1218 - val_accuracy: 0.9647 - lr: 0.0010 - 21s/epoch - 545ms/step
# Epoch 62/150
#
# Epoch 62: val_loss did not improve from 0.11978
# 39/39 - 21s - loss: 0.3140 - accuracy: 0.8731 - val_loss: 0.1245 - val_accuracy: 0.9576 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 63/150
#
# Epoch 63: val_loss improved from 0.11978 to 0.11496, saving model to model.h5
# 39/39 - 23s - loss: 0.3159 - accuracy: 0.8735 - val_loss: 0.1150 - val_accuracy: 0.9698 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 64/150
#
# Epoch 64: val_loss did not improve from 0.11496
# 39/39 - 21s - loss: 0.3176 - accuracy: 0.8792 - val_loss: 0.1283 - val_accuracy: 0.9600 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 65/150
#
# Epoch 65: val_loss improved from 0.11496 to 0.10528, saving model to model.h5
# 39/39 - 22s - loss: 0.3010 - accuracy: 0.8756 - val_loss: 0.1053 - val_accuracy: 0.9712 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 66/150
#
# Epoch 66: val_loss did not improve from 0.10528
# 39/39 - 21s - loss: 0.3109 - accuracy: 0.8760 - val_loss: 0.1100 - val_accuracy: 0.9720 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 67/150
#
# Epoch 67: val_loss did not improve from 0.10528
# 39/39 - 21s - loss: 0.3045 - accuracy: 0.8800 - val_loss: 0.1171 - val_accuracy: 0.9686 - lr: 0.0010 - 21s/epoch - 543ms/step
# Epoch 68/150
#
# Epoch 68: val_loss did not improve from 0.10528
# 39/39 - 21s - loss: 0.2951 - accuracy: 0.8855 - val_loss: 0.1063 - val_accuracy: 0.9706 - lr: 0.0010 - 21s/epoch - 539ms/step
# Epoch 69/150
#
# Epoch 69: val_loss improved from 0.10528 to 0.09733, saving model to model.h5
# 39/39 - 22s - loss: 0.2837 - accuracy: 0.8901 - val_loss: 0.0973 - val_accuracy: 0.9763 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 70/150
#
# Epoch 70: val_loss did not improve from 0.09733
# 39/39 - 21s - loss: 0.2867 - accuracy: 0.8861 - val_loss: 0.1066 - val_accuracy: 0.9696 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 71/150
#
# Epoch 71: val_loss improved from 0.09733 to 0.09366, saving model to model.h5
# 39/39 - 22s - loss: 0.2936 - accuracy: 0.8832 - val_loss: 0.0937 - val_accuracy: 0.9736 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 72/150
#
# Epoch 72: val_loss improved from 0.09366 to 0.09029, saving model to model.h5
# 39/39 - 23s - loss: 0.2933 - accuracy: 0.8859 - val_loss: 0.0903 - val_accuracy: 0.9791 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 73/150
#
# Epoch 73: val_loss did not improve from 0.09029
# 39/39 - 21s - loss: 0.2701 - accuracy: 0.8942 - val_loss: 0.0909 - val_accuracy: 0.9751 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 74/150
#
# Epoch 74: val_loss improved from 0.09029 to 0.08661, saving model to model.h5
# 39/39 - 23s - loss: 0.2674 - accuracy: 0.8940 - val_loss: 0.0866 - val_accuracy: 0.9769 - lr: 0.0010 - 23s/epoch - 584ms/step
# Epoch 75/150
#
# Epoch 75: val_loss improved from 0.08661 to 0.08303, saving model to model.h5
# 39/39 - 22s - loss: 0.2681 - accuracy: 0.8946 - val_loss: 0.0830 - val_accuracy: 0.9787 - lr: 0.0010 - 22s/epoch - 577ms/step
# Epoch 76/150
#
# Epoch 76: val_loss improved from 0.08303 to 0.08176, saving model to model.h5
# 39/39 - 22s - loss: 0.2645 - accuracy: 0.9002 - val_loss: 0.0818 - val_accuracy: 0.9803 - lr: 0.0010 - 22s/epoch - 570ms/step
# Epoch 77/150
#
# Epoch 77: val_loss did not improve from 0.08176
# 39/39 - 21s - loss: 0.2679 - accuracy: 0.8952 - val_loss: 0.0913 - val_accuracy: 0.9763 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 78/150
#
# Epoch 78: val_loss did not improve from 0.08176
# 39/39 - 21s - loss: 0.2682 - accuracy: 0.8942 - val_loss: 0.0941 - val_accuracy: 0.9722 - lr: 0.0010 - 21s/epoch - 537ms/step
# Epoch 79/150
#
# Epoch 79: val_loss did not improve from 0.08176
# 39/39 - 21s - loss: 0.2628 - accuracy: 0.8994 - val_loss: 0.0844 - val_accuracy: 0.9759 - lr: 0.0010 - 21s/epoch - 543ms/step
# Epoch 80/150
#
# Epoch 80: val_loss improved from 0.08176 to 0.08132, saving model to model.h5
# 39/39 - 22s - loss: 0.2560 - accuracy: 0.8996 - val_loss: 0.0813 - val_accuracy: 0.9755 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 81/150
#
# Epoch 81: val_loss improved from 0.08132 to 0.07913, saving model to model.h5
# 39/39 - 22s - loss: 0.2645 - accuracy: 0.8958 - val_loss: 0.0791 - val_accuracy: 0.9811 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 82/150
#
# Epoch 82: val_loss did not improve from 0.07913
# 39/39 - 21s - loss: 0.2613 - accuracy: 0.9011 - val_loss: 0.0793 - val_accuracy: 0.9819 - lr: 0.0010 - 21s/epoch - 540ms/step
# Epoch 83/150
#
# Epoch 83: val_loss improved from 0.07913 to 0.07652, saving model to model.h5
# 39/39 - 22s - loss: 0.2640 - accuracy: 0.9008 - val_loss: 0.0765 - val_accuracy: 0.9805 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 84/150
#
# Epoch 84: val_loss did not improve from 0.07652
# 39/39 - 21s - loss: 0.2494 - accuracy: 0.8996 - val_loss: 0.0774 - val_accuracy: 0.9771 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 85/150
#
# Epoch 85: val_loss improved from 0.07652 to 0.07412, saving model to model.h5
# 39/39 - 22s - loss: 0.2469 - accuracy: 0.9045 - val_loss: 0.0741 - val_accuracy: 0.9815 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 86/150
#
# Epoch 86: val_loss improved from 0.07412 to 0.06910, saving model to model.h5
# 39/39 - 22s - loss: 0.2432 - accuracy: 0.9065 - val_loss: 0.0691 - val_accuracy: 0.9844 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 87/150
#
# Epoch 87: val_loss did not improve from 0.06910
# 39/39 - 21s - loss: 0.2470 - accuracy: 0.9071 - val_loss: 0.0722 - val_accuracy: 0.9817 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 88/150
#
# Epoch 88: val_loss did not improve from 0.06910
# 39/39 - 21s - loss: 0.2410 - accuracy: 0.9057 - val_loss: 0.0749 - val_accuracy: 0.9761 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 89/150
#
# Epoch 89: val_loss did not improve from 0.06910
# 39/39 - 21s - loss: 0.2424 - accuracy: 0.9069 - val_loss: 0.0735 - val_accuracy: 0.9777 - lr: 0.0010 - 21s/epoch - 543ms/step
# Epoch 90/150
#
# Epoch 90: val_loss improved from 0.06910 to 0.06855, saving model to model.h5
# 39/39 - 23s - loss: 0.2401 - accuracy: 0.9049 - val_loss: 0.0686 - val_accuracy: 0.9813 - lr: 0.0010 - 23s/epoch - 577ms/step
# Epoch 91/150
#
# Epoch 91: val_loss did not improve from 0.06855
# 39/39 - 21s - loss: 0.2389 - accuracy: 0.9087 - val_loss: 0.0725 - val_accuracy: 0.9803 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 92/150
#
# Epoch 92: val_loss improved from 0.06855 to 0.06682, saving model to model.h5
# 39/39 - 22s - loss: 0.2297 - accuracy: 0.9116 - val_loss: 0.0668 - val_accuracy: 0.9819 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 93/150
#
# Epoch 93: val_loss improved from 0.06682 to 0.05995, saving model to model.h5
# 39/39 - 22s - loss: 0.2126 - accuracy: 0.9185 - val_loss: 0.0599 - val_accuracy: 0.9854 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 94/150
#
# Epoch 94: val_loss did not improve from 0.05995
# 39/39 - 21s - loss: 0.2316 - accuracy: 0.9134 - val_loss: 0.0778 - val_accuracy: 0.9759 - lr: 0.0010 - 21s/epoch - 543ms/step
# Epoch 95/150
#
# Epoch 95: val_loss did not improve from 0.05995
# 39/39 - 21s - loss: 0.2343 - accuracy: 0.9104 - val_loss: 0.0644 - val_accuracy: 0.9832 - lr: 0.0010 - 21s/epoch - 543ms/step
# Epoch 96/150
#
# Epoch 96: val_loss did not improve from 0.05995
# 39/39 - 21s - loss: 0.2355 - accuracy: 0.9118 - val_loss: 0.0709 - val_accuracy: 0.9791 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 97/150
#
# Epoch 97: val_loss did not improve from 0.05995
# 39/39 - 21s - loss: 0.2200 - accuracy: 0.9164 - val_loss: 0.0615 - val_accuracy: 0.9846 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 98/150
#
# Epoch 98: val_loss improved from 0.05995 to 0.05302, saving model to model.h5
# 39/39 - 22s - loss: 0.2096 - accuracy: 0.9217 - val_loss: 0.0530 - val_accuracy: 0.9874 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 99/150
#
# Epoch 99: val_loss improved from 0.05302 to 0.05172, saving model to model.h5
# 39/39 - 23s - loss: 0.2027 - accuracy: 0.9211 - val_loss: 0.0517 - val_accuracy: 0.9862 - lr: 0.0010 - 23s/epoch - 580ms/step
# Epoch 100/150
#
# Epoch 100: val_loss did not improve from 0.05172
# 39/39 - 21s - loss: 0.2250 - accuracy: 0.9160 - val_loss: 0.0553 - val_accuracy: 0.9842 - lr: 0.0010 - 21s/epoch - 541ms/step
# Epoch 101/150
#
# Epoch 101: val_loss did not improve from 0.05172
# 39/39 - 21s - loss: 0.2058 - accuracy: 0.9221 - val_loss: 0.0598 - val_accuracy: 0.9836 - lr: 0.0010 - 21s/epoch - 545ms/step
# Epoch 102/150
#
# Epoch 102: val_loss did not improve from 0.05172
# 39/39 - 21s - loss: 0.2126 - accuracy: 0.9156 - val_loss: 0.0588 - val_accuracy: 0.9836 - lr: 0.0010 - 21s/epoch - 539ms/step
# Epoch 103/150
#
# Epoch 103: val_loss did not improve from 0.05172
# 39/39 - 21s - loss: 0.2105 - accuracy: 0.9191 - val_loss: 0.0548 - val_accuracy: 0.9864 - lr: 0.0010 - 21s/epoch - 536ms/step
# Epoch 104/150
#
# Epoch 104: val_loss did not improve from 0.05172
# 39/39 - 21s - loss: 0.1969 - accuracy: 0.9253 - val_loss: 0.0541 - val_accuracy: 0.9830 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 105/150
#
# Epoch 105: val_loss improved from 0.05172 to 0.05065, saving model to model.h5
# 39/39 - 22s - loss: 0.2070 - accuracy: 0.9215 - val_loss: 0.0507 - val_accuracy: 0.9848 - lr: 0.0010 - 22s/epoch - 576ms/step
# Epoch 106/150
#
# Epoch 106: val_loss improved from 0.05065 to 0.04462, saving model to model.h5
# 39/39 - 22s - loss: 0.1898 - accuracy: 0.9308 - val_loss: 0.0446 - val_accuracy: 0.9870 - lr: 0.0010 - 22s/epoch - 571ms/step
# Epoch 107/150
#
# Epoch 107: val_loss did not improve from 0.04462
# 39/39 - 21s - loss: 0.1922 - accuracy: 0.9302 - val_loss: 0.0459 - val_accuracy: 0.9872 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 108/150
#
# Epoch 108: val_loss did not improve from 0.04462
# 39/39 - 21s - loss: 0.1950 - accuracy: 0.9241 - val_loss: 0.0513 - val_accuracy: 0.9862 - lr: 0.0010 - 21s/epoch - 545ms/step
# Epoch 109/150
#
# Epoch 109: val_loss did not improve from 0.04462
# 39/39 - 21s - loss: 0.2079 - accuracy: 0.9207 - val_loss: 0.0514 - val_accuracy: 0.9860 - lr: 0.0010 - 21s/epoch - 548ms/step
# Epoch 110/150
#
# Epoch 110: val_loss improved from 0.04462 to 0.04417, saving model to model.h5
# 39/39 - 22s - loss: 0.1900 - accuracy: 0.9270 - val_loss: 0.0442 - val_accuracy: 0.9890 - lr: 0.0010 - 22s/epoch - 574ms/step
# Epoch 111/150
#
# Epoch 111: val_loss did not improve from 0.04417
# 39/39 - 21s - loss: 0.1879 - accuracy: 0.9310 - val_loss: 0.0493 - val_accuracy: 0.9888 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 112/150
#
# Epoch 112: val_loss did not improve from 0.04417
# 39/39 - 21s - loss: 0.1893 - accuracy: 0.9328 - val_loss: 0.0501 - val_accuracy: 0.9856 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 113/150
#
# Epoch 113: val_loss did not improve from 0.04417
# 39/39 - 21s - loss: 0.1967 - accuracy: 0.9280 - val_loss: 0.0462 - val_accuracy: 0.9856 - lr: 0.0010 - 21s/epoch - 539ms/step
# Epoch 114/150
#
# Epoch 114: val_loss improved from 0.04417 to 0.04074, saving model to model.h5
# 39/39 - 22s - loss: 0.1919 - accuracy: 0.9276 - val_loss: 0.0407 - val_accuracy: 0.9888 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 115/150
#
# Epoch 115: val_loss did not improve from 0.04074
# 39/39 - 21s - loss: 0.1841 - accuracy: 0.9291 - val_loss: 0.0416 - val_accuracy: 0.9893 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 116/150
#
# Epoch 116: val_loss improved from 0.04074 to 0.03666, saving model to model.h5
# 39/39 - 23s - loss: 0.1637 - accuracy: 0.9371 - val_loss: 0.0367 - val_accuracy: 0.9886 - lr: 0.0010 - 23s/epoch - 579ms/step
# Epoch 117/150
#
# Epoch 117: val_loss did not improve from 0.03666
# 39/39 - 21s - loss: 0.1931 - accuracy: 0.9292 - val_loss: 0.0419 - val_accuracy: 0.9886 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 118/150
#
# Epoch 118: val_loss did not improve from 0.03666
# 39/39 - 21s - loss: 0.1844 - accuracy: 0.9294 - val_loss: 0.0408 - val_accuracy: 0.9893 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 119/150
#
# Epoch 119: val_loss did not improve from 0.03666
# 39/39 - 21s - loss: 0.1898 - accuracy: 0.9296 - val_loss: 0.0379 - val_accuracy: 0.9923 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 120/150
#
# Epoch 120: val_loss did not improve from 0.03666
# 39/39 - 21s - loss: 0.1706 - accuracy: 0.9330 - val_loss: 0.0413 - val_accuracy: 0.9903 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 121/150
#
# Epoch 121: val_loss did not improve from 0.03666
# 39/39 - 21s - loss: 0.1900 - accuracy: 0.9312 - val_loss: 0.0405 - val_accuracy: 0.9895 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 122/150
#
# Epoch 122: val_loss did not improve from 0.03666
# 39/39 - 21s - loss: 0.1741 - accuracy: 0.9375 - val_loss: 0.0418 - val_accuracy: 0.9909 - lr: 0.0010 - 21s/epoch - 543ms/step
# Epoch 123/150
#
# Epoch 123: val_loss improved from 0.03666 to 0.03475, saving model to model.h5
# 39/39 - 22s - loss: 0.1861 - accuracy: 0.9308 - val_loss: 0.0348 - val_accuracy: 0.9927 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 124/150
#
# Epoch 124: val_loss did not improve from 0.03475
# 39/39 - 21s - loss: 0.1780 - accuracy: 0.9278 - val_loss: 0.0415 - val_accuracy: 0.9882 - lr: 0.0010 - 21s/epoch - 543ms/step
# Epoch 125/150
#
# Epoch 125: val_loss improved from 0.03475 to 0.03406, saving model to model.h5
# 39/39 - 22s - loss: 0.1787 - accuracy: 0.9322 - val_loss: 0.0341 - val_accuracy: 0.9911 - lr: 0.0010 - 22s/epoch - 575ms/step
# Epoch 126/150
#
# Epoch 126: val_loss did not improve from 0.03406
# 39/39 - 21s - loss: 0.1757 - accuracy: 0.9359 - val_loss: 0.0350 - val_accuracy: 0.9899 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 127/150
#
# Epoch 127: val_loss improved from 0.03406 to 0.03370, saving model to model.h5
# 39/39 - 22s - loss: 0.1714 - accuracy: 0.9344 - val_loss: 0.0337 - val_accuracy: 0.9903 - lr: 0.0010 - 22s/epoch - 572ms/step
# Epoch 128/150
#
# Epoch 128: val_loss improved from 0.03370 to 0.02874, saving model to model.h5
# 39/39 - 22s - loss: 0.1561 - accuracy: 0.9391 - val_loss: 0.0287 - val_accuracy: 0.9923 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 129/150
#
# Epoch 129: val_loss did not improve from 0.02874
# 39/39 - 21s - loss: 0.1661 - accuracy: 0.9407 - val_loss: 0.0384 - val_accuracy: 0.9884 - lr: 0.0010 - 21s/epoch - 541ms/step
# Epoch 130/150
#
# Epoch 130: val_loss improved from 0.02874 to 0.02705, saving model to model.h5
# 39/39 - 23s - loss: 0.1695 - accuracy: 0.9330 - val_loss: 0.0270 - val_accuracy: 0.9937 - lr: 0.0010 - 23s/epoch - 578ms/step
# Epoch 131/150
#
# Epoch 131: val_loss did not improve from 0.02705
# 39/39 - 21s - loss: 0.1793 - accuracy: 0.9363 - val_loss: 0.0364 - val_accuracy: 0.9907 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 132/150
#
# Epoch 132: val_loss did not improve from 0.02705
# 39/39 - 21s - loss: 0.1685 - accuracy: 0.9352 - val_loss: 0.0322 - val_accuracy: 0.9929 - lr: 0.0010 - 21s/epoch - 541ms/step
# Epoch 133/150
#
# Epoch 133: val_loss did not improve from 0.02705
# 39/39 - 21s - loss: 0.1677 - accuracy: 0.9381 - val_loss: 0.0329 - val_accuracy: 0.9915 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 134/150
#
# Epoch 134: val_loss did not improve from 0.02705
# 39/39 - 21s - loss: 0.1530 - accuracy: 0.9427 - val_loss: 0.0356 - val_accuracy: 0.9909 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 135/150
#
# Epoch 135: val_loss did not improve from 0.02705
# 39/39 - 21s - loss: 0.1606 - accuracy: 0.9397 - val_loss: 0.0271 - val_accuracy: 0.9939 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 136/150
#
# Epoch 136: val_loss did not improve from 0.02705
# 39/39 - 21s - loss: 0.1569 - accuracy: 0.9391 - val_loss: 0.0286 - val_accuracy: 0.9919 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 137/150
#
# Epoch 137: val_loss improved from 0.02705 to 0.02491, saving model to model.h5
# 39/39 - 22s - loss: 0.1605 - accuracy: 0.9427 - val_loss: 0.0249 - val_accuracy: 0.9957 - lr: 0.0010 - 22s/epoch - 573ms/step
# Epoch 138/150
#
# Epoch 138: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1564 - accuracy: 0.9423 - val_loss: 0.0278 - val_accuracy: 0.9925 - lr: 0.0010 - 21s/epoch - 546ms/step
# Epoch 139/150
#
# Epoch 139: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1396 - accuracy: 0.9490 - val_loss: 0.0316 - val_accuracy: 0.9911 - lr: 0.0010 - 21s/epoch - 545ms/step
# Epoch 140/150
#
# Epoch 140: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1432 - accuracy: 0.9478 - val_loss: 0.0306 - val_accuracy: 0.9905 - lr: 0.0010 - 21s/epoch - 547ms/step
# Epoch 141/150
#
# Epoch 141: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1655 - accuracy: 0.9407 - val_loss: 0.0302 - val_accuracy: 0.9931 - lr: 0.0010 - 21s/epoch - 549ms/step
# Epoch 142/150
#
# Epoch 142: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1556 - accuracy: 0.9417 - val_loss: 0.0254 - val_accuracy: 0.9941 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 143/150
#
# Epoch 143: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1669 - accuracy: 0.9397 - val_loss: 0.0344 - val_accuracy: 0.9899 - lr: 0.0010 - 21s/epoch - 545ms/step
# Epoch 144/150
#
# Epoch 144: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1530 - accuracy: 0.9419 - val_loss: 0.0275 - val_accuracy: 0.9911 - lr: 0.0010 - 21s/epoch - 550ms/step
# Epoch 145/150
#
# Epoch 145: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1585 - accuracy: 0.9423 - val_loss: 0.0341 - val_accuracy: 0.9907 - lr: 0.0010 - 21s/epoch - 540ms/step
# Epoch 146/150
#
# Epoch 146: val_loss did not improve from 0.02491
# 39/39 - 22s - loss: 0.1487 - accuracy: 0.9486 - val_loss: 0.0359 - val_accuracy: 0.9893 - lr: 0.0010 - 22s/epoch - 557ms/step
# Epoch 147/150
#
# Epoch 147: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1536 - accuracy: 0.9401 - val_loss: 0.0325 - val_accuracy: 0.9899 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 148/150
#
# Epoch 148: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1479 - accuracy: 0.9474 - val_loss: 0.0310 - val_accuracy: 0.9915 - lr: 0.0010 - 21s/epoch - 544ms/step
# Epoch 149/150
#
# Epoch 149: val_loss did not improve from 0.02491
# 39/39 - 21s - loss: 0.1557 - accuracy: 0.9397 - val_loss: 0.0279 - val_accuracy: 0.9927 - lr: 0.0010 - 21s/epoch - 542ms/step
# Epoch 150/150
#
# Epoch 150: val_loss improved from 0.02491 to 0.02281, saving model to model.h5
# 39/39 - 22s - loss: 0.1528 - accuracy: 0.9444 - val_loss: 0.0228 - val_accuracy: 0.9941 - lr: 0.0010 - 22s/epoch - 570ms/step

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper left')
plt.show()

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper right')
plt.show()

# %%
model.save('/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/ML_Models/DenseNet_150_epoch/DenseNet201/Case_4_Left_CC/model.h5')

# %%
ypred = model.predict(xtest)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(ypred)):
    if np.argmax(ypred[i]) == np.argmax(ytest[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Total-test-data; 1268 	accurately-predicted-data: 1229 	 wrongly-predicted-data:  39
# Accuracy: 96.924 %

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(accurateindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(wrongindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
Ypred = model.predict(xtest)

Ypred = np.argmax(Ypred, axis=1)
Ytrue = np.argmax(ytest, axis=1)

cm = confusion_matrix(Ytrue, Ypred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')
