# %%
import tensorflow 

import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense,GlobalAveragePooling2D,Convolution2D,BatchNormalization
from tensorflow.keras.layers import Flatten,MaxPooling2D,Dropout

from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,img_to_array

from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import Adam

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import models

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print("Tensorflow-version:", tensorflow.__version__)
# Out:
# Tensorflow-version: 2.8.0

# %%
model_d=DenseNet169(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(8,activation='softmax')(x) #FC-layer
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step
# 51888128/51877672 [==============================] - 1s 0us/step

# %%
model_d=DenseNet169(weights='imagenet',include_top=False, input_shape=(128, 128, 3)) 

x=model_d.output

x= GlobalAveragePooling2D()(x)
x= BatchNormalization()(x)
x= Dropout(0.5)(x)
x= Dense(1024,activation='relu')(x) 
x= Dense(512,activation='relu')(x) 
x= BatchNormalization()(x)
x= Dropout(0.5)(x)

preds=Dense(3,activation='softmax')(x) #FC-layer

# %%
model=Model(inputs=model_d.input,outputs=preds)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 4, 4, 1440)  5760        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 4, 4, 1440)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 4, 4, 128)    184320      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 4, 4, 1472)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 4, 4, 1472)  5888        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 4, 4, 1472)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 4, 4, 128)    188416      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 4, 4, 1504)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 4, 4, 1504)  6016        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 4, 4, 1504)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 4, 4, 128)    192512      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 4, 4, 1536)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 4, 4, 1536)  6144        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 4, 4, 1536)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 4, 4, 128)    196608      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 4, 4, 1568)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 4, 4, 1568)  6272        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 4, 4, 1568)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 4, 4, 128)    200704      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 4, 4, 1600)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 4, 4, 1600)  6400        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 4, 4, 1600)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 4, 4, 128)    204800      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 4, 4, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 4, 4, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 4, 4, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 4, 4, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 4, 4, 1664)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1664)   6656        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1664)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1664)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1664)        6656        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1664)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1704960     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 14,882,883
# Trainable params: 14,720,131
# Non-trainable params: 162,752
# __________________________________________________________________________________________________

# %%
for layer in model.layers[:-8]:
    layer.trainable=False
    
for layer in model.layers[-8:]:
    layer.trainable=True

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 134, 134, 3)  0          ['input_2[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 64, 64, 64)   9408        ['zero_padding2d_2[0][0]']
#
#  conv1/bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1/conv[0][0]']
#
#  conv1/relu (Activation)        (None, 64, 64, 64)   0           ['conv1/bn[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 66, 66, 64)  0           ['conv1/relu[0][0]']
#  D)
#
#  pool1 (MaxPooling2D)           (None, 32, 32, 64)   0           ['zero_padding2d_3[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 32, 32, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 32, 32, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 32, 32, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 32, 32, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 32, 32, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 32, 32, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 32, 32, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 32, 32, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 32, 32, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 32, 32, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 32, 32, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 16, 16, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 16, 16, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 16, 16, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 16, 16, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 16, 16, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 16, 16, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 16, 16, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 16, 16, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 16, 16, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 16, 16, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 16, 16, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 16, 16, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 16, 16, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 16, 16, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 16, 16, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 16, 16, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 16, 16, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 16, 16, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 16, 16, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 16, 16, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 16, 16, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 16, 16, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 16, 16, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 16, 16, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 16, 16, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 16, 16, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 16, 16, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 16, 16, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 16, 16, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 16, 16, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 16, 16, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 16, 16, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 16, 16, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 16, 16, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 8, 8, 256)    0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 256)   1024        ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 128)    32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 8, 8, 288)   0           ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 8, 8, 288)   1152        ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 8, 8, 288)   0           ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 128)    36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 8, 8, 320)   0           ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 8, 8, 320)   1280        ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 8, 8, 320)   0           ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 128)    40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 8, 8, 352)   0           ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 8, 8, 352)   1408        ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 8, 8, 352)   0           ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 128)    45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 8, 8, 384)   0           ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 8, 8, 384)   1536        ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 8, 8, 384)   0           ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 128)    49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 128)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 32)     36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 8, 8, 416)   0           ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 8, 8, 416)   1664        ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 8, 8, 416)   0           ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 128)    53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 128)   512         ['conv4_block6_1_conv[0][0]']
#  ization)
#
# ...
#  ate)                                                             'conv5_block25_2_conv[0][0]']
#
#  conv5_block26_0_bn (BatchNorma  (None, 4, 4, 1440)  5760        ['conv5_block25_concat[0][0]']
#  lization)
#
#  conv5_block26_0_relu (Activati  (None, 4, 4, 1440)  0           ['conv5_block26_0_bn[0][0]']
#  on)
#
#  conv5_block26_1_conv (Conv2D)  (None, 4, 4, 128)    184320      ['conv5_block26_0_relu[0][0]']
#
#  conv5_block26_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block26_1_conv[0][0]']
#  lization)
#
#  conv5_block26_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block26_1_bn[0][0]']
#  on)
#
#  conv5_block26_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block26_1_relu[0][0]']
#
#  conv5_block26_concat (Concaten  (None, 4, 4, 1472)  0           ['conv5_block25_concat[0][0]',
#  ate)                                                             'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchNorma  (None, 4, 4, 1472)  5888        ['conv5_block26_concat[0][0]']
#  lization)
#
#  conv5_block27_0_relu (Activati  (None, 4, 4, 1472)  0           ['conv5_block27_0_bn[0][0]']
#  on)
#
#  conv5_block27_1_conv (Conv2D)  (None, 4, 4, 128)    188416      ['conv5_block27_0_relu[0][0]']
#
#  conv5_block27_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block27_1_conv[0][0]']
#  lization)
#
#  conv5_block27_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block27_1_bn[0][0]']
#  on)
#
#  conv5_block27_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block27_1_relu[0][0]']
#
#  conv5_block27_concat (Concaten  (None, 4, 4, 1504)  0           ['conv5_block26_concat[0][0]',
#  ate)                                                             'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchNorma  (None, 4, 4, 1504)  6016        ['conv5_block27_concat[0][0]']
#  lization)
#
#  conv5_block28_0_relu (Activati  (None, 4, 4, 1504)  0           ['conv5_block28_0_bn[0][0]']
#  on)
#
#  conv5_block28_1_conv (Conv2D)  (None, 4, 4, 128)    192512      ['conv5_block28_0_relu[0][0]']
#
#  conv5_block28_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block28_1_conv[0][0]']
#  lization)
#
#  conv5_block28_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block28_1_bn[0][0]']
#  on)
#
#  conv5_block28_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block28_1_relu[0][0]']
#
#  conv5_block28_concat (Concaten  (None, 4, 4, 1536)  0           ['conv5_block27_concat[0][0]',
#  ate)                                                             'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchNorma  (None, 4, 4, 1536)  6144        ['conv5_block28_concat[0][0]']
#  lization)
#
#  conv5_block29_0_relu (Activati  (None, 4, 4, 1536)  0           ['conv5_block29_0_bn[0][0]']
#  on)
#
#  conv5_block29_1_conv (Conv2D)  (None, 4, 4, 128)    196608      ['conv5_block29_0_relu[0][0]']
#
#  conv5_block29_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block29_1_conv[0][0]']
#  lization)
#
#  conv5_block29_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block29_1_bn[0][0]']
#  on)
#
#  conv5_block29_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block29_1_relu[0][0]']
#
#  conv5_block29_concat (Concaten  (None, 4, 4, 1568)  0           ['conv5_block28_concat[0][0]',
#  ate)                                                             'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchNorma  (None, 4, 4, 1568)  6272        ['conv5_block29_concat[0][0]']
#  lization)
#
#  conv5_block30_0_relu (Activati  (None, 4, 4, 1568)  0           ['conv5_block30_0_bn[0][0]']
#  on)
#
#  conv5_block30_1_conv (Conv2D)  (None, 4, 4, 128)    200704      ['conv5_block30_0_relu[0][0]']
#
#  conv5_block30_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block30_1_conv[0][0]']
#  lization)
#
#  conv5_block30_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block30_1_bn[0][0]']
#  on)
#
#  conv5_block30_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block30_1_relu[0][0]']
#
#  conv5_block30_concat (Concaten  (None, 4, 4, 1600)  0           ['conv5_block29_concat[0][0]',
#  ate)                                                             'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchNorma  (None, 4, 4, 1600)  6400        ['conv5_block30_concat[0][0]']
#  lization)
#
#  conv5_block31_0_relu (Activati  (None, 4, 4, 1600)  0           ['conv5_block31_0_bn[0][0]']
#  on)
#
#  conv5_block31_1_conv (Conv2D)  (None, 4, 4, 128)    204800      ['conv5_block31_0_relu[0][0]']
#
#  conv5_block31_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block31_1_conv[0][0]']
#  lization)
#
#  conv5_block31_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block31_1_bn[0][0]']
#  on)
#
#  conv5_block31_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block31_1_relu[0][0]']
#
#  conv5_block31_concat (Concaten  (None, 4, 4, 1632)  0           ['conv5_block30_concat[0][0]',
#  ate)                                                             'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchNorma  (None, 4, 4, 1632)  6528        ['conv5_block31_concat[0][0]']
#  lization)
#
#  conv5_block32_0_relu (Activati  (None, 4, 4, 1632)  0           ['conv5_block32_0_bn[0][0]']
#  on)
#
#  conv5_block32_1_conv (Conv2D)  (None, 4, 4, 128)    208896      ['conv5_block32_0_relu[0][0]']
#
#  conv5_block32_1_bn (BatchNorma  (None, 4, 4, 128)   512         ['conv5_block32_1_conv[0][0]']
#  lization)
#
#  conv5_block32_1_relu (Activati  (None, 4, 4, 128)   0           ['conv5_block32_1_bn[0][0]']
#  on)
#
#  conv5_block32_2_conv (Conv2D)  (None, 4, 4, 32)     36864       ['conv5_block32_1_relu[0][0]']
#
#  conv5_block32_concat (Concaten  (None, 4, 4, 1664)  0           ['conv5_block31_concat[0][0]',
#  ate)                                                             'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 4, 4, 1664)   6656        ['conv5_block32_concat[0][0]']
#
#  relu (Activation)              (None, 4, 4, 1664)   0           ['bn[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1664)        0           ['relu[0][0]']
#  obalAveragePooling2D)
#
#  batch_normalization_2 (BatchNo  (None, 1664)        6656        ['global_average_pooling2d_1[0][0
#  rmalization)                                                    ]']
#
#  dropout_2 (Dropout)            (None, 1664)         0           ['batch_normalization_2[0][0]']
#
#  dense_3 (Dense)                (None, 1024)         1704960     ['dropout_2[0][0]']
#
#  dense_4 (Dense)                (None, 512)          524800      ['dense_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 512)         2048        ['dense_4[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 512)          0           ['batch_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 3)            1539        ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 14,882,883
# Trainable params: 2,235,651
# Non-trainable params: 12,647,232
# __________________________________________________________________________________________________

# %%
data=[]
labels=[]
random.seed(42)
# imagePaths = sorted(list(os.listdir("/content/drive/MyDrive/Mini_DDSM_Upload")))
imagePaths = ['Benign','Cancer','Normal']
random.shuffle(imagePaths)
print(imagePaths)
# Out:
# ['Cancer', 'Benign', 'Normal']

# %%
for img in imagePaths:
    path=sorted(list(os.listdir("/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img)))
    for i in path:
      for flip in range(2):
          if(flip == 0):
            print("\n****************************************")
            print("Original")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            print(image_path)
            # print("Reading image")
            image = cv2.imread(image_path)
            # print("Imread ", i)
            # # print(image)
            # if('RIGHT' in i):
            #   print("Image is right sided. It has to be flipped")
            #   image = cv2.flip(image,1)
            #   print("Image has been flipped")
              
              #For Rotation
            # height, width = image.shape[:2]
            # center = (width/2, height/2)
            # M = cv2.getRotationMatrix2D(center, angle, 1.0)
            # image = cv2.warpAffine(image, M, (width, height))     
            # print("\nDirectly Resizing image")
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResized Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            # print("Label - ",l)
            labels.append(l)
          else:
            print("\n")
            print("FLIPPED")
            image_path = "/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/"+img+"/"+i
            # print("\n")
            # print("Image Path - ",image_path)
            # print("Reading image ",i)
            image = cv2.imread(image_path)
            # print("Flipping Image")
            image = cv2.flip(image,1)
            
            # print("\nResizing the flipped image")
            image = cv2.resize(image, (128,128))
            # print(image)
            # print("\nResizing Over")
            
            # print("\nGoing in tensorflow preprocessing")
            image = tensorflow.keras.preprocessing.image.img_to_array(image)
            # print("Appending image data")
            data.append(image)
            l = label = img
            print("Label - ",l)
            labels.append(l)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/438_A_0159_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/439_A_0159_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/43_A_0015_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/440_A_0159_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/441_A_0200_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/442_A_0200_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/443_A_0200_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/444_A_0200_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/445_A_0201_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/446_A_0201_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/447_A_0201_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/448_A_0201_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/449_A_0202_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/44_A_0015_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/450_A_0202_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/451_A_0202_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/452_A_0202_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/453_A_0203_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/454_A_0203_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/455_A_0203_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/456_A_0203_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/457_A_0204_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/458_A_0204_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/459_A_0204_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/45_A_0016_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/460_A_0204_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/461_A_0205_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/462_A_0205_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/463_A_0205_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/464_A_0205_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/465_A_0206_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/466_A_0206_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/467_A_0206_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/468_A_0206_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/469_A_0207_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/46_A_0016_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/470_A_0207_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/471_A_0207_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/472_A_0207_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/473_A_0208_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/474_A_0208_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/475_A_0208_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/476_A_0208_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/477_A_0209_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/478_A_0209_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/479_A_0209_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/47_A_0016_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/480_A_0209_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/481_A_0210_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/482_A_0210_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/483_A_0210_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/484_A_0210_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/485_A_0211_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/486_A_0211_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/487_A_0211_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/488_A_0211_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/489_A_0212_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/48_A_0016_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/490_A_0212_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/491_A_0212_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/492_A_0212_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/493_A_0214_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/494_A_0214_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/495_A_0214_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/496_A_0214_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/497_A_0215_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/498_A_0215_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/499_A_0215_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/49_A_0018_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/4_A_0002_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/500_A_0215_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/501_A_0216_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/502_A_0216_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/503_A_0216_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/504_A_0216_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/505_A_0217_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/506_A_0217_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/507_A_0217_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/508_A_0217_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/509_A_0218_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/50_A_0018_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/510_A_0218_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/511_A_0218_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/512_A_0218_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/513_A_0219_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/514_A_0219_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/515_A_0219_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/516_A_0219_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/517_A_0220_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/518_A_0220_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/519_A_0220_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/51_A_0018_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/520_A_0220_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/521_A_0221_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/522_A_0221_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/523_A_0221_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/524_A_0221_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/525_A_0222_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/526_A_0222_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/527_A_0222_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/528_A_0222_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/529_A_0223_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/52_A_0018_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/530_A_0223_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/531_A_0223_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/532_A_0223_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/533_A_0224_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/534_A_0224_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/535_A_0224_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/536_A_0224_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/537_A_0225_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/538_A_0225_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/539_A_0225_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/53_A_0020_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/540_A_0225_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/541_A_0226_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/542_A_0226_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/543_A_0226_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/544_A_0226_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/545_A_0227_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/546_A_0227_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/547_A_0227_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/548_A_0227_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/549_A_0229_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/54_A_0020_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/550_A_0229_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/551_A_0229_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/552_A_0229_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/553_A_0230_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/554_A_0230_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/555_A_0230_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/556_A_0230_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/557_A_0232_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/558_A_0232_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/559_A_0232_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/55_A_0020_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/560_A_0232_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/561_A_0233_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/562_A_0233_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/563_A_0233_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/564_A_0233_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/565_A_0234_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/566_A_0234_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/567_A_0234_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/568_A_0234_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/569_A_0235_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/56_A_0020_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/570_A_0235_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/571_A_0235_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/572_A_0235_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/573_A_0236_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/574_A_0236_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/575_A_0236_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/576_A_0236_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/577_A_0237_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/578_A_0237_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/579_A_0237_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/57_A_0022_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/580_A_0237_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/581_A_0238_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/582_A_0238_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/583_A_0238_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/584_A_0238_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/585_A_0239_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/586_A_0239_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/587_A_0239_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/588_A_0239_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/589_A_0240_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/58_A_0022_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/590_A_0240_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/591_A_0240_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/592_A_0240_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/593_A_0241_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/594_A_0241_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/595_A_0241_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/596_A_0241_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/597_A_0242_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/598_A_0242_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/599_A_0242_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/59_A_0022_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/5_A_0003_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/600_A_0242_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/601_A_0243_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/602_A_0243_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/603_A_0243_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/604_A_0243_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/605_A_0244_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/606_A_0244_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/607_A_0244_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/608_A_0244_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/609_A_0245_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/60_A_0022_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/610_A_0245_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/611_A_0245_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/612_A_0245_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/613_A_0246_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/614_A_0246_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/615_A_0246_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/616_A_0246_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/617_A_0247_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/618_A_0247_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/619_A_0247_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/61_A_0024_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/620_A_0247_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/621_A_0249_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/622_A_0249_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/623_A_0249_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/624_A_0249_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/625_A_0250_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/626_A_0250_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/627_A_0250_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/628_A_0250_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/629_A_0251_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/62_A_0024_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/630_A_0251_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/631_A_0251_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/632_A_0251_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/633_A_0252_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/634_A_0252_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/635_A_0252_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/636_A_0252_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/637_A_0253_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/638_A_0253_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/639_A_0253_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/63_A_0024_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/640_A_0253_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/641_A_0254_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/642_A_0254_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/643_A_0254_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/644_A_0254_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/645_A_0255_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/646_A_0255_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/647_A_0255_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/648_A_0255_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/649_A_0256_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/64_A_0024_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/650_A_0256_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/651_A_0256_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/652_A_0256_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/653_A_0257_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/654_A_0257_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/655_A_0257_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/656_A_0257_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/657_A_0258_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/658_A_0258_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/659_A_0258_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/65_A_0026_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/660_A_0258_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/661_A_0259_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/662_A_0259_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/663_A_0259_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/664_A_0259_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/665_A_0260_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/666_A_0260_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/667_A_0260_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/668_A_0260_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/669_A_0261_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/66_A_0026_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/670_A_0261_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/671_A_0261_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/672_A_0261_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/673_A_0262_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/674_A_0262_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/675_A_0262_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/676_A_0262_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/677_A_0263_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/678_A_0263_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/679_A_0263_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ...
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/920_A_0334_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/921_A_0335_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/922_A_0335_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/923_A_0335_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/924_A_0335_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/925_A_0336_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/926_A_0336_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/927_A_0336_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/928_A_0336_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/929_A_0337_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/92_A_0035_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/930_A_0337_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/931_A_0337_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/932_A_0337_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/933_A_0338_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/934_A_0338_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/935_A_0338_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/936_A_0338_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/937_A_0339_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/938_A_0339_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/939_A_0339_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/93_A_0036_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/940_A_0339_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/941_A_0341_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/942_A_0341_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/943_A_0341_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/944_A_0341_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/945_A_0342_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/946_A_0342_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/947_A_0342_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/948_A_0342_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/949_A_0343_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/94_A_0036_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/950_A_0343_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/951_A_0343_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/952_A_0343_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/953_A_0344_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/954_A_0344_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/955_A_0344_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/956_A_0344_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/957_A_0345_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/958_A_0345_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/959_A_0345_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/95_A_0036_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/960_A_0345_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/961_A_0347_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/962_A_0347_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/963_A_0347_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/964_A_0347_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/965_A_0348_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/966_A_0348_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/967_A_0348_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/968_A_0348_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/969_A_0349_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/96_A_0036_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/970_A_0349_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/971_A_0349_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/972_A_0349_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/973_A_0351_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/974_A_0351_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/975_A_0351_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/976_A_0351_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/977_A_0352_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/978_A_0352_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/979_A_0352_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/97_A_0037_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/980_A_0352_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/981_A_0354_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/982_A_0354_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/983_A_0354_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/984_A_0354_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/985_A_0355_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/986_A_0355_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/987_A_0355_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/988_A_0355_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/989_A_0356_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/98_A_0037_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/990_A_0356_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/991_A_0356_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/992_A_0356_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/993_A_0357_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/994_A_0357_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/995_A_0357_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/996_A_0357_1.RIGHT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/997_A_0358_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/998_A_0358_1.RIGHT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/999_A_0358_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/99_A_0037_1.LEFT_CC.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal
#
# ****************************************
# Original
# /content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/Normal/9_A_0005_1.LEFT_MLO.LJPEG.1_highpass.png
#
#
# FLIPPED
# Label -  Normal

# %%
print("Length of dataset = ",len(labels))
# Out:
# Length of dataset =  19390

# %%
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
mlb = LabelBinarizer()
labels = mlb.fit_transform(labels)
print(labels[0])
# Out:
# [0 1 0]

# %%
(xtrain,xtest,ytrain,ytest)=train_test_split(data,labels,test_size=0.2,random_state=42)
print(xtrain.shape, xtest.shape)
# Out:
# (15512, 128, 128, 3) (3878, 128, 128, 3)

# %%
anne = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)


datagen.fit(xtrain)
# Fits-the-model
history = model.fit_generator(datagen.flow(xtrain, ytrain, batch_size=128),
               steps_per_epoch=xtrain.shape[0] //128,
               epochs=150, #try 100
               verbose=2,
               callbacks=[anne, checkpoint],
               validation_data=(xtrain, ytrain))
# Out:
# Epoch 1/150
#
# Epoch 1: val_loss improved from inf to 0.80383, saving model to model.h5
# 121/121 - 97s - loss: 1.2144 - accuracy: 0.5291 - val_loss: 0.8038 - val_accuracy: 0.6224 - lr: 0.0010 - 97s/epoch - 805ms/step
# Epoch 2/150
#
# Epoch 2: val_loss improved from 0.80383 to 0.71213, saving model to model.h5
# 121/121 - 70s - loss: 0.8895 - accuracy: 0.5733 - val_loss: 0.7121 - val_accuracy: 0.6664 - lr: 0.0010 - 70s/epoch - 580ms/step
# Epoch 3/150
#
# Epoch 3: val_loss improved from 0.71213 to 0.67561, saving model to model.h5
# 121/121 - 71s - loss: 0.8120 - accuracy: 0.6060 - val_loss: 0.6756 - val_accuracy: 0.6954 - lr: 0.0010 - 71s/epoch - 585ms/step
# Epoch 4/150
#
# Epoch 4: val_loss improved from 0.67561 to 0.67561, saving model to model.h5
# 121/121 - 71s - loss: 0.7934 - accuracy: 0.6136 - val_loss: 0.6756 - val_accuracy: 0.7023 - lr: 0.0010 - 71s/epoch - 584ms/step
# Epoch 5/150
#
# Epoch 5: val_loss improved from 0.67561 to 0.63994, saving model to model.h5
# 121/121 - 70s - loss: 0.7696 - accuracy: 0.6300 - val_loss: 0.6399 - val_accuracy: 0.7158 - lr: 0.0010 - 70s/epoch - 581ms/step
# Epoch 6/150
#
# Epoch 6: val_loss improved from 0.63994 to 0.61179, saving model to model.h5
# 121/121 - 70s - loss: 0.7542 - accuracy: 0.6338 - val_loss: 0.6118 - val_accuracy: 0.7316 - lr: 0.0010 - 70s/epoch - 576ms/step
# Epoch 7/150
#
# Epoch 7: val_loss did not improve from 0.61179
# 121/121 - 69s - loss: 0.7453 - accuracy: 0.6449 - val_loss: 0.6411 - val_accuracy: 0.7033 - lr: 0.0010 - 69s/epoch - 570ms/step
# Epoch 8/150
#
# Epoch 8: val_loss improved from 0.61179 to 0.59293, saving model to model.h5
# 121/121 - 70s - loss: 0.7417 - accuracy: 0.6452 - val_loss: 0.5929 - val_accuracy: 0.7332 - lr: 0.0010 - 70s/epoch - 578ms/step
# Epoch 9/150
#
# Epoch 9: val_loss improved from 0.59293 to 0.58619, saving model to model.h5
# 121/121 - 69s - loss: 0.7323 - accuracy: 0.6507 - val_loss: 0.5862 - val_accuracy: 0.7403 - lr: 0.0010 - 69s/epoch - 574ms/step
# Epoch 10/150
#
# Epoch 10: val_loss improved from 0.58619 to 0.56598, saving model to model.h5
# 121/121 - 70s - loss: 0.7249 - accuracy: 0.6529 - val_loss: 0.5660 - val_accuracy: 0.7488 - lr: 0.0010 - 70s/epoch - 579ms/step
# Epoch 11/150
#
# Epoch 11: val_loss did not improve from 0.56598
# 121/121 - 69s - loss: 0.7162 - accuracy: 0.6609 - val_loss: 0.5687 - val_accuracy: 0.7495 - lr: 0.0010 - 69s/epoch - 568ms/step
# Epoch 12/150
#
# Epoch 12: val_loss improved from 0.56598 to 0.56172, saving model to model.h5
# 121/121 - 70s - loss: 0.7123 - accuracy: 0.6645 - val_loss: 0.5617 - val_accuracy: 0.7638 - lr: 0.0010 - 70s/epoch - 576ms/step
# Epoch 13/150
#
# Epoch 13: val_loss improved from 0.56172 to 0.55351, saving model to model.h5
# 121/121 - 70s - loss: 0.6976 - accuracy: 0.6691 - val_loss: 0.5535 - val_accuracy: 0.7574 - lr: 0.0010 - 70s/epoch - 578ms/step
# Epoch 14/150
#
# Epoch 14: val_loss improved from 0.55351 to 0.53369, saving model to model.h5
# 121/121 - 70s - loss: 0.6946 - accuracy: 0.6695 - val_loss: 0.5337 - val_accuracy: 0.7671 - lr: 0.0010 - 70s/epoch - 581ms/step
# Epoch 15/150
#
# Epoch 15: val_loss did not improve from 0.53369
# 121/121 - 69s - loss: 0.6977 - accuracy: 0.6726 - val_loss: 0.5352 - val_accuracy: 0.7792 - lr: 0.0010 - 69s/epoch - 571ms/step
# Epoch 16/150
#
# Epoch 16: val_loss improved from 0.53369 to 0.53160, saving model to model.h5
# 121/121 - 70s - loss: 0.6836 - accuracy: 0.6801 - val_loss: 0.5316 - val_accuracy: 0.7673 - lr: 0.0010 - 70s/epoch - 576ms/step
# Epoch 17/150
#
# Epoch 17: val_loss improved from 0.53160 to 0.50934, saving model to model.h5
# 121/121 - 70s - loss: 0.6773 - accuracy: 0.6832 - val_loss: 0.5093 - val_accuracy: 0.7893 - lr: 0.0010 - 70s/epoch - 581ms/step
# Epoch 18/150
#
# Epoch 18: val_loss did not improve from 0.50934
# 121/121 - 68s - loss: 0.6711 - accuracy: 0.6898 - val_loss: 0.5192 - val_accuracy: 0.7722 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 19/150
#
# Epoch 19: val_loss improved from 0.50934 to 0.50638, saving model to model.h5
# 121/121 - 69s - loss: 0.6620 - accuracy: 0.6970 - val_loss: 0.5064 - val_accuracy: 0.7936 - lr: 0.0010 - 69s/epoch - 572ms/step
# Epoch 20/150
#
# Epoch 20: val_loss did not improve from 0.50638
# 121/121 - 69s - loss: 0.6616 - accuracy: 0.6971 - val_loss: 0.5184 - val_accuracy: 0.7829 - lr: 0.0010 - 69s/epoch - 569ms/step
# Epoch 21/150
#
# Epoch 21: val_loss improved from 0.50638 to 0.46986, saving model to model.h5
# 121/121 - 70s - loss: 0.6444 - accuracy: 0.7050 - val_loss: 0.4699 - val_accuracy: 0.8060 - lr: 0.0010 - 70s/epoch - 580ms/step
# Epoch 22/150
#
# Epoch 22: val_loss did not improve from 0.46986
# 121/121 - 69s - loss: 0.6399 - accuracy: 0.7072 - val_loss: 0.4833 - val_accuracy: 0.7909 - lr: 0.0010 - 69s/epoch - 567ms/step
# Epoch 23/150
#
# Epoch 23: val_loss did not improve from 0.46986
# 121/121 - 69s - loss: 0.6385 - accuracy: 0.7083 - val_loss: 0.4828 - val_accuracy: 0.8065 - lr: 0.0010 - 69s/epoch - 566ms/step
# Epoch 24/150
#
# Epoch 24: val_loss improved from 0.46986 to 0.45140, saving model to model.h5
# 121/121 - 70s - loss: 0.6320 - accuracy: 0.7126 - val_loss: 0.4514 - val_accuracy: 0.8231 - lr: 0.0010 - 70s/epoch - 580ms/step
# Epoch 25/150
#
# Epoch 25: val_loss did not improve from 0.45140
# 121/121 - 69s - loss: 0.6244 - accuracy: 0.7142 - val_loss: 0.4744 - val_accuracy: 0.8022 - lr: 0.0010 - 69s/epoch - 573ms/step
# Epoch 26/150
#
# Epoch 26: val_loss improved from 0.45140 to 0.43293, saving model to model.h5
# 121/121 - 70s - loss: 0.6272 - accuracy: 0.7131 - val_loss: 0.4329 - val_accuracy: 0.8302 - lr: 0.0010 - 70s/epoch - 579ms/step
# Epoch 27/150
#
# Epoch 27: val_loss improved from 0.43293 to 0.42368, saving model to model.h5
# 121/121 - 70s - loss: 0.6098 - accuracy: 0.7237 - val_loss: 0.4237 - val_accuracy: 0.8415 - lr: 0.0010 - 70s/epoch - 575ms/step
# Epoch 28/150
#
# Epoch 28: val_loss did not improve from 0.42368
# 121/121 - 68s - loss: 0.6129 - accuracy: 0.7259 - val_loss: 0.4323 - val_accuracy: 0.8210 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 29/150
#
# Epoch 29: val_loss improved from 0.42368 to 0.40908, saving model to model.h5
# 121/121 - 69s - loss: 0.5982 - accuracy: 0.7302 - val_loss: 0.4091 - val_accuracy: 0.8492 - lr: 0.0010 - 69s/epoch - 574ms/step
# Epoch 30/150
#
# Epoch 30: val_loss did not improve from 0.40908
# 121/121 - 68s - loss: 0.5933 - accuracy: 0.7334 - val_loss: 0.4159 - val_accuracy: 0.8402 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 31/150
#
# Epoch 31: val_loss did not improve from 0.40908
# 121/121 - 69s - loss: 0.5826 - accuracy: 0.7421 - val_loss: 0.4096 - val_accuracy: 0.8429 - lr: 0.0010 - 69s/epoch - 568ms/step
# Epoch 32/150
#
# Epoch 32: val_loss improved from 0.40908 to 0.38779, saving model to model.h5
# 121/121 - 70s - loss: 0.5891 - accuracy: 0.7381 - val_loss: 0.3878 - val_accuracy: 0.8585 - lr: 0.0010 - 70s/epoch - 575ms/step
# Epoch 33/150
#
# Epoch 33: val_loss improved from 0.38779 to 0.37161, saving model to model.h5
# 121/121 - 69s - loss: 0.5733 - accuracy: 0.7465 - val_loss: 0.3716 - val_accuracy: 0.8622 - lr: 0.0010 - 69s/epoch - 573ms/step
# Epoch 34/150
#
# Epoch 34: val_loss did not improve from 0.37161
# 121/121 - 68s - loss: 0.5677 - accuracy: 0.7501 - val_loss: 0.3760 - val_accuracy: 0.8545 - lr: 0.0010 - 68s/epoch - 564ms/step
# Epoch 35/150
#
# Epoch 35: val_loss improved from 0.37161 to 0.37022, saving model to model.h5
# 121/121 - 69s - loss: 0.5696 - accuracy: 0.7452 - val_loss: 0.3702 - val_accuracy: 0.8609 - lr: 0.0010 - 69s/epoch - 573ms/step
# Epoch 36/150
#
# Epoch 36: val_loss improved from 0.37022 to 0.36672, saving model to model.h5
# 121/121 - 70s - loss: 0.5535 - accuracy: 0.7517 - val_loss: 0.3667 - val_accuracy: 0.8611 - lr: 0.0010 - 70s/epoch - 576ms/step
# Epoch 37/150
#
# Epoch 37: val_loss did not improve from 0.36672
# 121/121 - 68s - loss: 0.5527 - accuracy: 0.7598 - val_loss: 0.3701 - val_accuracy: 0.8642 - lr: 0.0010 - 68s/epoch - 566ms/step
# Epoch 38/150
#
# Epoch 38: val_loss improved from 0.36672 to 0.34880, saving model to model.h5
# 121/121 - 70s - loss: 0.5487 - accuracy: 0.7591 - val_loss: 0.3488 - val_accuracy: 0.8724 - lr: 0.0010 - 70s/epoch - 577ms/step
# Epoch 39/150
#
# Epoch 39: val_loss did not improve from 0.34880
# 121/121 - 69s - loss: 0.5415 - accuracy: 0.7650 - val_loss: 0.3496 - val_accuracy: 0.8756 - lr: 0.0010 - 69s/epoch - 568ms/step
# Epoch 40/150
#
# Epoch 40: val_loss improved from 0.34880 to 0.34695, saving model to model.h5
# 121/121 - 70s - loss: 0.5345 - accuracy: 0.7700 - val_loss: 0.3470 - val_accuracy: 0.8741 - lr: 0.0010 - 70s/epoch - 577ms/step
# Epoch 41/150
#
# Epoch 41: val_loss improved from 0.34695 to 0.32204, saving model to model.h5
# 121/121 - 69s - loss: 0.5381 - accuracy: 0.7622 - val_loss: 0.3220 - val_accuracy: 0.8865 - lr: 0.0010 - 69s/epoch - 574ms/step
# Epoch 42/150
#
# Epoch 42: val_loss did not improve from 0.32204
# 121/121 - 68s - loss: 0.5215 - accuracy: 0.7728 - val_loss: 0.3290 - val_accuracy: 0.8841 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 43/150
#
# Epoch 43: val_loss did not improve from 0.32204
# 121/121 - 68s - loss: 0.5220 - accuracy: 0.7728 - val_loss: 0.3269 - val_accuracy: 0.8817 - lr: 0.0010 - 68s/epoch - 563ms/step
# Epoch 44/150
#
# Epoch 44: val_loss improved from 0.32204 to 0.32000, saving model to model.h5
# 121/121 - 70s - loss: 0.5061 - accuracy: 0.7811 - val_loss: 0.3200 - val_accuracy: 0.8893 - lr: 0.0010 - 70s/epoch - 574ms/step
# Epoch 45/150
#
# Epoch 45: val_loss improved from 0.32000 to 0.30966, saving model to model.h5
# 121/121 - 69s - loss: 0.5146 - accuracy: 0.7772 - val_loss: 0.3097 - val_accuracy: 0.8914 - lr: 0.0010 - 69s/epoch - 572ms/step
# Epoch 46/150
#
# Epoch 46: val_loss improved from 0.30966 to 0.30526, saving model to model.h5
# 121/121 - 70s - loss: 0.5059 - accuracy: 0.7850 - val_loss: 0.3053 - val_accuracy: 0.8966 - lr: 0.0010 - 70s/epoch - 576ms/step
# Epoch 47/150
#
# Epoch 47: val_loss improved from 0.30526 to 0.30031, saving model to model.h5
# 121/121 - 69s - loss: 0.4970 - accuracy: 0.7861 - val_loss: 0.3003 - val_accuracy: 0.9032 - lr: 0.0010 - 69s/epoch - 573ms/step
# Epoch 48/150
#
# Epoch 48: val_loss improved from 0.30031 to 0.28599, saving model to model.h5
# 121/121 - 70s - loss: 0.4913 - accuracy: 0.7911 - val_loss: 0.2860 - val_accuracy: 0.9029 - lr: 0.0010 - 70s/epoch - 576ms/step
# Epoch 49/150
#
# Epoch 49: val_loss improved from 0.28599 to 0.28007, saving model to model.h5
# 121/121 - 70s - loss: 0.4925 - accuracy: 0.7895 - val_loss: 0.2801 - val_accuracy: 0.9028 - lr: 0.0010 - 70s/epoch - 575ms/step
# Epoch 50/150
#
# Epoch 50: val_loss did not improve from 0.28007
# 121/121 - 69s - loss: 0.4897 - accuracy: 0.7885 - val_loss: 0.2820 - val_accuracy: 0.9010 - lr: 0.0010 - 69s/epoch - 570ms/step
# Epoch 51/150
#
# Epoch 51: val_loss improved from 0.28007 to 0.27991, saving model to model.h5
# 121/121 - 69s - loss: 0.4777 - accuracy: 0.7949 - val_loss: 0.2799 - val_accuracy: 0.9052 - lr: 0.0010 - 69s/epoch - 574ms/step
# Epoch 52/150
#
# Epoch 52: val_loss improved from 0.27991 to 0.27250, saving model to model.h5
# 121/121 - 70s - loss: 0.4781 - accuracy: 0.7990 - val_loss: 0.2725 - val_accuracy: 0.9079 - lr: 0.0010 - 70s/epoch - 575ms/step
# Epoch 53/150
#
# Epoch 53: val_loss improved from 0.27250 to 0.26358, saving model to model.h5
# 121/121 - 69s - loss: 0.4756 - accuracy: 0.8000 - val_loss: 0.2636 - val_accuracy: 0.9103 - lr: 0.0010 - 69s/epoch - 573ms/step
# Epoch 54/150
#
# Epoch 54: val_loss did not improve from 0.26358
# 121/121 - 69s - loss: 0.4774 - accuracy: 0.7956 - val_loss: 0.2718 - val_accuracy: 0.9074 - lr: 0.0010 - 69s/epoch - 568ms/step
# Epoch 55/150
#
# Epoch 55: val_loss improved from 0.26358 to 0.25038, saving model to model.h5
# 121/121 - 69s - loss: 0.4645 - accuracy: 0.8009 - val_loss: 0.2504 - val_accuracy: 0.9159 - lr: 0.0010 - 69s/epoch - 566ms/step
# Epoch 56/150
#
# Epoch 56: val_loss improved from 0.25038 to 0.23848, saving model to model.h5
# 121/121 - 68s - loss: 0.4570 - accuracy: 0.8065 - val_loss: 0.2385 - val_accuracy: 0.9183 - lr: 0.0010 - 68s/epoch - 566ms/step
# Epoch 57/150
#
# Epoch 57: val_loss did not improve from 0.23848
# 121/121 - 67s - loss: 0.4508 - accuracy: 0.8092 - val_loss: 0.2533 - val_accuracy: 0.9153 - lr: 0.0010 - 67s/epoch - 557ms/step
# Epoch 58/150
#
# Epoch 58: val_loss did not improve from 0.23848
# 121/121 - 67s - loss: 0.4531 - accuracy: 0.8080 - val_loss: 0.2494 - val_accuracy: 0.9159 - lr: 0.0010 - 67s/epoch - 556ms/step
# Epoch 59/150
#
# Epoch 59: val_loss did not improve from 0.23848
# 121/121 - 68s - loss: 0.4499 - accuracy: 0.8103 - val_loss: 0.2420 - val_accuracy: 0.9212 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 60/150
#
# Epoch 60: val_loss improved from 0.23848 to 0.23704, saving model to model.h5
# 121/121 - 68s - loss: 0.4491 - accuracy: 0.8115 - val_loss: 0.2370 - val_accuracy: 0.9205 - lr: 0.0010 - 68s/epoch - 566ms/step
# Epoch 61/150
#
# Epoch 61: val_loss improved from 0.23704 to 0.23398, saving model to model.h5
# 121/121 - 69s - loss: 0.4446 - accuracy: 0.8129 - val_loss: 0.2340 - val_accuracy: 0.9235 - lr: 0.0010 - 69s/epoch - 571ms/step
# Epoch 62/150
#
# Epoch 62: val_loss did not improve from 0.23398
# 121/121 - 68s - loss: 0.4485 - accuracy: 0.8116 - val_loss: 0.2355 - val_accuracy: 0.9270 - lr: 0.0010 - 68s/epoch - 558ms/step
# Epoch 63/150
#
# Epoch 63: val_loss did not improve from 0.23398
# 121/121 - 68s - loss: 0.4360 - accuracy: 0.8178 - val_loss: 0.2347 - val_accuracy: 0.9225 - lr: 0.0010 - 68s/epoch - 559ms/step
# Epoch 64/150
#
# Epoch 64: val_loss improved from 0.23398 to 0.21769, saving model to model.h5
# 121/121 - 68s - loss: 0.4300 - accuracy: 0.8205 - val_loss: 0.2177 - val_accuracy: 0.9310 - lr: 0.0010 - 68s/epoch - 566ms/step
# Epoch 65/150
#
# Epoch 65: val_loss improved from 0.21769 to 0.21271, saving model to model.h5
# 121/121 - 69s - loss: 0.4202 - accuracy: 0.8239 - val_loss: 0.2127 - val_accuracy: 0.9306 - lr: 0.0010 - 69s/epoch - 569ms/step
# Epoch 66/150
#
# Epoch 66: val_loss improved from 0.21271 to 0.20983, saving model to model.h5
# 121/121 - 69s - loss: 0.4166 - accuracy: 0.8279 - val_loss: 0.2098 - val_accuracy: 0.9329 - lr: 0.0010 - 69s/epoch - 568ms/step
# Epoch 67/150
#
# Epoch 67: val_loss improved from 0.20983 to 0.19516, saving model to model.h5
# 121/121 - 68s - loss: 0.4070 - accuracy: 0.8286 - val_loss: 0.1952 - val_accuracy: 0.9400 - lr: 0.0010 - 68s/epoch - 562ms/step
# Epoch 68/150
#
# Epoch 68: val_loss did not improve from 0.19516
# 121/121 - 68s - loss: 0.4144 - accuracy: 0.8244 - val_loss: 0.2008 - val_accuracy: 0.9338 - lr: 0.0010 - 68s/epoch - 559ms/step
# Epoch 69/150
#
# Epoch 69: val_loss did not improve from 0.19516
# 121/121 - 68s - loss: 0.4082 - accuracy: 0.8318 - val_loss: 0.2042 - val_accuracy: 0.9395 - lr: 0.0010 - 68s/epoch - 559ms/step
# Epoch 70/150
#
# Epoch 70: val_loss improved from 0.19516 to 0.19017, saving model to model.h5
# 121/121 - 68s - loss: 0.4173 - accuracy: 0.8289 - val_loss: 0.1902 - val_accuracy: 0.9439 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 71/150
#
# Epoch 71: val_loss did not improve from 0.19017
# 121/121 - 68s - loss: 0.4034 - accuracy: 0.8330 - val_loss: 0.1977 - val_accuracy: 0.9375 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 72/150
#
# Epoch 72: val_loss improved from 0.19017 to 0.18919, saving model to model.h5
# 121/121 - 69s - loss: 0.4031 - accuracy: 0.8367 - val_loss: 0.1892 - val_accuracy: 0.9450 - lr: 0.0010 - 69s/epoch - 566ms/step
# Epoch 73/150
#
# Epoch 73: val_loss did not improve from 0.18919
# 121/121 - 68s - loss: 0.4018 - accuracy: 0.8365 - val_loss: 0.1923 - val_accuracy: 0.9404 - lr: 0.0010 - 68s/epoch - 559ms/step
# Epoch 74/150
#
# Epoch 74: val_loss did not improve from 0.18919
# 121/121 - 67s - loss: 0.4042 - accuracy: 0.8350 - val_loss: 0.1894 - val_accuracy: 0.9398 - lr: 0.0010 - 67s/epoch - 557ms/step
# Epoch 75/150
#
# Epoch 75: val_loss improved from 0.18919 to 0.18301, saving model to model.h5
# 121/121 - 69s - loss: 0.3993 - accuracy: 0.8340 - val_loss: 0.1830 - val_accuracy: 0.9449 - lr: 0.0010 - 69s/epoch - 568ms/step
# Epoch 76/150
#
# Epoch 76: val_loss did not improve from 0.18301
# 121/121 - 68s - loss: 0.3965 - accuracy: 0.8365 - val_loss: 0.1838 - val_accuracy: 0.9394 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 77/150
#
# Epoch 77: val_loss improved from 0.18301 to 0.17260, saving model to model.h5
# 121/121 - 69s - loss: 0.3877 - accuracy: 0.8411 - val_loss: 0.1726 - val_accuracy: 0.9506 - lr: 0.0010 - 69s/epoch - 568ms/step
# Epoch 78/150
#
# Epoch 78: val_loss did not improve from 0.17260
# 121/121 - 68s - loss: 0.3776 - accuracy: 0.8456 - val_loss: 0.1729 - val_accuracy: 0.9471 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 79/150
#
# Epoch 79: val_loss did not improve from 0.17260
# 121/121 - 68s - loss: 0.3807 - accuracy: 0.8381 - val_loss: 0.1782 - val_accuracy: 0.9419 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 80/150
#
# Epoch 80: val_loss did not improve from 0.17260
# 121/121 - 68s - loss: 0.3860 - accuracy: 0.8435 - val_loss: 0.1739 - val_accuracy: 0.9478 - lr: 0.0010 - 68s/epoch - 561ms/step
# Epoch 81/150
#
# Epoch 81: val_loss improved from 0.17260 to 0.16922, saving model to model.h5
# 121/121 - 68s - loss: 0.3791 - accuracy: 0.8452 - val_loss: 0.1692 - val_accuracy: 0.9481 - lr: 0.0010 - 68s/epoch - 566ms/step
# Epoch 82/150
#
# Epoch 82: val_loss did not improve from 0.16922
# 121/121 - 68s - loss: 0.3729 - accuracy: 0.8468 - val_loss: 0.1873 - val_accuracy: 0.9402 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 83/150
#
# Epoch 83: val_loss improved from 0.16922 to 0.16646, saving model to model.h5
# 121/121 - 69s - loss: 0.3653 - accuracy: 0.8485 - val_loss: 0.1665 - val_accuracy: 0.9480 - lr: 0.0010 - 69s/epoch - 566ms/step
# Epoch 84/150
#
# Epoch 84: val_loss improved from 0.16646 to 0.16314, saving model to model.h5
# 121/121 - 69s - loss: 0.3722 - accuracy: 0.8441 - val_loss: 0.1631 - val_accuracy: 0.9523 - lr: 0.0010 - 69s/epoch - 573ms/step
# Epoch 85/150
#
# Epoch 85: val_loss did not improve from 0.16314
# 121/121 - 68s - loss: 0.3706 - accuracy: 0.8524 - val_loss: 0.1645 - val_accuracy: 0.9497 - lr: 0.0010 - 68s/epoch - 562ms/step
# Epoch 86/150
#
# Epoch 86: val_loss improved from 0.16314 to 0.16167, saving model to model.h5
# 121/121 - 70s - loss: 0.3620 - accuracy: 0.8522 - val_loss: 0.1617 - val_accuracy: 0.9502 - lr: 0.0010 - 70s/epoch - 575ms/step
# Epoch 87/150
#
# Epoch 87: val_loss improved from 0.16167 to 0.16030, saving model to model.h5
# 121/121 - 69s - loss: 0.3571 - accuracy: 0.8569 - val_loss: 0.1603 - val_accuracy: 0.9502 - lr: 0.0010 - 69s/epoch - 572ms/step
# Epoch 88/150
#
# Epoch 88: val_loss improved from 0.16030 to 0.15698, saving model to model.h5
# 121/121 - 70s - loss: 0.3579 - accuracy: 0.8546 - val_loss: 0.1570 - val_accuracy: 0.9536 - lr: 0.0010 - 70s/epoch - 576ms/step
# Epoch 89/150
#
# Epoch 89: val_loss improved from 0.15698 to 0.14998, saving model to model.h5
# 121/121 - 69s - loss: 0.3577 - accuracy: 0.8508 - val_loss: 0.1500 - val_accuracy: 0.9568 - lr: 0.0010 - 69s/epoch - 571ms/step
# Epoch 90/150
#
# Epoch 90: val_loss did not improve from 0.14998
# 121/121 - 68s - loss: 0.3518 - accuracy: 0.8585 - val_loss: 0.1528 - val_accuracy: 0.9534 - lr: 0.0010 - 68s/epoch - 563ms/step
# Epoch 91/150
#
# Epoch 91: val_loss did not improve from 0.14998
# 121/121 - 68s - loss: 0.3553 - accuracy: 0.8547 - val_loss: 0.1648 - val_accuracy: 0.9464 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 92/150
#
# Epoch 92: val_loss improved from 0.14998 to 0.14517, saving model to model.h5
# 121/121 - 69s - loss: 0.3507 - accuracy: 0.8578 - val_loss: 0.1452 - val_accuracy: 0.9564 - lr: 0.0010 - 69s/epoch - 569ms/step
# Epoch 93/150
#
# Epoch 93: val_loss did not improve from 0.14517
# 121/121 - 68s - loss: 0.3415 - accuracy: 0.8621 - val_loss: 0.1454 - val_accuracy: 0.9565 - lr: 0.0010 - 68s/epoch - 564ms/step
# Epoch 94/150
#
# Epoch 94: val_loss improved from 0.14517 to 0.14341, saving model to model.h5
# 121/121 - 68s - loss: 0.3391 - accuracy: 0.8651 - val_loss: 0.1434 - val_accuracy: 0.9574 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 95/150
#
# Epoch 95: val_loss improved from 0.14341 to 0.13574, saving model to model.h5
# 121/121 - 69s - loss: 0.3433 - accuracy: 0.8628 - val_loss: 0.1357 - val_accuracy: 0.9604 - lr: 0.0010 - 69s/epoch - 569ms/step
# Epoch 96/150
#
# Epoch 96: val_loss improved from 0.13574 to 0.13453, saving model to model.h5
# 121/121 - 68s - loss: 0.3447 - accuracy: 0.8610 - val_loss: 0.1345 - val_accuracy: 0.9580 - lr: 0.0010 - 68s/epoch - 566ms/step
# Epoch 97/150
#
# Epoch 97: val_loss did not improve from 0.13453
# 121/121 - 67s - loss: 0.3369 - accuracy: 0.8637 - val_loss: 0.1352 - val_accuracy: 0.9609 - lr: 0.0010 - 67s/epoch - 556ms/step
# Epoch 98/150
#
# Epoch 98: val_loss did not improve from 0.13453
# 121/121 - 67s - loss: 0.3390 - accuracy: 0.8656 - val_loss: 0.1362 - val_accuracy: 0.9586 - lr: 0.0010 - 67s/epoch - 555ms/step
# Epoch 99/150
#
# Epoch 99: val_loss did not improve from 0.13453
# 121/121 - 67s - loss: 0.3449 - accuracy: 0.8612 - val_loss: 0.1400 - val_accuracy: 0.9589 - lr: 0.0010 - 67s/epoch - 557ms/step
# Epoch 100/150
#
# Epoch 100: val_loss improved from 0.13453 to 0.13112, saving model to model.h5
# 121/121 - 68s - loss: 0.3319 - accuracy: 0.8677 - val_loss: 0.1311 - val_accuracy: 0.9585 - lr: 0.0010 - 68s/epoch - 563ms/step
# Epoch 101/150
#
# Epoch 101: val_loss did not improve from 0.13112
# 121/121 - 68s - loss: 0.3291 - accuracy: 0.8673 - val_loss: 0.1342 - val_accuracy: 0.9580 - lr: 0.0010 - 68s/epoch - 559ms/step
# Epoch 102/150
#
# Epoch 102: val_loss improved from 0.13112 to 0.12864, saving model to model.h5
# 121/121 - 68s - loss: 0.3337 - accuracy: 0.8664 - val_loss: 0.1286 - val_accuracy: 0.9615 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 103/150
#
# Epoch 103: val_loss improved from 0.12864 to 0.12681, saving model to model.h5
# 121/121 - 69s - loss: 0.3268 - accuracy: 0.8669 - val_loss: 0.1268 - val_accuracy: 0.9628 - lr: 0.0010 - 69s/epoch - 567ms/step
# Epoch 104/150
#
# Epoch 104: val_loss improved from 0.12681 to 0.12353, saving model to model.h5
# 121/121 - 68s - loss: 0.3237 - accuracy: 0.8726 - val_loss: 0.1235 - val_accuracy: 0.9637 - lr: 0.0010 - 68s/epoch - 563ms/step
# Epoch 105/150
#
# Epoch 105: val_loss did not improve from 0.12353
# 121/121 - 67s - loss: 0.3194 - accuracy: 0.8694 - val_loss: 0.1241 - val_accuracy: 0.9620 - lr: 0.0010 - 67s/epoch - 558ms/step
# Epoch 106/150
#
# Epoch 106: val_loss improved from 0.12353 to 0.11867, saving model to model.h5
# 121/121 - 68s - loss: 0.3276 - accuracy: 0.8677 - val_loss: 0.1187 - val_accuracy: 0.9676 - lr: 0.0010 - 68s/epoch - 564ms/step
# Epoch 107/150
#
# Epoch 107: val_loss did not improve from 0.11867
# 121/121 - 67s - loss: 0.3202 - accuracy: 0.8734 - val_loss: 0.1262 - val_accuracy: 0.9616 - lr: 0.0010 - 67s/epoch - 556ms/step
# Epoch 108/150
#
# Epoch 108: val_loss improved from 0.11867 to 0.11567, saving model to model.h5
# 121/121 - 68s - loss: 0.3132 - accuracy: 0.8729 - val_loss: 0.1157 - val_accuracy: 0.9644 - lr: 0.0010 - 68s/epoch - 561ms/step
# Epoch 109/150
#
# Epoch 109: val_loss did not improve from 0.11567
# 121/121 - 67s - loss: 0.3135 - accuracy: 0.8734 - val_loss: 0.1230 - val_accuracy: 0.9626 - lr: 0.0010 - 67s/epoch - 553ms/step
# Epoch 110/150
#
# Epoch 110: val_loss did not improve from 0.11567
# 121/121 - 67s - loss: 0.3176 - accuracy: 0.8717 - val_loss: 0.1217 - val_accuracy: 0.9642 - lr: 0.0010 - 67s/epoch - 555ms/step
# Epoch 111/150
#
# Epoch 111: val_loss improved from 0.11567 to 0.11378, saving model to model.h5
# 121/121 - 68s - loss: 0.3115 - accuracy: 0.8777 - val_loss: 0.1138 - val_accuracy: 0.9662 - lr: 0.0010 - 68s/epoch - 564ms/step
# Epoch 112/150
#
# Epoch 112: val_loss did not improve from 0.11378
# 121/121 - 67s - loss: 0.3098 - accuracy: 0.8745 - val_loss: 0.1161 - val_accuracy: 0.9651 - lr: 0.0010 - 67s/epoch - 555ms/step
# Epoch 113/150
#
# Epoch 113: val_loss did not improve from 0.11378
# 121/121 - 67s - loss: 0.3146 - accuracy: 0.8727 - val_loss: 0.1165 - val_accuracy: 0.9660 - lr: 0.0010 - 67s/epoch - 553ms/step
# Epoch 114/150
#
# Epoch 114: val_loss improved from 0.11378 to 0.11139, saving model to model.h5
# 121/121 - 68s - loss: 0.3020 - accuracy: 0.8771 - val_loss: 0.1114 - val_accuracy: 0.9677 - lr: 0.0010 - 68s/epoch - 561ms/step
# Epoch 115/150
#
# Epoch 115: val_loss did not improve from 0.11139
# 121/121 - 67s - loss: 0.3127 - accuracy: 0.8772 - val_loss: 0.1114 - val_accuracy: 0.9693 - lr: 0.0010 - 67s/epoch - 558ms/step
# Epoch 116/150
#
# Epoch 116: val_loss did not improve from 0.11139
# 121/121 - 67s - loss: 0.2982 - accuracy: 0.8815 - val_loss: 0.1124 - val_accuracy: 0.9657 - lr: 0.0010 - 67s/epoch - 553ms/step
# Epoch 117/150
#
# Epoch 117: val_loss improved from 0.11139 to 0.10138, saving model to model.h5
# 121/121 - 68s - loss: 0.2977 - accuracy: 0.8786 - val_loss: 0.1014 - val_accuracy: 0.9710 - lr: 0.0010 - 68s/epoch - 562ms/step
# Epoch 118/150
#
# Epoch 118: val_loss did not improve from 0.10138
# 121/121 - 67s - loss: 0.3064 - accuracy: 0.8770 - val_loss: 0.1082 - val_accuracy: 0.9699 - lr: 0.0010 - 67s/epoch - 555ms/step
# Epoch 119/150
#
# Epoch 119: val_loss did not improve from 0.10138
# 121/121 - 67s - loss: 0.3002 - accuracy: 0.8801 - val_loss: 0.1053 - val_accuracy: 0.9683 - lr: 0.0010 - 67s/epoch - 556ms/step
# Epoch 120/150
#
# Epoch 120: val_loss improved from 0.10138 to 0.10087, saving model to model.h5
# 121/121 - 68s - loss: 0.2956 - accuracy: 0.8808 - val_loss: 0.1009 - val_accuracy: 0.9713 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 121/150
#
# Epoch 121: val_loss improved from 0.10087 to 0.10012, saving model to model.h5
# 121/121 - 68s - loss: 0.3059 - accuracy: 0.8774 - val_loss: 0.1001 - val_accuracy: 0.9721 - lr: 0.0010 - 68s/epoch - 563ms/step
# Epoch 122/150
#
# Epoch 122: val_loss did not improve from 0.10012
# 121/121 - 68s - loss: 0.2968 - accuracy: 0.8829 - val_loss: 0.1051 - val_accuracy: 0.9705 - lr: 0.0010 - 68s/epoch - 562ms/step
# Epoch 123/150
#
# Epoch 123: val_loss improved from 0.10012 to 0.09712, saving model to model.h5
# 121/121 - 68s - loss: 0.2987 - accuracy: 0.8812 - val_loss: 0.0971 - val_accuracy: 0.9745 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 124/150
#
# Epoch 124: val_loss did not improve from 0.09712
# 121/121 - 67s - loss: 0.2904 - accuracy: 0.8861 - val_loss: 0.0997 - val_accuracy: 0.9710 - lr: 0.0010 - 67s/epoch - 554ms/step
# Epoch 125/150
#
# Epoch 125: val_loss did not improve from 0.09712
# 121/121 - 67s - loss: 0.2951 - accuracy: 0.8829 - val_loss: 0.1067 - val_accuracy: 0.9692 - lr: 0.0010 - 67s/epoch - 557ms/step
# Epoch 126/150
#
# Epoch 126: val_loss improved from 0.09712 to 0.09583, saving model to model.h5
# 121/121 - 68s - loss: 0.2850 - accuracy: 0.8884 - val_loss: 0.0958 - val_accuracy: 0.9729 - lr: 0.0010 - 68s/epoch - 563ms/step
# Epoch 127/150
#
# Epoch 127: val_loss improved from 0.09583 to 0.09552, saving model to model.h5
# 121/121 - 68s - loss: 0.2899 - accuracy: 0.8833 - val_loss: 0.0955 - val_accuracy: 0.9731 - lr: 0.0010 - 68s/epoch - 564ms/step
# Epoch 128/150
#
# Epoch 128: val_loss did not improve from 0.09552
# 121/121 - 68s - loss: 0.2823 - accuracy: 0.8888 - val_loss: 0.0963 - val_accuracy: 0.9719 - lr: 0.0010 - 68s/epoch - 561ms/step
# Epoch 129/150
#
# Epoch 129: val_loss improved from 0.09552 to 0.09303, saving model to model.h5
# 121/121 - 68s - loss: 0.2759 - accuracy: 0.8894 - val_loss: 0.0930 - val_accuracy: 0.9724 - lr: 0.0010 - 68s/epoch - 564ms/step
# Epoch 130/150
#
# Epoch 130: val_loss improved from 0.09303 to 0.09106, saving model to model.h5
# 121/121 - 68s - loss: 0.2838 - accuracy: 0.8870 - val_loss: 0.0911 - val_accuracy: 0.9751 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 131/150
#
# Epoch 131: val_loss did not improve from 0.09106
# 121/121 - 67s - loss: 0.2873 - accuracy: 0.8866 - val_loss: 0.0993 - val_accuracy: 0.9704 - lr: 0.0010 - 67s/epoch - 556ms/step
# Epoch 132/150
#
# Epoch 132: val_loss improved from 0.09106 to 0.09045, saving model to model.h5
# 121/121 - 68s - loss: 0.2721 - accuracy: 0.8946 - val_loss: 0.0905 - val_accuracy: 0.9751 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 133/150
#
# Epoch 133: val_loss improved from 0.09045 to 0.08757, saving model to model.h5
# 121/121 - 68s - loss: 0.2769 - accuracy: 0.8914 - val_loss: 0.0876 - val_accuracy: 0.9749 - lr: 0.0010 - 68s/epoch - 561ms/step
# Epoch 134/150
#
# Epoch 134: val_loss did not improve from 0.08757
# 121/121 - 67s - loss: 0.2764 - accuracy: 0.8906 - val_loss: 0.0932 - val_accuracy: 0.9743 - lr: 0.0010 - 67s/epoch - 557ms/step
# Epoch 135/150
#
# Epoch 135: val_loss improved from 0.08757 to 0.08339, saving model to model.h5
# 121/121 - 68s - loss: 0.2675 - accuracy: 0.8951 - val_loss: 0.0834 - val_accuracy: 0.9760 - lr: 0.0010 - 68s/epoch - 562ms/step
# Epoch 136/150
#
# Epoch 136: val_loss did not improve from 0.08339
# 121/121 - 67s - loss: 0.2765 - accuracy: 0.8924 - val_loss: 0.0926 - val_accuracy: 0.9717 - lr: 0.0010 - 67s/epoch - 554ms/step
# Epoch 137/150
#
# Epoch 137: val_loss did not improve from 0.08339
# 121/121 - 68s - loss: 0.2737 - accuracy: 0.8923 - val_loss: 0.0955 - val_accuracy: 0.9727 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 138/150
#
# Epoch 138: val_loss did not improve from 0.08339
# 121/121 - 67s - loss: 0.2688 - accuracy: 0.8924 - val_loss: 0.0866 - val_accuracy: 0.9755 - lr: 0.0010 - 67s/epoch - 554ms/step
# Epoch 139/150
#
# Epoch 139: val_loss did not improve from 0.08339
# 121/121 - 67s - loss: 0.2754 - accuracy: 0.8929 - val_loss: 0.0845 - val_accuracy: 0.9762 - lr: 0.0010 - 67s/epoch - 550ms/step
# Epoch 140/150
#
# Epoch 140: val_loss did not improve from 0.08339
# 121/121 - 67s - loss: 0.2765 - accuracy: 0.8931 - val_loss: 0.0856 - val_accuracy: 0.9734 - lr: 0.0010 - 67s/epoch - 555ms/step
# Epoch 141/150
#
# Epoch 141: val_loss improved from 0.08339 to 0.07944, saving model to model.h5
# 121/121 - 68s - loss: 0.2621 - accuracy: 0.8974 - val_loss: 0.0794 - val_accuracy: 0.9771 - lr: 0.0010 - 68s/epoch - 565ms/step
# Epoch 142/150
#
# Epoch 142: val_loss improved from 0.07944 to 0.07905, saving model to model.h5
# 121/121 - 68s - loss: 0.2685 - accuracy: 0.8947 - val_loss: 0.0791 - val_accuracy: 0.9786 - lr: 0.0010 - 68s/epoch - 564ms/step
# Epoch 143/150
#
# Epoch 143: val_loss did not improve from 0.07905
# 121/121 - 67s - loss: 0.2722 - accuracy: 0.8939 - val_loss: 0.0814 - val_accuracy: 0.9790 - lr: 0.0010 - 67s/epoch - 556ms/step
# Epoch 144/150
#
# Epoch 144: val_loss did not improve from 0.07905
# 121/121 - 67s - loss: 0.2678 - accuracy: 0.8949 - val_loss: 0.0832 - val_accuracy: 0.9784 - lr: 0.0010 - 67s/epoch - 556ms/step
# Epoch 145/150
#
# Epoch 145: val_loss did not improve from 0.07905
# 121/121 - 67s - loss: 0.2593 - accuracy: 0.8978 - val_loss: 0.0841 - val_accuracy: 0.9773 - lr: 0.0010 - 67s/epoch - 554ms/step
# Epoch 146/150
#
# Epoch 146: val_loss did not improve from 0.07905
# 121/121 - 68s - loss: 0.2622 - accuracy: 0.8961 - val_loss: 0.0819 - val_accuracy: 0.9767 - lr: 0.0010 - 68s/epoch - 560ms/step
# Epoch 147/150
#
# Epoch 147: val_loss did not improve from 0.07905
# 121/121 - 67s - loss: 0.2575 - accuracy: 0.8972 - val_loss: 0.0810 - val_accuracy: 0.9752 - lr: 0.0010 - 67s/epoch - 556ms/step
# Epoch 148/150
#
# Epoch 148: val_loss did not improve from 0.07905
# 121/121 - 67s - loss: 0.2630 - accuracy: 0.8972 - val_loss: 0.0811 - val_accuracy: 0.9783 - lr: 0.0010 - 67s/epoch - 552ms/step
# Epoch 149/150
#
# Epoch 149: val_loss did not improve from 0.07905
# 121/121 - 67s - loss: 0.2687 - accuracy: 0.8955 - val_loss: 0.0838 - val_accuracy: 0.9767 - lr: 0.0010 - 67s/epoch - 553ms/step
# Epoch 150/150
#
# Epoch 150: val_loss did not improve from 0.07905
# 121/121 - 67s - loss: 0.2653 - accuracy: 0.8950 - val_loss: 0.0807 - val_accuracy: 0.9773 - lr: 0.0010 - 67s/epoch - 554ms/step

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper left')
plt.show()

# %%
#Model Accuracy graph and Loss Value Graph
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train'],loc = 'upper right')
plt.show()

# %%
model.save('/content/drive/MyDrive/KFMZ/Mohsin/Mini_DDSM_Upload/ML_Models/DenseNet_150_epoch/DenseNet169/Case_7_All_Cases/model.h5')

# %%
ypred = model.predict(xtest)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(ypred)):
    if np.argmax(ypred[i]) == np.argmax(ytest[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)
        
    total += 1
    
print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)
print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Total-test-data; 3878 	accurately-predicted-data: 3528 	 wrongly-predicted-data:  350
# Accuracy: 90.975 %

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(accurateindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
label=['Benign','Cancer','Normal']
imidx = random.sample(wrongindex, k=9)# replace with 'wrongindex'

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(15, 12))

n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(xtest[imidx[n]])
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(label[np.argmax(ypred[imidx[n]])], label[np.argmax(ytest[imidx[n]])]))
            n += 1

plt.show()

# %%
Ypred = model.predict(xtest)

Ypred = np.argmax(Ypred, axis=1)
Ytrue = np.argmax(ytest, axis=1)

cm = confusion_matrix(Ytrue, Ypred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap="rocket_r", fmt=".01f",annot_kws={'size':16}, annot=True, square=True, xticklabels=label, yticklabels=label)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')
